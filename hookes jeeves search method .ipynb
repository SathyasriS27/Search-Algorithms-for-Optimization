# %%
#termination parameter is given 
# 2 variables 
import math
from decimal import Decimal
def f(x,y):
    return Decimal((x-1)**2+(y-2)**2)
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
E=Decimal(input(("enter the termination parameter")))
alpha=Decimal(input(("enter the reduction parameter or alpha")))
k=0
i=1
j=0
l=0
x1=[]
y1=[]
fminb=[]
fcomp=[]
while True :
    print("")
    print("iteration no. :",i)
    print("For X")
    x=[]
    y=[]
    fxx=[]
    fxy=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    f0=f(Decimal(x0),Decimal(y0))
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx)))
    x.append(Decimal(x[k]-(delx)))
    fxx.append(f(x[1],y[0]))
    fxx.append(f(x[2],y[0]))
    p=0
    print("x(0)=(",x0,",",y0,")\tf(x(0))=",f0)
    print("x(1)=(",x[1],",",y[0],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[2],",",y[0],")\tf(x(2))=",fxx[2])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x01=x0
        y01=y0
    elif fxx[1]==fmin:
        x01=x[1]
        y01=y0
    elif fxx[2]==fmin:
        x01=x[2]
        y01=y0
    print("the new values for calculation of Y is (",x01,",",y01,")")
    print("For Y")
    y.append(Decimal(y[k]+(dely)))
    y.append(Decimal(y[k]-(dely)))
    fxy.append(f(Decimal(x01),Decimal(y01)))
    fxy.append(f(Decimal(x01),y[1]))
    fxy.append(f(Decimal(x01),y[2]))
    print("x(0)=(",x01,",",y01,")\tf(x(0))=",fxy[0])
    print("x(1)=(",x01,",",y[1],")\tf(x(1))=",fxy[1])
    print("x(2)=(",x01,",",y[2],")\tf(x(2))=",fxy[2])
    fmin=min(fxy)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxy[0]==fmin:
        x02=x01
        y02=y01
    elif fxy[1]==fmin:
        x02=x01
        y02=y[1]
    elif fxy[2]==fmin:
        x02=x01
        y02=y[2]
    x1.append(Decimal(x0))
    x1.append(Decimal(x02))
    y1.append(Decimal(y0))
    y1.append(Decimal(y02))
    print("min lies in (",x02,",",y02,")")
    fcomp.append(f(x02,y02))
    if l>=1:
        if (fcomp[i-1]<fcomp[i-2]):
            print("f(x(",i,"))<f(x(",i-1,"))")
            
        elif (fcomp[i-1]==fcomp[i-2]):
            print("f(x(",i,"))=f(x(",i-1,"))")
            moddel=((delx)**2+(dely)**2)**Decimal(0.5)
            if moddel>E:
                p=1
                print("||del||>E=||",moddel,"||>",E)
                delx=delx/2
                dely=dely/2
                print("the new values of delx and dely are =(",delx,",",dely,")")
                x0=x02
                y0=y02
                i=i+1
                j=j+2
                l=l+1
                continue
        else :
            print("f(x(",i,"))>f(x(",i-1,"))") 
    if (x0==x02) and (y0==y02):
        print("Exploratory move is not a success")
        moddel=((delx)**2+(dely)**2)**Decimal(0.5)
        if moddel<E:
            print("||del||<E=||",moddel,"||<",E)  
            print("min lies in (",x02,",",y02,")")
            break
    elif p!=1:
        print("Exploratory move is a success")
        print("pattern move :")
        if j==0:
            xp1=2*(x1[j+1])-(x1[j])
            yp1=2*(x1[j+1])-(x1[j])
            print("x(p)=(",xp1,",",yp1,")")
            
        else :
            xp1=2*(x1[j+1])-(x1[j-1])
            yp1=2*(y1[j+1])-(y1[j-1])
            print("x(p)=(",xp1,",",yp1,")")
        x0=xp1
        y0=yp1
        i=i+1
        j=j+2
        l=l+1
# Out:
# Enter the intital value of x00
# Enter the intital value of y00
# Enter the x value in the reduction parameter0.5
# Enter the y value in the reduction parameter0.5
# enter the termination parameter0.5
# enter the reduction parameter or alpha2
#
# iteration no. : 1
# For X
# x(0)=( 0 , 0 )	f(x(0))= 5
# x(1)=( 0.5 , 0 )	f(x(1))= 4.25
# x(2)=( -0.5 , 0 )	f(x(2))= 6.25
# fmin= 4.25
# the new values for calculation of Y is ( 0.5 , 0 )
# For Y
# x(0)=( 0.5 , 0 )	f(x(0))= 4.25
# x(1)=( 0.5 , 0.5 )	f(x(1))= 2.50
# x(2)=( 0.5 , -0.5 )	f(x(2))= 6.50
# fmin= 2.50
# min lies in ( 0.5 , 0.5 )
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 1.0 )
#
# iteration no. : 2
# For X
# x(0)=( 1.0 , 1.0 )	f(x(0))= 1.00
# x(1)=( 1.5 , 1.0 )	f(x(1))= 1.25
# x(2)=( 0.5 , 1.0 )	f(x(2))= 1.25
# fmin= 1.00
# the new values for calculation of Y is ( 1.0 , 1.0 )
# For Y
# x(0)=( 1.0 , 1.0 )	f(x(0))= 1.00
# x(1)=( 1.0 , 1.5 )	f(x(1))= 0.25
# x(2)=( 1.0 , 0.5 )	f(x(2))= 2.25
# fmin= 0.25
# min lies in ( 1.0 , 1.5 )
# f(x( 2 ))<f(x( 1 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.5 , 2.5 )
#
# iteration no. : 3
# For X
# x(0)=( 1.5 , 2.5 )	f(x(0))= 0.50
# x(1)=( 2.0 , 2.5 )	f(x(1))= 1.25
# x(2)=( 1.0 , 2.5 )	f(x(2))= 0.25
# fmin= 0.25
# the new values for calculation of Y is ( 1.0 , 2.5 )
# For Y
# x(0)=( 1.0 , 2.5 )	f(x(0))= 0.25
# x(1)=( 1.0 , 3.0 )	f(x(1))= 1.00
# x(2)=( 1.0 , 2.0 )	f(x(2))= 0
# fmin= 0
# min lies in ( 1.0 , 2.0 )
# f(x( 3 ))<f(x( 2 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.5 )
#
# iteration no. : 4
# For X
# x(0)=( 1.0 , 2.5 )	f(x(0))= 0.25
# x(1)=( 1.5 , 2.5 )	f(x(1))= 0.50
# x(2)=( 0.5 , 2.5 )	f(x(2))= 0.50
# fmin= 0.25
# the new values for calculation of Y is ( 1.0 , 2.5 )
# For Y
# x(0)=( 1.0 , 2.5 )	f(x(0))= 0.25
# x(1)=( 1.0 , 3.0 )	f(x(1))= 1.00
# x(2)=( 1.0 , 2.0 )	f(x(2))= 0
# fmin= 0
# min lies in ( 1.0 , 2.0 )
# f(x( 4 ))=f(x( 3 ))
# ||del||>E=|| 0.7071067811865475244008443621 ||> 0.5
# the new values of delx and dely are =( 0.25 , 0.25 )
#
# iteration no. : 5
# For X
# x(0)=( 1.0 , 2.0 )	f(x(0))= 0
# x(1)=( 1.25 , 2.0 )	f(x(1))= 0.0625
# x(2)=( 0.75 , 2.0 )	f(x(2))= 0.0625
# fmin= 0
# the new values for calculation of Y is ( 1.0 , 2.0 )
# For Y
# x(0)=( 1.0 , 2.0 )	f(x(0))= 0
# x(1)=( 1.0 , 2.25 )	f(x(1))= 0.0625
# x(2)=( 1.0 , 1.75 )	f(x(2))= 0.0625
# fmin= 0
# min lies in ( 1.0 , 2.0 )
# f(x( 5 ))=f(x( 4 ))
# Exploratory move is not a success
# ||del||<E=|| 0.3535533905932737622004221811 ||< 0.5
# min lies in ( 1.0 , 2.0 )

# %%
#termination parameter 
#3 variables 
import math
from decimal import Decimal
def f(x,y,z):
    return Decimal(((x-1)**2+(y-2)**2)+z)
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
z0=input(("Enter the intital value of z0"))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
E=Decimal(input(("enter the termination parameter")))
alpha=Decimal(input(("enter the reduction parameter or alpha")))
k=0
i=1
j=0
l=0
x1=[]
y1=[]
z1=[]
fminb=[]
fcomp=[]
while True :
    print("")
    print("iteration no. :",i)
    print("For X")
    x=[]
    y=[]
    z=[]
    fxx=[]
    fxy=[]
    fxz=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    z.append(Decimal(z0))
    f0=f(Decimal(x0),Decimal(y0),Decimal(z0))
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx)))
    x.append(Decimal(x[k]-(delx)))
    fxx.append(f(x[1],y[0],z[0]))
    fxx.append(f(x[2],y[0],z[0]))
    print("f=(",x0,",",y0,",",z0,")\tf(x(0))=",f0)
    print("f+=(",x[1],",",y[0],",",z[0],")\tf(x(1))=",fxx[1])
    print("f-=(",x[2],",",y[0],",",z[0],")\tf(x(2))=",fxx[2])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x01=x0
        y01=y0
        z01=z0
    elif fxx[1]==fmin:
        x01=x[1]
        y01=y0
        z01=z0
    elif fxx[2]==fmin:
        x01=x[2]
        y01=y0
        z01=z0
    print("the new values for calculation of Y is (",x01,",",y01,",",z01,")")
    print("For Y")
    y.append(Decimal(y[k]+(dely)))
    y.append(Decimal(y[k]-(dely)))
    fxy.append(f(Decimal(x01),Decimal(y01),Decimal(z01)))
    fxy.append(f(Decimal(x01),y[1],Decimal(z01)))
    fxy.append(f(Decimal(x01),y[2],Decimal(z01)))
    print("f=(",x01,",",y01,",",z01,")\tf(x(0))=",fxy[0])
    print("f+=(",x01,",",y[1],",",z01,")\tf(x(1))=",fxy[1])
    print("f-=(",x01,",",y[2],",",z01,")\tf(x(2))=",fxy[2])
    fmin=min(fxy)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxy[0]==fmin:
        x02=x01
        y02=y01
        z02=z01
    elif fxy[1]==fmin:
        x02=x01
        y02=y[1]
        z02=z01
    elif fxy[2]==fmin:
        x02=x01
        y02=y[2]
        z02=z01
    print("the new values for calculation of Z is (",x02,",",y02,",",z02,")")
    print("For Z")
    z.append(Decimal(z[k]+(delz)))
    z.append(Decimal(z[k]-(delz)))
    fxz.append(f(Decimal(x02),Decimal(y02),Decimal(z02)))
    fxz.append(f(Decimal(x02),Decimal(y02),z[1]))
    fxz.append(f(Decimal(x02),Decimal(y02),z[2]))
    print("f=(",x02,",",y02,",",z02,")\tf(x(0))=",fxz[0])
    print("f+=(",x02,",",y02,",",z[1],")\tf(x(1))=",fxz[1])
    print("f-=(",x02,",",y02,",",z[2],")\tf(x(2))=",fxz[2])
    fmin=min(fxz)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxz[0]==fmin:
        x03=x02
        y03=y02
        z03=z02
    elif fxz[1]==fmin:
        x03=x02
        y03=y02
        z03=z[1]
    elif fxz[2]==fmin:
        x03=x02
        y03=y02
        z03=z[2] 
    x1.append(Decimal(x0))
    x1.append(Decimal(x03))
    y1.append(Decimal(y0))
    y1.append(Decimal(y03))
    z1.append(Decimal(z0))
    z1.append(Decimal(z03))
    print("min lies in (",x03,",",y03,",",z03,")")
    fcomp.append(f(x03,y03,z03))
    if l>=1:
        if (fcomp[i-1]<fcomp[i-2]):
            print("f(x(",i,"))<f(x(",i-1,"))")
            
        elif (fcomp[i-1]==fcomp[i-2]):
            print("f(x(",i,"))=f(x(",i-1,"))")
            moddel=((delx)**2+(dely)**2+(delz)**2)**Decimal(0.5)
            if moddel>E:
                p=1
                print("||del||>E=||",moddel,"||>",E)
                delx=delx/2
                dely=dely/2
                delz=delz/2
                print("the new values of del are =(",delx,",",dely,",",delz,")")
                x0=x03
                y0=y03
                z0=z03
                i=i+1
                j=j+2
                l=l+1
                continue
        else :
            print("f(x(",i,"))>f(x(",i-1,"))") 
    if (x0==x03) and (y0==y03) and (z0==z03):
        print("Exploratory move is not a success")
        moddel=((delx)**2+(dely)**2+(dely)**2)**Decimal(0.5)
        if moddel<E:
            print("||del||<E=||",moddel,"||<",E)  
            print("min lies in (",x03,",",y03,",",z03,")")
            break
    elif p!=1:
        print("Exploratory move is a success")
        print("pattern move :")
        if j==0:
            xp1=2*(x1[j+1])-(x1[j])
            yp1=2*(y1[j+1])-(y1[j])
            zp1=2*(z1[j+1])-(z1[j])
            print("x(p)=(",xp1,",",yp1,",",zp1,")") 
            
        else :
            xp1=2*(x1[j+1])-(x1[j-1])
            yp1=2*(y1[j+1])-(y1[j-1])
            zp1=2*(z1[j+1])-(z1[j-1])
            print("x(p)=(",xp1,",",yp1,",",zp1,")") 
        x0=xp1
        y0=yp1
        z0=zp1
        i=i+1
        j=j+2
        l=l+1
# Out:
# Enter the intital value of x00
# Enter the intital value of y00
# Enter the intital value of z00
# Enter the x value in the reduction parameter0.5
# Enter the y value in the reduction parameter0.5
# Enter the z value in the reduction parameter0.5
# enter the termination parameter0.8
# enter the reduction parameter or alpha2
#
# iteration no. : 1
# For X
# f=( 0 , 0 , 0 )	f(x(0))= 5
# f+=( 0.5 , 0 , 0 )	f(x(1))= 4.25
# f-=( -0.5 , 0 , 0 )	f(x(2))= 6.25
# fmin= 4.25
# the new values for calculation of Y is ( 0.5 , 0 , 0 )
# For Y
# f=( 0.5 , 0 , 0 )	f(x(0))= 4.25
# f+=( 0.5 , 0.5 , 0 )	f(x(1))= 2.50
# f-=( 0.5 , -0.5 , 0 )	f(x(2))= 6.50
# fmin= 2.50
# the new values for calculation of Z is ( 0.5 , 0.5 , 0 )
# For Z
# f=( 0.5 , 0.5 , 0 )	f(x(0))= 2.50
# f+=( 0.5 , 0.5 , 0.5 )	f(x(1))= 3.00
# f-=( 0.5 , 0.5 , -0.5 )	f(x(2))= 2.00
# fmin= 2.00
# min lies in ( 0.5 , 0.5 , -0.5 )
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 1.0 , -1.0 )
#
# iteration no. : 2
# For X
# f=( 1.0 , 1.0 , -1.0 )	f(x(0))= 0.00
# f+=( 1.5 , 1.0 , -1.0 )	f(x(1))= 0.25
# f-=( 0.5 , 1.0 , -1.0 )	f(x(2))= 0.25
# fmin= 0.00
# the new values for calculation of Y is ( 1.0 , 1.0 , -1.0 )
# For Y
# f=( 1.0 , 1.0 , -1.0 )	f(x(0))= 0.00
# f+=( 1.0 , 1.5 , -1.0 )	f(x(1))= -0.75
# f-=( 1.0 , 0.5 , -1.0 )	f(x(2))= 1.25
# fmin= -0.75
# the new values for calculation of Z is ( 1.0 , 1.5 , -1.0 )
# For Z
# f=( 1.0 , 1.5 , -1.0 )	f(x(0))= -0.75
# f+=( 1.0 , 1.5 , -0.5 )	f(x(1))= -0.25
# f-=( 1.0 , 1.5 , -1.5 )	f(x(2))= -1.25
# fmin= -1.25
# min lies in ( 1.0 , 1.5 , -1.5 )
# f(x( 2 ))<f(x( 1 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.5 , 2.5 , -2.5 )
#
# iteration no. : 3
# For X
# f=( 1.5 , 2.5 , -2.5 )	f(x(0))= -2.00
# f+=( 2.0 , 2.5 , -2.5 )	f(x(1))= -1.25
# f-=( 1.0 , 2.5 , -2.5 )	f(x(2))= -2.25
# fmin= -2.25
# the new values for calculation of Y is ( 1.0 , 2.5 , -2.5 )
# For Y
# f=( 1.0 , 2.5 , -2.5 )	f(x(0))= -2.25
# f+=( 1.0 , 3.0 , -2.5 )	f(x(1))= -1.50
# f-=( 1.0 , 2.0 , -2.5 )	f(x(2))= -2.5
# fmin= -2.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -2.5 )
# For Z
# f=( 1.0 , 2.0 , -2.5 )	f(x(0))= -2.5
# f+=( 1.0 , 2.0 , -2.0 )	f(x(1))= -2.0
# f-=( 1.0 , 2.0 , -3.0 )	f(x(2))= -3.0
# fmin= -3.0
# min lies in ( 1.0 , 2.0 , -3.0 )
# f(x( 3 ))<f(x( 2 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.5 , -4.5 )
#
# iteration no. : 4
# For X
# f=( 1.0 , 2.5 , -4.5 )	f(x(0))= -4.25
# f+=( 1.5 , 2.5 , -4.5 )	f(x(1))= -4.00
# f-=( 0.5 , 2.5 , -4.5 )	f(x(2))= -4.00
# fmin= -4.25
# the new values for calculation of Y is ( 1.0 , 2.5 , -4.5 )
# For Y
# f=( 1.0 , 2.5 , -4.5 )	f(x(0))= -4.25
# f+=( 1.0 , 3.0 , -4.5 )	f(x(1))= -3.50
# f-=( 1.0 , 2.0 , -4.5 )	f(x(2))= -4.5
# fmin= -4.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -4.5 )
# For Z
# f=( 1.0 , 2.0 , -4.5 )	f(x(0))= -4.5
# f+=( 1.0 , 2.0 , -4.0 )	f(x(1))= -4.0
# f-=( 1.0 , 2.0 , -5.0 )	f(x(2))= -5.0
# fmin= -5.0
# min lies in ( 1.0 , 2.0 , -5.0 )
# f(x( 4 ))<f(x( 3 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -7.0 )
#
# iteration no. : 5
# For X
# f=( 1.0 , 2.0 , -7.0 )	f(x(0))= -7.0
# f+=( 1.5 , 2.0 , -7.0 )	f(x(1))= -6.75
# f-=( 0.5 , 2.0 , -7.0 )	f(x(2))= -6.75
# fmin= -7.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -7.0 )
# For Y
# f=( 1.0 , 2.0 , -7.0 )	f(x(0))= -7.0
# f+=( 1.0 , 2.5 , -7.0 )	f(x(1))= -6.75
# f-=( 1.0 , 1.5 , -7.0 )	f(x(2))= -6.75
# fmin= -7.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -7.0 )
# For Z
# f=( 1.0 , 2.0 , -7.0 )	f(x(0))= -7.0
# f+=( 1.0 , 2.0 , -6.5 )	f(x(1))= -6.5
# f-=( 1.0 , 2.0 , -7.5 )	f(x(2))= -7.5
# fmin= -7.5
# min lies in ( 1.0 , 2.0 , -7.5 )
# f(x( 5 ))<f(x( 4 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -10.0 )
#
# iteration no. : 6
# For X
# f=( 1.0 , 2.0 , -10.0 )	f(x(0))= -10.0
# f+=( 1.5 , 2.0 , -10.0 )	f(x(1))= -9.75
# f-=( 0.5 , 2.0 , -10.0 )	f(x(2))= -9.75
# fmin= -10.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -10.0 )
# For Y
# f=( 1.0 , 2.0 , -10.0 )	f(x(0))= -10.0
# f+=( 1.0 , 2.5 , -10.0 )	f(x(1))= -9.75
# f-=( 1.0 , 1.5 , -10.0 )	f(x(2))= -9.75
# fmin= -10.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -10.0 )
# For Z
# f=( 1.0 , 2.0 , -10.0 )	f(x(0))= -10.0
# f+=( 1.0 , 2.0 , -9.5 )	f(x(1))= -9.5
# f-=( 1.0 , 2.0 , -10.5 )	f(x(2))= -10.5
# fmin= -10.5
# min lies in ( 1.0 , 2.0 , -10.5 )
# f(x( 6 ))<f(x( 5 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -13.5 )
#
# iteration no. : 7
# For X
# f=( 1.0 , 2.0 , -13.5 )	f(x(0))= -13.5
# f+=( 1.5 , 2.0 , -13.5 )	f(x(1))= -13.25
# f-=( 0.5 , 2.0 , -13.5 )	f(x(2))= -13.25
# fmin= -13.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -13.5 )
# For Y
# f=( 1.0 , 2.0 , -13.5 )	f(x(0))= -13.5
# f+=( 1.0 , 2.5 , -13.5 )	f(x(1))= -13.25
# f-=( 1.0 , 1.5 , -13.5 )	f(x(2))= -13.25
# fmin= -13.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -13.5 )
# For Z
# f=( 1.0 , 2.0 , -13.5 )	f(x(0))= -13.5
# f+=( 1.0 , 2.0 , -13.0 )	f(x(1))= -13.0
# f-=( 1.0 , 2.0 , -14.0 )	f(x(2))= -14.0
# fmin= -14.0
# min lies in ( 1.0 , 2.0 , -14.0 )
# f(x( 7 ))<f(x( 6 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -17.5 )
#
# iteration no. : 8
# For X
# f=( 1.0 , 2.0 , -17.5 )	f(x(0))= -17.5
# f+=( 1.5 , 2.0 , -17.5 )	f(x(1))= -17.25
# f-=( 0.5 , 2.0 , -17.5 )	f(x(2))= -17.25
# fmin= -17.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -17.5 )
# For Y
# f=( 1.0 , 2.0 , -17.5 )	f(x(0))= -17.5
# f+=( 1.0 , 2.5 , -17.5 )	f(x(1))= -17.25
# f-=( 1.0 , 1.5 , -17.5 )	f(x(2))= -17.25
# fmin= -17.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -17.5 )
# For Z
# f=( 1.0 , 2.0 , -17.5 )	f(x(0))= -17.5
# f+=( 1.0 , 2.0 , -17.0 )	f(x(1))= -17.0
# f-=( 1.0 , 2.0 , -18.0 )	f(x(2))= -18.0
# fmin= -18.0
# min lies in ( 1.0 , 2.0 , -18.0 )
# f(x( 8 ))<f(x( 7 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -22.0 )
#
# iteration no. : 9
# For X
# f=( 1.0 , 2.0 , -22.0 )	f(x(0))= -22.0
# f+=( 1.5 , 2.0 , -22.0 )	f(x(1))= -21.75
# f-=( 0.5 , 2.0 , -22.0 )	f(x(2))= -21.75
# fmin= -22.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -22.0 )
# For Y
# f=( 1.0 , 2.0 , -22.0 )	f(x(0))= -22.0
# f+=( 1.0 , 2.5 , -22.0 )	f(x(1))= -21.75
# f-=( 1.0 , 1.5 , -22.0 )	f(x(2))= -21.75
# fmin= -22.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -22.0 )
# For Z
# f=( 1.0 , 2.0 , -22.0 )	f(x(0))= -22.0
# f+=( 1.0 , 2.0 , -21.5 )	f(x(1))= -21.5
# f-=( 1.0 , 2.0 , -22.5 )	f(x(2))= -22.5
# fmin= -22.5
# min lies in ( 1.0 , 2.0 , -22.5 )
# f(x( 9 ))<f(x( 8 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -27.0 )
#
# iteration no. : 10
# For X
# f=( 1.0 , 2.0 , -27.0 )	f(x(0))= -27.0
# f+=( 1.5 , 2.0 , -27.0 )	f(x(1))= -26.75
# f-=( 0.5 , 2.0 , -27.0 )	f(x(2))= -26.75
# fmin= -27.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -27.0 )
# For Y
# f=( 1.0 , 2.0 , -27.0 )	f(x(0))= -27.0
# f+=( 1.0 , 2.5 , -27.0 )	f(x(1))= -26.75
# f-=( 1.0 , 1.5 , -27.0 )	f(x(2))= -26.75
# fmin= -27.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -27.0 )
# For Z
# f=( 1.0 , 2.0 , -27.0 )	f(x(0))= -27.0
# f+=( 1.0 , 2.0 , -26.5 )	f(x(1))= -26.5
# f-=( 1.0 , 2.0 , -27.5 )	f(x(2))= -27.5
# fmin= -27.5
# min lies in ( 1.0 , 2.0 , -27.5 )
# f(x( 10 ))<f(x( 9 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -32.5 )
#
# iteration no. : 11
# For X
# f=( 1.0 , 2.0 , -32.5 )	f(x(0))= -32.5
# f+=( 1.5 , 2.0 , -32.5 )	f(x(1))= -32.25
# f-=( 0.5 , 2.0 , -32.5 )	f(x(2))= -32.25
# fmin= -32.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -32.5 )
# For Y
# f=( 1.0 , 2.0 , -32.5 )	f(x(0))= -32.5
# f+=( 1.0 , 2.5 , -32.5 )	f(x(1))= -32.25
# f-=( 1.0 , 1.5 , -32.5 )	f(x(2))= -32.25
# fmin= -32.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -32.5 )
# For Z
# f=( 1.0 , 2.0 , -32.5 )	f(x(0))= -32.5
# f+=( 1.0 , 2.0 , -32.0 )	f(x(1))= -32.0
# f-=( 1.0 , 2.0 , -33.0 )	f(x(2))= -33.0
# fmin= -33.0
# min lies in ( 1.0 , 2.0 , -33.0 )
# f(x( 11 ))<f(x( 10 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -38.5 )
#
# iteration no. : 12
# For X
# f=( 1.0 , 2.0 , -38.5 )	f(x(0))= -38.5
# f+=( 1.5 , 2.0 , -38.5 )	f(x(1))= -38.25
# f-=( 0.5 , 2.0 , -38.5 )	f(x(2))= -38.25
# fmin= -38.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -38.5 )
# For Y
# f=( 1.0 , 2.0 , -38.5 )	f(x(0))= -38.5
# f+=( 1.0 , 2.5 , -38.5 )	f(x(1))= -38.25
# f-=( 1.0 , 1.5 , -38.5 )	f(x(2))= -38.25
# fmin= -38.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -38.5 )
# For Z
# f=( 1.0 , 2.0 , -38.5 )	f(x(0))= -38.5
# f+=( 1.0 , 2.0 , -38.0 )	f(x(1))= -38.0
# f-=( 1.0 , 2.0 , -39.0 )	f(x(2))= -39.0
# fmin= -39.0
# min lies in ( 1.0 , 2.0 , -39.0 )
# f(x( 12 ))<f(x( 11 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -45.0 )
#
# iteration no. : 13
# For X
# f=( 1.0 , 2.0 , -45.0 )	f(x(0))= -45.0
# f+=( 1.5 , 2.0 , -45.0 )	f(x(1))= -44.75
# f-=( 0.5 , 2.0 , -45.0 )	f(x(2))= -44.75
# fmin= -45.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -45.0 )
# For Y
# f=( 1.0 , 2.0 , -45.0 )	f(x(0))= -45.0
# f+=( 1.0 , 2.5 , -45.0 )	f(x(1))= -44.75
# f-=( 1.0 , 1.5 , -45.0 )	f(x(2))= -44.75
# fmin= -45.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -45.0 )
# For Z
# f=( 1.0 , 2.0 , -45.0 )	f(x(0))= -45.0
# f+=( 1.0 , 2.0 , -44.5 )	f(x(1))= -44.5
# f-=( 1.0 , 2.0 , -45.5 )	f(x(2))= -45.5
# fmin= -45.5
# min lies in ( 1.0 , 2.0 , -45.5 )
# f(x( 13 ))<f(x( 12 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -52.0 )
#
# iteration no. : 14
# For X
# f=( 1.0 , 2.0 , -52.0 )	f(x(0))= -52.0
# f+=( 1.5 , 2.0 , -52.0 )	f(x(1))= -51.75
# f-=( 0.5 , 2.0 , -52.0 )	f(x(2))= -51.75
# fmin= -52.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -52.0 )
# For Y
# f=( 1.0 , 2.0 , -52.0 )	f(x(0))= -52.0
# f+=( 1.0 , 2.5 , -52.0 )	f(x(1))= -51.75
# f-=( 1.0 , 1.5 , -52.0 )	f(x(2))= -51.75
# fmin= -52.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -52.0 )
# For Z
# f=( 1.0 , 2.0 , -52.0 )	f(x(0))= -52.0
# f+=( 1.0 , 2.0 , -51.5 )	f(x(1))= -51.5
# f-=( 1.0 , 2.0 , -52.5 )	f(x(2))= -52.5
# fmin= -52.5
# min lies in ( 1.0 , 2.0 , -52.5 )
# f(x( 14 ))<f(x( 13 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -59.5 )
#
# iteration no. : 15
# For X
# f=( 1.0 , 2.0 , -59.5 )	f(x(0))= -59.5
# f+=( 1.5 , 2.0 , -59.5 )	f(x(1))= -59.25
# f-=( 0.5 , 2.0 , -59.5 )	f(x(2))= -59.25
# fmin= -59.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -59.5 )
# For Y
# f=( 1.0 , 2.0 , -59.5 )	f(x(0))= -59.5
# f+=( 1.0 , 2.5 , -59.5 )	f(x(1))= -59.25
# f-=( 1.0 , 1.5 , -59.5 )	f(x(2))= -59.25
# fmin= -59.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -59.5 )
# For Z
# f=( 1.0 , 2.0 , -59.5 )	f(x(0))= -59.5
# f+=( 1.0 , 2.0 , -59.0 )	f(x(1))= -59.0
# f-=( 1.0 , 2.0 , -60.0 )	f(x(2))= -60.0
# fmin= -60.0
# min lies in ( 1.0 , 2.0 , -60.0 )
# f(x( 15 ))<f(x( 14 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -67.5 )
#
# iteration no. : 16
# For X
# f=( 1.0 , 2.0 , -67.5 )	f(x(0))= -67.5
# f+=( 1.5 , 2.0 , -67.5 )	f(x(1))= -67.25
# f-=( 0.5 , 2.0 , -67.5 )	f(x(2))= -67.25
# fmin= -67.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -67.5 )
# For Y
# f=( 1.0 , 2.0 , -67.5 )	f(x(0))= -67.5
# f+=( 1.0 , 2.5 , -67.5 )	f(x(1))= -67.25
# f-=( 1.0 , 1.5 , -67.5 )	f(x(2))= -67.25
# fmin= -67.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -67.5 )
# For Z
# f=( 1.0 , 2.0 , -67.5 )	f(x(0))= -67.5
# f+=( 1.0 , 2.0 , -67.0 )	f(x(1))= -67.0
# f-=( 1.0 , 2.0 , -68.0 )	f(x(2))= -68.0
# fmin= -68.0
# min lies in ( 1.0 , 2.0 , -68.0 )
# f(x( 16 ))<f(x( 15 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -76.0 )
#
# iteration no. : 17
# For X
# f=( 1.0 , 2.0 , -76.0 )	f(x(0))= -76.0
# f+=( 1.5 , 2.0 , -76.0 )	f(x(1))= -75.75
# f-=( 0.5 , 2.0 , -76.0 )	f(x(2))= -75.75
# fmin= -76.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -76.0 )
# For Y
# f=( 1.0 , 2.0 , -76.0 )	f(x(0))= -76.0
# f+=( 1.0 , 2.5 , -76.0 )	f(x(1))= -75.75
# f-=( 1.0 , 1.5 , -76.0 )	f(x(2))= -75.75
# fmin= -76.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -76.0 )
# For Z
# f=( 1.0 , 2.0 , -76.0 )	f(x(0))= -76.0
# f+=( 1.0 , 2.0 , -75.5 )	f(x(1))= -75.5
# f-=( 1.0 , 2.0 , -76.5 )	f(x(2))= -76.5
# fmin= -76.5
# min lies in ( 1.0 , 2.0 , -76.5 )
# f(x( 17 ))<f(x( 16 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -85.0 )
#
# iteration no. : 18
# For X
# f=( 1.0 , 2.0 , -85.0 )	f(x(0))= -85.0
# f+=( 1.5 , 2.0 , -85.0 )	f(x(1))= -84.75
# f-=( 0.5 , 2.0 , -85.0 )	f(x(2))= -84.75
# fmin= -85.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -85.0 )
# For Y
# f=( 1.0 , 2.0 , -85.0 )	f(x(0))= -85.0
# f+=( 1.0 , 2.5 , -85.0 )	f(x(1))= -84.75
# f-=( 1.0 , 1.5 , -85.0 )	f(x(2))= -84.75
# fmin= -85.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -85.0 )
# For Z
# f=( 1.0 , 2.0 , -85.0 )	f(x(0))= -85.0
# f+=( 1.0 , 2.0 , -84.5 )	f(x(1))= -84.5
# f-=( 1.0 , 2.0 , -85.5 )	f(x(2))= -85.5
# fmin= -85.5
# min lies in ( 1.0 , 2.0 , -85.5 )
# f(x( 18 ))<f(x( 17 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -94.5 )
#
# iteration no. : 19
# For X
# f=( 1.0 , 2.0 , -94.5 )	f(x(0))= -94.5
# f+=( 1.5 , 2.0 , -94.5 )	f(x(1))= -94.25
# f-=( 0.5 , 2.0 , -94.5 )	f(x(2))= -94.25
# fmin= -94.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -94.5 )
# For Y
# f=( 1.0 , 2.0 , -94.5 )	f(x(0))= -94.5
# f+=( 1.0 , 2.5 , -94.5 )	f(x(1))= -94.25
# f-=( 1.0 , 1.5 , -94.5 )	f(x(2))= -94.25
# fmin= -94.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -94.5 )
# For Z
# f=( 1.0 , 2.0 , -94.5 )	f(x(0))= -94.5
# f+=( 1.0 , 2.0 , -94.0 )	f(x(1))= -94.0
# f-=( 1.0 , 2.0 , -95.0 )	f(x(2))= -95.0
# fmin= -95.0
# min lies in ( 1.0 , 2.0 , -95.0 )
# f(x( 19 ))<f(x( 18 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -104.5 )
#
# iteration no. : 20
# For X
# f=( 1.0 , 2.0 , -104.5 )	f(x(0))= -104.5
# f+=( 1.5 , 2.0 , -104.5 )	f(x(1))= -104.25
# f-=( 0.5 , 2.0 , -104.5 )	f(x(2))= -104.25
# fmin= -104.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -104.5 )
# For Y
# f=( 1.0 , 2.0 , -104.5 )	f(x(0))= -104.5
# f+=( 1.0 , 2.5 , -104.5 )	f(x(1))= -104.25
# f-=( 1.0 , 1.5 , -104.5 )	f(x(2))= -104.25
# fmin= -104.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -104.5 )
# For Z
# f=( 1.0 , 2.0 , -104.5 )	f(x(0))= -104.5
# f+=( 1.0 , 2.0 , -104.0 )	f(x(1))= -104.0
# f-=( 1.0 , 2.0 , -105.0 )	f(x(2))= -105.0
# fmin= -105.0
# min lies in ( 1.0 , 2.0 , -105.0 )
# f(x( 20 ))<f(x( 19 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -115.0 )
#
# iteration no. : 21
# For X
# f=( 1.0 , 2.0 , -115.0 )	f(x(0))= -115.0
# f+=( 1.5 , 2.0 , -115.0 )	f(x(1))= -114.75
# f-=( 0.5 , 2.0 , -115.0 )	f(x(2))= -114.75
# fmin= -115.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -115.0 )
# For Y
# f=( 1.0 , 2.0 , -115.0 )	f(x(0))= -115.0
# f+=( 1.0 , 2.5 , -115.0 )	f(x(1))= -114.75
# f-=( 1.0 , 1.5 , -115.0 )	f(x(2))= -114.75
# fmin= -115.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -115.0 )
# For Z
# f=( 1.0 , 2.0 , -115.0 )	f(x(0))= -115.0
# f+=( 1.0 , 2.0 , -114.5 )	f(x(1))= -114.5
# f-=( 1.0 , 2.0 , -115.5 )	f(x(2))= -115.5
# fmin= -115.5
# min lies in ( 1.0 , 2.0 , -115.5 )
# f(x( 21 ))<f(x( 20 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -126.0 )
#
# iteration no. : 22
# For X
# f=( 1.0 , 2.0 , -126.0 )	f(x(0))= -126.0
# f+=( 1.5 , 2.0 , -126.0 )	f(x(1))= -125.75
# f-=( 0.5 , 2.0 , -126.0 )	f(x(2))= -125.75
# fmin= -126.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -126.0 )
# For Y
# f=( 1.0 , 2.0 , -126.0 )	f(x(0))= -126.0
# f+=( 1.0 , 2.5 , -126.0 )	f(x(1))= -125.75
# f-=( 1.0 , 1.5 , -126.0 )	f(x(2))= -125.75
# fmin= -126.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -126.0 )
# For Z
# f=( 1.0 , 2.0 , -126.0 )	f(x(0))= -126.0
# f+=( 1.0 , 2.0 , -125.5 )	f(x(1))= -125.5
# f-=( 1.0 , 2.0 , -126.5 )	f(x(2))= -126.5
# fmin= -126.5
# min lies in ( 1.0 , 2.0 , -126.5 )
# f(x( 22 ))<f(x( 21 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -137.5 )
#
# iteration no. : 23
# For X
# f=( 1.0 , 2.0 , -137.5 )	f(x(0))= -137.5
# f+=( 1.5 , 2.0 , -137.5 )	f(x(1))= -137.25
# f-=( 0.5 , 2.0 , -137.5 )	f(x(2))= -137.25
# fmin= -137.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -137.5 )
# For Y
# f=( 1.0 , 2.0 , -137.5 )	f(x(0))= -137.5
# f+=( 1.0 , 2.5 , -137.5 )	f(x(1))= -137.25
# f-=( 1.0 , 1.5 , -137.5 )	f(x(2))= -137.25
# fmin= -137.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -137.5 )
# For Z
# f=( 1.0 , 2.0 , -137.5 )	f(x(0))= -137.5
# f+=( 1.0 , 2.0 , -137.0 )	f(x(1))= -137.0
# f-=( 1.0 , 2.0 , -138.0 )	f(x(2))= -138.0
# fmin= -138.0
# min lies in ( 1.0 , 2.0 , -138.0 )
# f(x( 23 ))<f(x( 22 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -149.5 )
#
# iteration no. : 24
# For X
# f=( 1.0 , 2.0 , -149.5 )	f(x(0))= -149.5
# f+=( 1.5 , 2.0 , -149.5 )	f(x(1))= -149.25
# f-=( 0.5 , 2.0 , -149.5 )	f(x(2))= -149.25
# fmin= -149.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -149.5 )
# For Y
# f=( 1.0 , 2.0 , -149.5 )	f(x(0))= -149.5
# f+=( 1.0 , 2.5 , -149.5 )	f(x(1))= -149.25
# f-=( 1.0 , 1.5 , -149.5 )	f(x(2))= -149.25
# fmin= -149.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -149.5 )
# For Z
# f=( 1.0 , 2.0 , -149.5 )	f(x(0))= -149.5
# f+=( 1.0 , 2.0 , -149.0 )	f(x(1))= -149.0
# f-=( 1.0 , 2.0 , -150.0 )	f(x(2))= -150.0
# fmin= -150.0
# min lies in ( 1.0 , 2.0 , -150.0 )
# f(x( 24 ))<f(x( 23 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -162.0 )
#
# iteration no. : 25
# For X
# f=( 1.0 , 2.0 , -162.0 )	f(x(0))= -162.0
# f+=( 1.5 , 2.0 , -162.0 )	f(x(1))= -161.75
# f-=( 0.5 , 2.0 , -162.0 )	f(x(2))= -161.75
# fmin= -162.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -162.0 )
# For Y
# f=( 1.0 , 2.0 , -162.0 )	f(x(0))= -162.0
# f+=( 1.0 , 2.5 , -162.0 )	f(x(1))= -161.75
# f-=( 1.0 , 1.5 , -162.0 )	f(x(2))= -161.75
# fmin= -162.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -162.0 )
# For Z
# f=( 1.0 , 2.0 , -162.0 )	f(x(0))= -162.0
# f+=( 1.0 , 2.0 , -161.5 )	f(x(1))= -161.5
# f-=( 1.0 , 2.0 , -162.5 )	f(x(2))= -162.5
# fmin= -162.5
# min lies in ( 1.0 , 2.0 , -162.5 )
# f(x( 25 ))<f(x( 24 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -175.0 )
# iteration no. : 26
# For X
# f=( 1.0 , 2.0 , -175.0 )	f(x(0))= -175.0
# f+=( 1.5 , 2.0 , -175.0 )	f(x(1))= -174.75
# f-=( 0.5 , 2.0 , -175.0 )	f(x(2))= -174.75
# fmin= -175.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -175.0 )
# For Y
# f=( 1.0 , 2.0 , -175.0 )	f(x(0))= -175.0
# f+=( 1.0 , 2.5 , -175.0 )	f(x(1))= -174.75
# f-=( 1.0 , 1.5 , -175.0 )	f(x(2))= -174.75
# fmin= -175.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -175.0 )
# For Z
# f=( 1.0 , 2.0 , -175.0 )	f(x(0))= -175.0
# f+=( 1.0 , 2.0 , -174.5 )	f(x(1))= -174.5
# f-=( 1.0 , 2.0 , -175.5 )	f(x(2))= -175.5
# fmin= -175.5
# min lies in ( 1.0 , 2.0 , -175.5 )
# f(x( 26 ))<f(x( 25 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -188.5 )
#
# iteration no. : 27
# For X
# f=( 1.0 , 2.0 , -188.5 )	f(x(0))= -188.5
# f+=( 1.5 , 2.0 , -188.5 )	f(x(1))= -188.25
# f-=( 0.5 , 2.0 , -188.5 )	f(x(2))= -188.25
# fmin= -188.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -188.5 )
# For Y
# f=( 1.0 , 2.0 , -188.5 )	f(x(0))= -188.5
# f+=( 1.0 , 2.5 , -188.5 )	f(x(1))= -188.25
# f-=( 1.0 , 1.5 , -188.5 )	f(x(2))= -188.25
# fmin= -188.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -188.5 )
# For Z
# f=( 1.0 , 2.0 , -188.5 )	f(x(0))= -188.5
# f+=( 1.0 , 2.0 , -188.0 )	f(x(1))= -188.0
# f-=( 1.0 , 2.0 , -189.0 )	f(x(2))= -189.0
# fmin= -189.0
# min lies in ( 1.0 , 2.0 , -189.0 )
# f(x( 27 ))<f(x( 26 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -202.5 )
#
# iteration no. : 28
# For X
# f=( 1.0 , 2.0 , -202.5 )	f(x(0))= -202.5
# f+=( 1.5 , 2.0 , -202.5 )	f(x(1))= -202.25
# f-=( 0.5 , 2.0 , -202.5 )	f(x(2))= -202.25
# fmin= -202.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -202.5 )
# For Y
# f=( 1.0 , 2.0 , -202.5 )	f(x(0))= -202.5
# f+=( 1.0 , 2.5 , -202.5 )	f(x(1))= -202.25
# f-=( 1.0 , 1.5 , -202.5 )	f(x(2))= -202.25
# fmin= -202.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -202.5 )
# For Z
# f=( 1.0 , 2.0 , -202.5 )	f(x(0))= -202.5
# f+=( 1.0 , 2.0 , -202.0 )	f(x(1))= -202.0
# f-=( 1.0 , 2.0 , -203.0 )	f(x(2))= -203.0
# fmin= -203.0
# min lies in ( 1.0 , 2.0 , -203.0 )
# f(x( 28 ))<f(x( 27 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -217.0 )
#
# iteration no. : 29
# For X
# f=( 1.0 , 2.0 , -217.0 )	f(x(0))= -217.0
# f+=( 1.5 , 2.0 , -217.0 )	f(x(1))= -216.75
# f-=( 0.5 , 2.0 , -217.0 )	f(x(2))= -216.75
# fmin= -217.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -217.0 )
# For Y
# f=( 1.0 , 2.0 , -217.0 )	f(x(0))= -217.0
# f+=( 1.0 , 2.5 , -217.0 )	f(x(1))= -216.75
# f-=( 1.0 , 1.5 , -217.0 )	f(x(2))= -216.75
# fmin= -217.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -217.0 )
# For Z
# f=( 1.0 , 2.0 , -217.0 )	f(x(0))= -217.0
# f+=( 1.0 , 2.0 , -216.5 )	f(x(1))= -216.5
# f-=( 1.0 , 2.0 , -217.5 )	f(x(2))= -217.5
# fmin= -217.5
# min lies in ( 1.0 , 2.0 , -217.5 )
# f(x( 29 ))<f(x( 28 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -232.0 )
#
# iteration no. : 30
# For X
# f=( 1.0 , 2.0 , -232.0 )	f(x(0))= -232.0
# f+=( 1.5 , 2.0 , -232.0 )	f(x(1))= -231.75
# f-=( 0.5 , 2.0 , -232.0 )	f(x(2))= -231.75
# fmin= -232.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -232.0 )
# For Y
# f=( 1.0 , 2.0 , -232.0 )	f(x(0))= -232.0
# f+=( 1.0 , 2.5 , -232.0 )	f(x(1))= -231.75
# f-=( 1.0 , 1.5 , -232.0 )	f(x(2))= -231.75
# fmin= -232.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -232.0 )
# For Z
# f=( 1.0 , 2.0 , -232.0 )	f(x(0))= -232.0
# f+=( 1.0 , 2.0 , -231.5 )	f(x(1))= -231.5
# f-=( 1.0 , 2.0 , -232.5 )	f(x(2))= -232.5
# fmin= -232.5
# min lies in ( 1.0 , 2.0 , -232.5 )
# f(x( 30 ))<f(x( 29 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -247.5 )
#
# iteration no. : 31
# For X
# f=( 1.0 , 2.0 , -247.5 )	f(x(0))= -247.5
# f+=( 1.5 , 2.0 , -247.5 )	f(x(1))= -247.25
# f-=( 0.5 , 2.0 , -247.5 )	f(x(2))= -247.25
# fmin= -247.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -247.5 )
# For Y
# f=( 1.0 , 2.0 , -247.5 )	f(x(0))= -247.5
# f+=( 1.0 , 2.5 , -247.5 )	f(x(1))= -247.25
# f-=( 1.0 , 1.5 , -247.5 )	f(x(2))= -247.25
# fmin= -247.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -247.5 )
# For Z
# f=( 1.0 , 2.0 , -247.5 )	f(x(0))= -247.5
# f+=( 1.0 , 2.0 , -247.0 )	f(x(1))= -247.0
# f-=( 1.0 , 2.0 , -248.0 )	f(x(2))= -248.0
# fmin= -248.0
# min lies in ( 1.0 , 2.0 , -248.0 )
# f(x( 31 ))<f(x( 30 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -263.5 )
#
# iteration no. : 32
# For X
# f=( 1.0 , 2.0 , -263.5 )	f(x(0))= -263.5
# f+=( 1.5 , 2.0 , -263.5 )	f(x(1))= -263.25
# f-=( 0.5 , 2.0 , -263.5 )	f(x(2))= -263.25
# fmin= -263.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -263.5 )
# For Y
# f=( 1.0 , 2.0 , -263.5 )	f(x(0))= -263.5
# f+=( 1.0 , 2.5 , -263.5 )	f(x(1))= -263.25
# f-=( 1.0 , 1.5 , -263.5 )	f(x(2))= -263.25
# fmin= -263.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -263.5 )
# For Z
# f=( 1.0 , 2.0 , -263.5 )	f(x(0))= -263.5
# f+=( 1.0 , 2.0 , -263.0 )	f(x(1))= -263.0
# f-=( 1.0 , 2.0 , -264.0 )	f(x(2))= -264.0
# fmin= -264.0
# min lies in ( 1.0 , 2.0 , -264.0 )
# f(x( 32 ))<f(x( 31 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -280.0 )
#
# iteration no. : 33
# For X
# f=( 1.0 , 2.0 , -280.0 )	f(x(0))= -280.0
# f+=( 1.5 , 2.0 , -280.0 )	f(x(1))= -279.75
# f-=( 0.5 , 2.0 , -280.0 )	f(x(2))= -279.75
# fmin= -280.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -280.0 )
# For Y
# f=( 1.0 , 2.0 , -280.0 )	f(x(0))= -280.0
# f+=( 1.0 , 2.5 , -280.0 )	f(x(1))= -279.75
# f-=( 1.0 , 1.5 , -280.0 )	f(x(2))= -279.75
# fmin= -280.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -280.0 )
# For Z
# f=( 1.0 , 2.0 , -280.0 )	f(x(0))= -280.0
# f+=( 1.0 , 2.0 , -279.5 )	f(x(1))= -279.5
# f-=( 1.0 , 2.0 , -280.5 )	f(x(2))= -280.5
# fmin= -280.5
# min lies in ( 1.0 , 2.0 , -280.5 )
# f(x( 33 ))<f(x( 32 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -297.0 )
#
# iteration no. : 34
# For X
# f=( 1.0 , 2.0 , -297.0 )	f(x(0))= -297.0
# f+=( 1.5 , 2.0 , -297.0 )	f(x(1))= -296.75
# f-=( 0.5 , 2.0 , -297.0 )	f(x(2))= -296.75
# fmin= -297.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -297.0 )
# For Y
# f=( 1.0 , 2.0 , -297.0 )	f(x(0))= -297.0
# f+=( 1.0 , 2.5 , -297.0 )	f(x(1))= -296.75
# f-=( 1.0 , 1.5 , -297.0 )	f(x(2))= -296.75
# fmin= -297.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -297.0 )
# For Z
# f=( 1.0 , 2.0 , -297.0 )	f(x(0))= -297.0
# f+=( 1.0 , 2.0 , -296.5 )	f(x(1))= -296.5
# f-=( 1.0 , 2.0 , -297.5 )	f(x(2))= -297.5
# fmin= -297.5
# min lies in ( 1.0 , 2.0 , -297.5 )
# f(x( 34 ))<f(x( 33 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -314.5 )
#
# iteration no. : 35
# For X
# f=( 1.0 , 2.0 , -314.5 )	f(x(0))= -314.5
# f+=( 1.5 , 2.0 , -314.5 )	f(x(1))= -314.25
# f-=( 0.5 , 2.0 , -314.5 )	f(x(2))= -314.25
# fmin= -314.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -314.5 )
# For Y
# f=( 1.0 , 2.0 , -314.5 )	f(x(0))= -314.5
# f+=( 1.0 , 2.5 , -314.5 )	f(x(1))= -314.25
# f-=( 1.0 , 1.5 , -314.5 )	f(x(2))= -314.25
# fmin= -314.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -314.5 )
# For Z
# f=( 1.0 , 2.0 , -314.5 )	f(x(0))= -314.5
# f+=( 1.0 , 2.0 , -314.0 )	f(x(1))= -314.0
# f-=( 1.0 , 2.0 , -315.0 )	f(x(2))= -315.0
# fmin= -315.0
# min lies in ( 1.0 , 2.0 , -315.0 )
# f(x( 35 ))<f(x( 34 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -332.5 )
#
# iteration no. : 36
# For X
# f=( 1.0 , 2.0 , -332.5 )	f(x(0))= -332.5
# f+=( 1.5 , 2.0 , -332.5 )	f(x(1))= -332.25
# f-=( 0.5 , 2.0 , -332.5 )	f(x(2))= -332.25
# fmin= -332.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -332.5 )
# For Y
# f=( 1.0 , 2.0 , -332.5 )	f(x(0))= -332.5
# f+=( 1.0 , 2.5 , -332.5 )	f(x(1))= -332.25
# f-=( 1.0 , 1.5 , -332.5 )	f(x(2))= -332.25
# fmin= -332.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -332.5 )
# For Z
# f=( 1.0 , 2.0 , -332.5 )	f(x(0))= -332.5
# f+=( 1.0 , 2.0 , -332.0 )	f(x(1))= -332.0
# f-=( 1.0 , 2.0 , -333.0 )	f(x(2))= -333.0
# fmin= -333.0
# min lies in ( 1.0 , 2.0 , -333.0 )
# f(x( 36 ))<f(x( 35 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -351.0 )
#
# iteration no. : 37
# For X
# f=( 1.0 , 2.0 , -351.0 )	f(x(0))= -351.0
# f+=( 1.5 , 2.0 , -351.0 )	f(x(1))= -350.75
# f-=( 0.5 , 2.0 , -351.0 )	f(x(2))= -350.75
# fmin= -351.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -351.0 )
# For Y
# f=( 1.0 , 2.0 , -351.0 )	f(x(0))= -351.0
# f+=( 1.0 , 2.5 , -351.0 )	f(x(1))= -350.75
# f-=( 1.0 , 1.5 , -351.0 )	f(x(2))= -350.75
# fmin= -351.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -351.0 )
# For Z
# f=( 1.0 , 2.0 , -351.0 )	f(x(0))= -351.0
# f+=( 1.0 , 2.0 , -350.5 )	f(x(1))= -350.5
# f-=( 1.0 , 2.0 , -351.5 )	f(x(2))= -351.5
# fmin= -351.5
# min lies in ( 1.0 , 2.0 , -351.5 )
# f(x( 37 ))<f(x( 36 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -370.0 )
#
# iteration no. : 38
# For X
# f=( 1.0 , 2.0 , -370.0 )	f(x(0))= -370.0
# f+=( 1.5 , 2.0 , -370.0 )	f(x(1))= -369.75
# f-=( 0.5 , 2.0 , -370.0 )	f(x(2))= -369.75
# fmin= -370.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -370.0 )
# For Y
# f=( 1.0 , 2.0 , -370.0 )	f(x(0))= -370.0
# f+=( 1.0 , 2.5 , -370.0 )	f(x(1))= -369.75
# f-=( 1.0 , 1.5 , -370.0 )	f(x(2))= -369.75
# fmin= -370.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -370.0 )
# For Z
# f=( 1.0 , 2.0 , -370.0 )	f(x(0))= -370.0
# f+=( 1.0 , 2.0 , -369.5 )	f(x(1))= -369.5
# f-=( 1.0 , 2.0 , -370.5 )	f(x(2))= -370.5
# fmin= -370.5
# min lies in ( 1.0 , 2.0 , -370.5 )
# f(x( 38 ))<f(x( 37 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -389.5 )
#
# iteration no. : 39
# For X
# f=( 1.0 , 2.0 , -389.5 )	f(x(0))= -389.5
# f+=( 1.5 , 2.0 , -389.5 )	f(x(1))= -389.25
# f-=( 0.5 , 2.0 , -389.5 )	f(x(2))= -389.25
# fmin= -389.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -389.5 )
# For Y
# f=( 1.0 , 2.0 , -389.5 )	f(x(0))= -389.5
# f+=( 1.0 , 2.5 , -389.5 )	f(x(1))= -389.25
# f-=( 1.0 , 1.5 , -389.5 )	f(x(2))= -389.25
# fmin= -389.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -389.5 )
# For Z
# f=( 1.0 , 2.0 , -389.5 )	f(x(0))= -389.5
# f+=( 1.0 , 2.0 , -389.0 )	f(x(1))= -389.0
# f-=( 1.0 , 2.0 , -390.0 )	f(x(2))= -390.0
# fmin= -390.0
# min lies in ( 1.0 , 2.0 , -390.0 )
# f(x( 39 ))<f(x( 38 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -409.5 )
#
# iteration no. : 40
# For X
# f=( 1.0 , 2.0 , -409.5 )	f(x(0))= -409.5
# f+=( 1.5 , 2.0 , -409.5 )	f(x(1))= -409.25
# f-=( 0.5 , 2.0 , -409.5 )	f(x(2))= -409.25
# fmin= -409.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -409.5 )
# For Y
# f=( 1.0 , 2.0 , -409.5 )	f(x(0))= -409.5
# f+=( 1.0 , 2.5 , -409.5 )	f(x(1))= -409.25
# f-=( 1.0 , 1.5 , -409.5 )	f(x(2))= -409.25
# fmin= -409.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -409.5 )
# For Z
# f=( 1.0 , 2.0 , -409.5 )	f(x(0))= -409.5
# f+=( 1.0 , 2.0 , -409.0 )	f(x(1))= -409.0
# f-=( 1.0 , 2.0 , -410.0 )	f(x(2))= -410.0
# fmin= -410.0
# min lies in ( 1.0 , 2.0 , -410.0 )
# f(x( 40 ))<f(x( 39 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -430.0 )
#
# iteration no. : 41
# For X
# f=( 1.0 , 2.0 , -430.0 )	f(x(0))= -430.0
# f+=( 1.5 , 2.0 , -430.0 )	f(x(1))= -429.75
# f-=( 0.5 , 2.0 , -430.0 )	f(x(2))= -429.75
# fmin= -430.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -430.0 )
# For Y
# f=( 1.0 , 2.0 , -430.0 )	f(x(0))= -430.0
# f+=( 1.0 , 2.5 , -430.0 )	f(x(1))= -429.75
# f-=( 1.0 , 1.5 , -430.0 )	f(x(2))= -429.75
# fmin= -430.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -430.0 )
# For Z
# f=( 1.0 , 2.0 , -430.0 )	f(x(0))= -430.0
# f+=( 1.0 , 2.0 , -429.5 )	f(x(1))= -429.5
# f-=( 1.0 , 2.0 , -430.5 )	f(x(2))= -430.5
# fmin= -430.5
# min lies in ( 1.0 , 2.0 , -430.5 )
# f(x( 41 ))<f(x( 40 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -451.0 )
#
# iteration no. : 42
# For X
# f=( 1.0 , 2.0 , -451.0 )	f(x(0))= -451.0
# f+=( 1.5 , 2.0 , -451.0 )	f(x(1))= -450.75
# f-=( 0.5 , 2.0 , -451.0 )	f(x(2))= -450.75
# fmin= -451.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -451.0 )
# For Y
# f=( 1.0 , 2.0 , -451.0 )	f(x(0))= -451.0
# f+=( 1.0 , 2.5 , -451.0 )	f(x(1))= -450.75
# f-=( 1.0 , 1.5 , -451.0 )	f(x(2))= -450.75
# fmin= -451.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -451.0 )
# For Z
# f=( 1.0 , 2.0 , -451.0 )	f(x(0))= -451.0
# f+=( 1.0 , 2.0 , -450.5 )	f(x(1))= -450.5
# f-=( 1.0 , 2.0 , -451.5 )	f(x(2))= -451.5
# fmin= -451.5
# min lies in ( 1.0 , 2.0 , -451.5 )
# f(x( 42 ))<f(x( 41 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -472.5 )
#
# iteration no. : 43
# For X
# f=( 1.0 , 2.0 , -472.5 )	f(x(0))= -472.5
# f+=( 1.5 , 2.0 , -472.5 )	f(x(1))= -472.25
# f-=( 0.5 , 2.0 , -472.5 )	f(x(2))= -472.25
# fmin= -472.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -472.5 )
# For Y
# f=( 1.0 , 2.0 , -472.5 )	f(x(0))= -472.5
# f+=( 1.0 , 2.5 , -472.5 )	f(x(1))= -472.25
# f-=( 1.0 , 1.5 , -472.5 )	f(x(2))= -472.25
# fmin= -472.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -472.5 )
# For Z
# f=( 1.0 , 2.0 , -472.5 )	f(x(0))= -472.5
# f+=( 1.0 , 2.0 , -472.0 )	f(x(1))= -472.0
# f-=( 1.0 , 2.0 , -473.0 )	f(x(2))= -473.0
# fmin= -473.0
# min lies in ( 1.0 , 2.0 , -473.0 )
# f(x( 43 ))<f(x( 42 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -494.5 )
#
# iteration no. : 44
# For X
# f=( 1.0 , 2.0 , -494.5 )	f(x(0))= -494.5
# f+=( 1.5 , 2.0 , -494.5 )	f(x(1))= -494.25
# f-=( 0.5 , 2.0 , -494.5 )	f(x(2))= -494.25
# fmin= -494.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -494.5 )
# For Y
# f=( 1.0 , 2.0 , -494.5 )	f(x(0))= -494.5
# f+=( 1.0 , 2.5 , -494.5 )	f(x(1))= -494.25
# f-=( 1.0 , 1.5 , -494.5 )	f(x(2))= -494.25
# fmin= -494.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -494.5 )
# For Z
# f=( 1.0 , 2.0 , -494.5 )	f(x(0))= -494.5
# f+=( 1.0 , 2.0 , -494.0 )	f(x(1))= -494.0
# f-=( 1.0 , 2.0 , -495.0 )	f(x(2))= -495.0
# fmin= -495.0
# min lies in ( 1.0 , 2.0 , -495.0 )
# f(x( 44 ))<f(x( 43 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -517.0 )
#
# iteration no. : 45
# For X
# f=( 1.0 , 2.0 , -517.0 )	f(x(0))= -517.0
# f+=( 1.5 , 2.0 , -517.0 )	f(x(1))= -516.75
# f-=( 0.5 , 2.0 , -517.0 )	f(x(2))= -516.75
# fmin= -517.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -517.0 )
# For Y
# f=( 1.0 , 2.0 , -517.0 )	f(x(0))= -517.0
# f+=( 1.0 , 2.5 , -517.0 )	f(x(1))= -516.75
# f-=( 1.0 , 1.5 , -517.0 )	f(x(2))= -516.75
# fmin= -517.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -517.0 )
# For Z
# f=( 1.0 , 2.0 , -517.0 )	f(x(0))= -517.0
# f+=( 1.0 , 2.0 , -516.5 )	f(x(1))= -516.5
# f-=( 1.0 , 2.0 , -517.5 )	f(x(2))= -517.5
# fmin= -517.5
# min lies in ( 1.0 , 2.0 , -517.5 )
# f(x( 45 ))<f(x( 44 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -540.0 )
#
# iteration no. : 46
# For X
# f=( 1.0 , 2.0 , -540.0 )	f(x(0))= -540.0
# f+=( 1.5 , 2.0 , -540.0 )	f(x(1))= -539.75
# f-=( 0.5 , 2.0 , -540.0 )	f(x(2))= -539.75
# fmin= -540.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -540.0 )
# For Y
# f=( 1.0 , 2.0 , -540.0 )	f(x(0))= -540.0
# f+=( 1.0 , 2.5 , -540.0 )	f(x(1))= -539.75
# f-=( 1.0 , 1.5 , -540.0 )	f(x(2))= -539.75
# fmin= -540.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -540.0 )
# For Z
# f=( 1.0 , 2.0 , -540.0 )	f(x(0))= -540.0
# f+=( 1.0 , 2.0 , -539.5 )	f(x(1))= -539.5
# f-=( 1.0 , 2.0 , -540.5 )	f(x(2))= -540.5
# fmin= -540.5
# min lies in ( 1.0 , 2.0 , -540.5 )
# f(x( 46 ))<f(x( 45 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -563.5 )
#
# iteration no. : 47
# For X
# f=( 1.0 , 2.0 , -563.5 )	f(x(0))= -563.5
# f+=( 1.5 , 2.0 , -563.5 )	f(x(1))= -563.25
# f-=( 0.5 , 2.0 , -563.5 )	f(x(2))= -563.25
# fmin= -563.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -563.5 )
# For Y
# f=( 1.0 , 2.0 , -563.5 )	f(x(0))= -563.5
# f+=( 1.0 , 2.5 , -563.5 )	f(x(1))= -563.25
# f-=( 1.0 , 1.5 , -563.5 )	f(x(2))= -563.25
# fmin= -563.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -563.5 )
# For Z
# f=( 1.0 , 2.0 , -563.5 )	f(x(0))= -563.5
# f+=( 1.0 , 2.0 , -563.0 )	f(x(1))= -563.0
# f-=( 1.0 , 2.0 , -564.0 )	f(x(2))= -564.0
# fmin= -564.0
# min lies in ( 1.0 , 2.0 , -564.0 )
# f(x( 47 ))<f(x( 46 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -587.5 )
#
# iteration no. : 48
# For X
# f=( 1.0 , 2.0 , -587.5 )	f(x(0))= -587.5
# f+=( 1.5 , 2.0 , -587.5 )	f(x(1))= -587.25
# f-=( 0.5 , 2.0 , -587.5 )	f(x(2))= -587.25
# fmin= -587.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -587.5 )
# For Y
# f=( 1.0 , 2.0 , -587.5 )	f(x(0))= -587.5
# f+=( 1.0 , 2.5 , -587.5 )	f(x(1))= -587.25
# f-=( 1.0 , 1.5 , -587.5 )	f(x(2))= -587.25
# fmin= -587.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -587.5 )
# For Z
# f=( 1.0 , 2.0 , -587.5 )	f(x(0))= -587.5
# f+=( 1.0 , 2.0 , -587.0 )	f(x(1))= -587.0
# f-=( 1.0 , 2.0 , -588.0 )	f(x(2))= -588.0
# fmin= -588.0
# min lies in ( 1.0 , 2.0 , -588.0 )
# f(x( 48 ))<f(x( 47 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -612.0 )
#
# iteration no. : 49
# For X
# f=( 1.0 , 2.0 , -612.0 )	f(x(0))= -612.0
# f+=( 1.5 , 2.0 , -612.0 )	f(x(1))= -611.75
# f-=( 0.5 , 2.0 , -612.0 )	f(x(2))= -611.75
# fmin= -612.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -612.0 )
# For Y
# f=( 1.0 , 2.0 , -612.0 )	f(x(0))= -612.0
# f+=( 1.0 , 2.5 , -612.0 )	f(x(1))= -611.75
# f-=( 1.0 , 1.5 , -612.0 )	f(x(2))= -611.75
# fmin= -612.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -612.0 )
# For Z
# f=( 1.0 , 2.0 , -612.0 )	f(x(0))= -612.0
# f+=( 1.0 , 2.0 , -611.5 )	f(x(1))= -611.5
# f-=( 1.0 , 2.0 , -612.5 )	f(x(2))= -612.5
# fmin= -612.5
# min lies in ( 1.0 , 2.0 , -612.5 )
# f(x( 49 ))<f(x( 48 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -637.0 )
#
# iteration no. : 50
# For X
# f=( 1.0 , 2.0 , -637.0 )	f(x(0))= -637.0
# f+=( 1.5 , 2.0 , -637.0 )	f(x(1))= -636.75
# f-=( 0.5 , 2.0 , -637.0 )	f(x(2))= -636.75
# fmin= -637.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -637.0 )
# For Y
# f=( 1.0 , 2.0 , -637.0 )	f(x(0))= -637.0
# f+=( 1.0 , 2.5 , -637.0 )	f(x(1))= -636.75
# f-=( 1.0 , 1.5 , -637.0 )	f(x(2))= -636.75
# fmin= -637.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -637.0 )
# For Z
# f=( 1.0 , 2.0 , -637.0 )	f(x(0))= -637.0
# f+=( 1.0 , 2.0 , -636.5 )	f(x(1))= -636.5
# f-=( 1.0 , 2.0 , -637.5 )	f(x(2))= -637.5
# fmin= -637.5
# min lies in ( 1.0 , 2.0 , -637.5 )
# f(x( 50 ))<f(x( 49 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -662.5 )
#
# iteration no. : 51
# For X
# f=( 1.0 , 2.0 , -662.5 )	f(x(0))= -662.5
# f+=( 1.5 , 2.0 , -662.5 )	f(x(1))= -662.25
# f-=( 0.5 , 2.0 , -662.5 )	f(x(2))= -662.25
# fmin= -662.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -662.5 )
# For Y
# f=( 1.0 , 2.0 , -662.5 )	f(x(0))= -662.5
# f+=( 1.0 , 2.5 , -662.5 )	f(x(1))= -662.25
# f-=( 1.0 , 1.5 , -662.5 )	f(x(2))= -662.25
# fmin= -662.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -662.5 )
# For Z
# f=( 1.0 , 2.0 , -662.5 )	f(x(0))= -662.5
# f+=( 1.0 , 2.0 , -662.0 )	f(x(1))= -662.0
# f-=( 1.0 , 2.0 , -663.0 )	f(x(2))= -663.0
# fmin= -663.0
# min lies in ( 1.0 , 2.0 , -663.0 )
# f(x( 51 ))<f(x( 50 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -688.5 )
#
# iteration no. : 52
# For X
# f=( 1.0 , 2.0 , -688.5 )	f(x(0))= -688.5
# f+=( 1.5 , 2.0 , -688.5 )	f(x(1))= -688.25
# f-=( 0.5 , 2.0 , -688.5 )	f(x(2))= -688.25
# fmin= -688.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -688.5 )
# For Y
# f=( 1.0 , 2.0 , -688.5 )	f(x(0))= -688.5
# f+=( 1.0 , 2.5 , -688.5 )	f(x(1))= -688.25
# f-=( 1.0 , 1.5 , -688.5 )	f(x(2))= -688.25
# fmin= -688.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -688.5 )
# For Z
# f=( 1.0 , 2.0 , -688.5 )	f(x(0))= -688.5
# f+=( 1.0 , 2.0 , -688.0 )	f(x(1))= -688.0
# f-=( 1.0 , 2.0 , -689.0 )	f(x(2))= -689.0
# fmin= -689.0
# min lies in ( 1.0 , 2.0 , -689.0 )
# f(x( 52 ))<f(x( 51 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -715.0 )
#
# iteration no. : 53
# For X
# f=( 1.0 , 2.0 , -715.0 )	f(x(0))= -715.0
# f+=( 1.5 , 2.0 , -715.0 )	f(x(1))= -714.75
# f-=( 0.5 , 2.0 , -715.0 )	f(x(2))= -714.75
# fmin= -715.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -715.0 )
# For Y
# f=( 1.0 , 2.0 , -715.0 )	f(x(0))= -715.0
# f+=( 1.0 , 2.5 , -715.0 )	f(x(1))= -714.75
# f-=( 1.0 , 1.5 , -715.0 )	f(x(2))= -714.75
# fmin= -715.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -715.0 )
# For Z
# f=( 1.0 , 2.0 , -715.0 )	f(x(0))= -715.0
# f+=( 1.0 , 2.0 , -714.5 )	f(x(1))= -714.5
# f-=( 1.0 , 2.0 , -715.5 )	f(x(2))= -715.5
# fmin= -715.5
# min lies in ( 1.0 , 2.0 , -715.5 )
# f(x( 53 ))<f(x( 52 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -742.0 )
#
# iteration no. : 54
# For X
# f=( 1.0 , 2.0 , -742.0 )	f(x(0))= -742.0
# f+=( 1.5 , 2.0 , -742.0 )	f(x(1))= -741.75
# f-=( 0.5 , 2.0 , -742.0 )	f(x(2))= -741.75
# fmin= -742.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -742.0 )
# For Y
# f=( 1.0 , 2.0 , -742.0 )	f(x(0))= -742.0
# f+=( 1.0 , 2.5 , -742.0 )	f(x(1))= -741.75
# f-=( 1.0 , 1.5 , -742.0 )	f(x(2))= -741.75
# fmin= -742.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -742.0 )
# For Z
# f=( 1.0 , 2.0 , -742.0 )	f(x(0))= -742.0
# f+=( 1.0 , 2.0 , -741.5 )	f(x(1))= -741.5
# f-=( 1.0 , 2.0 , -742.5 )	f(x(2))= -742.5
# fmin= -742.5
# min lies in ( 1.0 , 2.0 , -742.5 )
# f(x( 54 ))<f(x( 53 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -769.5 )
#
# iteration no. : 55
# For X
# f=( 1.0 , 2.0 , -769.5 )	f(x(0))= -769.5
# f+=( 1.5 , 2.0 , -769.5 )	f(x(1))= -769.25
# f-=( 0.5 , 2.0 , -769.5 )	f(x(2))= -769.25
# fmin= -769.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -769.5 )
# For Y
# f=( 1.0 , 2.0 , -769.5 )	f(x(0))= -769.5
# f+=( 1.0 , 2.5 , -769.5 )	f(x(1))= -769.25
# f-=( 1.0 , 1.5 , -769.5 )	f(x(2))= -769.25
# fmin= -769.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -769.5 )
# For Z
# f=( 1.0 , 2.0 , -769.5 )	f(x(0))= -769.5
# f+=( 1.0 , 2.0 , -769.0 )	f(x(1))= -769.0
# f-=( 1.0 , 2.0 , -770.0 )	f(x(2))= -770.0
# fmin= -770.0
# min lies in ( 1.0 , 2.0 , -770.0 )
# f(x( 55 ))<f(x( 54 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -797.5 )
#
# iteration no. : 56
# For X
# f=( 1.0 , 2.0 , -797.5 )	f(x(0))= -797.5
# f+=( 1.5 , 2.0 , -797.5 )	f(x(1))= -797.25
# f-=( 0.5 , 2.0 , -797.5 )	f(x(2))= -797.25
# fmin= -797.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -797.5 )
# For Y
# f=( 1.0 , 2.0 , -797.5 )	f(x(0))= -797.5
# f+=( 1.0 , 2.5 , -797.5 )	f(x(1))= -797.25
# f-=( 1.0 , 1.5 , -797.5 )	f(x(2))= -797.25
# fmin= -797.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -797.5 )
# For Z
# f=( 1.0 , 2.0 , -797.5 )	f(x(0))= -797.5
# f+=( 1.0 , 2.0 , -797.0 )	f(x(1))= -797.0
# f-=( 1.0 , 2.0 , -798.0 )	f(x(2))= -798.0
# fmin= -798.0
# min lies in ( 1.0 , 2.0 , -798.0 )
# f(x( 56 ))<f(x( 55 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -826.0 )
#
# iteration no. : 57
# For X
# f=( 1.0 , 2.0 , -826.0 )	f(x(0))= -826.0
# f+=( 1.5 , 2.0 , -826.0 )	f(x(1))= -825.75
# f-=( 0.5 , 2.0 , -826.0 )	f(x(2))= -825.75
# fmin= -826.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -826.0 )
# For Y
# f=( 1.0 , 2.0 , -826.0 )	f(x(0))= -826.0
# f+=( 1.0 , 2.5 , -826.0 )	f(x(1))= -825.75
# f-=( 1.0 , 1.5 , -826.0 )	f(x(2))= -825.75
# fmin= -826.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -826.0 )
# For Z
# f=( 1.0 , 2.0 , -826.0 )	f(x(0))= -826.0
# f+=( 1.0 , 2.0 , -825.5 )	f(x(1))= -825.5
# f-=( 1.0 , 2.0 , -826.5 )	f(x(2))= -826.5
# fmin= -826.5
# min lies in ( 1.0 , 2.0 , -826.5 )
# f(x( 57 ))<f(x( 56 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -855.0 )
#
# iteration no. : 58
# For X
# f=( 1.0 , 2.0 , -855.0 )	f(x(0))= -855.0
# f+=( 1.5 , 2.0 , -855.0 )	f(x(1))= -854.75
# f-=( 0.5 , 2.0 , -855.0 )	f(x(2))= -854.75
# fmin= -855.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -855.0 )
# For Y
# f=( 1.0 , 2.0 , -855.0 )	f(x(0))= -855.0
# f+=( 1.0 , 2.5 , -855.0 )	f(x(1))= -854.75
# f-=( 1.0 , 1.5 , -855.0 )	f(x(2))= -854.75
# fmin= -855.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -855.0 )
# For Z
# f=( 1.0 , 2.0 , -855.0 )	f(x(0))= -855.0
# f+=( 1.0 , 2.0 , -854.5 )	f(x(1))= -854.5
# f-=( 1.0 , 2.0 , -855.5 )	f(x(2))= -855.5
# fmin= -855.5
# min lies in ( 1.0 , 2.0 , -855.5 )
# f(x( 58 ))<f(x( 57 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -884.5 )
#
# iteration no. : 59
# For X
# f=( 1.0 , 2.0 , -884.5 )	f(x(0))= -884.5
# f+=( 1.5 , 2.0 , -884.5 )	f(x(1))= -884.25
# f-=( 0.5 , 2.0 , -884.5 )	f(x(2))= -884.25
# fmin= -884.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -884.5 )
# For Y
# f=( 1.0 , 2.0 , -884.5 )	f(x(0))= -884.5
# f+=( 1.0 , 2.5 , -884.5 )	f(x(1))= -884.25
# f-=( 1.0 , 1.5 , -884.5 )	f(x(2))= -884.25
# fmin= -884.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -884.5 )
# For Z
# f=( 1.0 , 2.0 , -884.5 )	f(x(0))= -884.5
# f+=( 1.0 , 2.0 , -884.0 )	f(x(1))= -884.0
# f-=( 1.0 , 2.0 , -885.0 )	f(x(2))= -885.0
# fmin= -885.0
# min lies in ( 1.0 , 2.0 , -885.0 )
# f(x( 59 ))<f(x( 58 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -914.5 )
#
# iteration no. : 60
# For X
# f=( 1.0 , 2.0 , -914.5 )	f(x(0))= -914.5
# f+=( 1.5 , 2.0 , -914.5 )	f(x(1))= -914.25
# f-=( 0.5 , 2.0 , -914.5 )	f(x(2))= -914.25
# fmin= -914.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -914.5 )
# For Y
# f=( 1.0 , 2.0 , -914.5 )	f(x(0))= -914.5
# f+=( 1.0 , 2.5 , -914.5 )	f(x(1))= -914.25
# f-=( 1.0 , 1.5 , -914.5 )	f(x(2))= -914.25
# fmin= -914.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -914.5 )
# For Z
# f=( 1.0 , 2.0 , -914.5 )	f(x(0))= -914.5
# f+=( 1.0 , 2.0 , -914.0 )	f(x(1))= -914.0
# f-=( 1.0 , 2.0 , -915.0 )	f(x(2))= -915.0
# fmin= -915.0
# min lies in ( 1.0 , 2.0 , -915.0 )
# f(x( 60 ))<f(x( 59 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -945.0 )
#
# iteration no. : 61
# For X
# f=( 1.0 , 2.0 , -945.0 )	f(x(0))= -945.0
# f+=( 1.5 , 2.0 , -945.0 )	f(x(1))= -944.75
# f-=( 0.5 , 2.0 , -945.0 )	f(x(2))= -944.75
# fmin= -945.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -945.0 )
# For Y
# f=( 1.0 , 2.0 , -945.0 )	f(x(0))= -945.0
# f+=( 1.0 , 2.5 , -945.0 )	f(x(1))= -944.75
# f-=( 1.0 , 1.5 , -945.0 )	f(x(2))= -944.75
# fmin= -945.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -945.0 )
# For Z
# f=( 1.0 , 2.0 , -945.0 )	f(x(0))= -945.0
# f+=( 1.0 , 2.0 , -944.5 )	f(x(1))= -944.5
# f-=( 1.0 , 2.0 , -945.5 )	f(x(2))= -945.5
# fmin= -945.5
# min lies in ( 1.0 , 2.0 , -945.5 )
# f(x( 61 ))<f(x( 60 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -976.0 )
#
# iteration no. : 62
# For X
# f=( 1.0 , 2.0 , -976.0 )	f(x(0))= -976.0
# f+=( 1.5 , 2.0 , -976.0 )	f(x(1))= -975.75
# f-=( 0.5 , 2.0 , -976.0 )	f(x(2))= -975.75
# fmin= -976.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -976.0 )
# For Y
# f=( 1.0 , 2.0 , -976.0 )	f(x(0))= -976.0
# f+=( 1.0 , 2.5 , -976.0 )	f(x(1))= -975.75
# f-=( 1.0 , 1.5 , -976.0 )	f(x(2))= -975.75
# fmin= -976.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -976.0 )
# For Z
# f=( 1.0 , 2.0 , -976.0 )	f(x(0))= -976.0
# f+=( 1.0 , 2.0 , -975.5 )	f(x(1))= -975.5
# f-=( 1.0 , 2.0 , -976.5 )	f(x(2))= -976.5
# fmin= -976.5
# min lies in ( 1.0 , 2.0 , -976.5 )
# f(x( 62 ))<f(x( 61 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -1007.5 )
#
# iteration no. : 63
# For X
# f=( 1.0 , 2.0 , -1007.5 )	f(x(0))= -1007.5
# f+=( 1.5 , 2.0 , -1007.5 )	f(x(1))= -1007.25
# f-=( 0.5 , 2.0 , -1007.5 )	f(x(2))= -1007.25
# fmin= -1007.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -1007.5 )
# For Y
# f=( 1.0 , 2.0 , -1007.5 )	f(x(0))= -1007.5
# f+=( 1.0 , 2.5 , -1007.5 )	f(x(1))= -1007.25
# f-=( 1.0 , 1.5 , -1007.5 )	f(x(2))= -1007.25
# fmin= -1007.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -1007.5 )
# For Z
# f=( 1.0 , 2.0 , -1007.5 )	f(x(0))= -1007.5
# f+=( 1.0 , 2.0 , -1007.0 )	f(x(1))= -1007.0
# f-=( 1.0 , 2.0 , -1008.0 )	f(x(2))= -1008.0
# fmin= -1008.0
# min lies in ( 1.0 , 2.0 , -1008.0 )
# f(x( 63 ))<f(x( 62 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -1039.5 )
#
# iteration no. : 64
# For X
# f=( 1.0 , 2.0 , -1039.5 )	f(x(0))= -1039.5
# f+=( 1.5 , 2.0 , -1039.5 )	f(x(1))= -1039.25
# f-=( 0.5 , 2.0 , -1039.5 )	f(x(2))= -1039.25
# fmin= -1039.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -1039.5 )
# For Y
# f=( 1.0 , 2.0 , -1039.5 )	f(x(0))= -1039.5
# f+=( 1.0 , 2.5 , -1039.5 )	f(x(1))= -1039.25
# f-=( 1.0 , 1.5 , -1039.5 )	f(x(2))= -1039.25
# fmin= -1039.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -1039.5 )
# For Z
# f=( 1.0 , 2.0 , -1039.5 )	f(x(0))= -1039.5
# f+=( 1.0 , 2.0 , -1039.0 )	f(x(1))= -1039.0
# f-=( 1.0 , 2.0 , -1040.0 )	f(x(2))= -1040.0
# fmin= -1040.0
# min lies in ( 1.0 , 2.0 , -1040.0 )
# f(x( 64 ))<f(x( 63 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -1072.0 )
#
# iteration no. : 65
# For X
# f=( 1.0 , 2.0 , -1072.0 )	f(x(0))= -1072.0
# f+=( 1.5 , 2.0 , -1072.0 )	f(x(1))= -1071.75
# f-=( 0.5 , 2.0 , -1072.0 )	f(x(2))= -1071.75
# fmin= -1072.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -1072.0 )
# For Y
# f=( 1.0 , 2.0 , -1072.0 )	f(x(0))= -1072.0
# f+=( 1.0 , 2.5 , -1072.0 )	f(x(1))= -1071.75
# f-=( 1.0 , 1.5 , -1072.0 )	f(x(2))= -1071.75
# fmin= -1072.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -1072.0 )
# For Z
# f=( 1.0 , 2.0 , -1072.0 )	f(x(0))= -1072.0
# f+=( 1.0 , 2.0 , -1071.5 )	f(x(1))= -1071.5
# f-=( 1.0 , 2.0 , -1072.5 )	f(x(2))= -1072.5
# fmin= -1072.5
# min lies in ( 1.0 , 2.0 , -1072.5 )
# f(x( 65 ))<f(x( 64 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -1105.0 )
#
# iteration no. : 66
# For X
# f=( 1.0 , 2.0 , -1105.0 )	f(x(0))= -1105.0
# f+=( 1.5 , 2.0 , -1105.0 )	f(x(1))= -1104.75
# f-=( 0.5 , 2.0 , -1105.0 )	f(x(2))= -1104.75
# fmin= -1105.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -1105.0 )
# For Y
# f=( 1.0 , 2.0 , -1105.0 )	f(x(0))= -1105.0
# f+=( 1.0 , 2.5 , -1105.0 )	f(x(1))= -1104.75
# f-=( 1.0 , 1.5 , -1105.0 )	f(x(2))= -1104.75
# fmin= -1105.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -1105.0 )
# For Z
# f=( 1.0 , 2.0 , -1105.0 )	f(x(0))= -1105.0
# f+=( 1.0 , 2.0 , -1104.5 )	f(x(1))= -1104.5
# f-=( 1.0 , 2.0 , -1105.5 )	f(x(2))= -1105.5
# fmin= -1105.5
# min lies in ( 1.0 , 2.0 , -1105.5 )
# f(x( 66 ))<f(x( 65 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -1138.5 )
#
# iteration no. : 67
# For X
# f=( 1.0 , 2.0 , -1138.5 )	f(x(0))= -1138.5
# f+=( 1.5 , 2.0 , -1138.5 )	f(x(1))= -1138.25
# f-=( 0.5 , 2.0 , -1138.5 )	f(x(2))= -1138.25
# fmin= -1138.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -1138.5 )
# For Y
# f=( 1.0 , 2.0 , -1138.5 )	f(x(0))= -1138.5
# f+=( 1.0 , 2.5 , -1138.5 )	f(x(1))= -1138.25
# f-=( 1.0 , 1.5 , -1138.5 )	f(x(2))= -1138.25
# fmin= -1138.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -1138.5 )
# For Z
# f=( 1.0 , 2.0 , -1138.5 )	f(x(0))= -1138.5
# f+=( 1.0 , 2.0 , -1138.0 )	f(x(1))= -1138.0
# f-=( 1.0 , 2.0 , -1139.0 )	f(x(2))= -1139.0
# fmin= -1139.0
# min lies in ( 1.0 , 2.0 , -1139.0 )
# f(x( 67 ))<f(x( 66 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -1172.5 )
#
# iteration no. : 68
# For X
# f=( 1.0 , 2.0 , -1172.5 )	f(x(0))= -1172.5
# f+=( 1.5 , 2.0 , -1172.5 )	f(x(1))= -1172.25
# f-=( 0.5 , 2.0 , -1172.5 )	f(x(2))= -1172.25
# fmin= -1172.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -1172.5 )
# For Y
# f=( 1.0 , 2.0 , -1172.5 )	f(x(0))= -1172.5
# f+=( 1.0 , 2.5 , -1172.5 )	f(x(1))= -1172.25
# f-=( 1.0 , 1.5 , -1172.5 )	f(x(2))= -1172.25
# fmin= -1172.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -1172.5 )
# For Z
# f=( 1.0 , 2.0 , -1172.5 )	f(x(0))= -1172.5
# f+=( 1.0 , 2.0 , -1172.0 )	f(x(1))= -1172.0
# f-=( 1.0 , 2.0 , -1173.0 )	f(x(2))= -1173.0
# fmin= -1173.0
# min lies in ( 1.0 , 2.0 , -1173.0 )
# f(x( 68 ))<f(x( 67 ))
# ...
# f+=( 1.5 , 2.0 , -56287.0 )	f(x(1))= -56286.75
# f-=( 0.5 , 2.0 , -56287.0 )	f(x(2))= -56286.75
# fmin= -56287.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -56287.0 )
# For Y
# f=( 1.0 , 2.0 , -56287.0 )	f(x(0))= -56287.0
# f+=( 1.0 , 2.5 , -56287.0 )	f(x(1))= -56286.75
# f-=( 1.0 , 1.5 , -56287.0 )	f(x(2))= -56286.75
# fmin= -56287.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -56287.0 )
# For Z
# f=( 1.0 , 2.0 , -56287.0 )	f(x(0))= -56287.0
# f+=( 1.0 , 2.0 , -56286.5 )	f(x(1))= -56286.5
# f-=( 1.0 , 2.0 , -56287.5 )	f(x(2))= -56287.5
# fmin= -56287.5
# min lies in ( 1.0 , 2.0 , -56287.5 )
# f(x( 474 ))<f(x( 473 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -56524.5 )
#
# iteration no. : 475
# For X
# f=( 1.0 , 2.0 , -56524.5 )	f(x(0))= -56524.5
# f+=( 1.5 , 2.0 , -56524.5 )	f(x(1))= -56524.25
# f-=( 0.5 , 2.0 , -56524.5 )	f(x(2))= -56524.25
# fmin= -56524.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -56524.5 )
# For Y
# f=( 1.0 , 2.0 , -56524.5 )	f(x(0))= -56524.5
# f+=( 1.0 , 2.5 , -56524.5 )	f(x(1))= -56524.25
# f-=( 1.0 , 1.5 , -56524.5 )	f(x(2))= -56524.25
# fmin= -56524.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -56524.5 )
# For Z
# f=( 1.0 , 2.0 , -56524.5 )	f(x(0))= -56524.5
# f+=( 1.0 , 2.0 , -56524.0 )	f(x(1))= -56524.0
# f-=( 1.0 , 2.0 , -56525.0 )	f(x(2))= -56525.0
# fmin= -56525.0
# min lies in ( 1.0 , 2.0 , -56525.0 )
# f(x( 475 ))<f(x( 474 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -56762.5 )
#
# iteration no. : 476
# For X
# f=( 1.0 , 2.0 , -56762.5 )	f(x(0))= -56762.5
# f+=( 1.5 , 2.0 , -56762.5 )	f(x(1))= -56762.25
# f-=( 0.5 , 2.0 , -56762.5 )	f(x(2))= -56762.25
# fmin= -56762.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -56762.5 )
# For Y
# f=( 1.0 , 2.0 , -56762.5 )	f(x(0))= -56762.5
# f+=( 1.0 , 2.5 , -56762.5 )	f(x(1))= -56762.25
# f-=( 1.0 , 1.5 , -56762.5 )	f(x(2))= -56762.25
# fmin= -56762.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -56762.5 )
# For Z
# f=( 1.0 , 2.0 , -56762.5 )	f(x(0))= -56762.5
# f+=( 1.0 , 2.0 , -56762.0 )	f(x(1))= -56762.0
# f-=( 1.0 , 2.0 , -56763.0 )	f(x(2))= -56763.0
# fmin= -56763.0
# min lies in ( 1.0 , 2.0 , -56763.0 )
# f(x( 476 ))<f(x( 475 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -57001.0 )
#
# iteration no. : 477
# For X
# f=( 1.0 , 2.0 , -57001.0 )	f(x(0))= -57001.0
# f+=( 1.5 , 2.0 , -57001.0 )	f(x(1))= -57000.75
# f-=( 0.5 , 2.0 , -57001.0 )	f(x(2))= -57000.75
# fmin= -57001.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -57001.0 )
# For Y
# f=( 1.0 , 2.0 , -57001.0 )	f(x(0))= -57001.0
# f+=( 1.0 , 2.5 , -57001.0 )	f(x(1))= -57000.75
# f-=( 1.0 , 1.5 , -57001.0 )	f(x(2))= -57000.75
# fmin= -57001.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -57001.0 )
# For Z
# f=( 1.0 , 2.0 , -57001.0 )	f(x(0))= -57001.0
# f+=( 1.0 , 2.0 , -57000.5 )	f(x(1))= -57000.5
# f-=( 1.0 , 2.0 , -57001.5 )	f(x(2))= -57001.5
# fmin= -57001.5
# min lies in ( 1.0 , 2.0 , -57001.5 )
# f(x( 477 ))<f(x( 476 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -57240.0 )
#
# iteration no. : 478
# For X
# f=( 1.0 , 2.0 , -57240.0 )	f(x(0))= -57240.0
# f+=( 1.5 , 2.0 , -57240.0 )	f(x(1))= -57239.75
# f-=( 0.5 , 2.0 , -57240.0 )	f(x(2))= -57239.75
# fmin= -57240.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -57240.0 )
# For Y
# f=( 1.0 , 2.0 , -57240.0 )	f(x(0))= -57240.0
# f+=( 1.0 , 2.5 , -57240.0 )	f(x(1))= -57239.75
# f-=( 1.0 , 1.5 , -57240.0 )	f(x(2))= -57239.75
# fmin= -57240.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -57240.0 )
# For Z
# f=( 1.0 , 2.0 , -57240.0 )	f(x(0))= -57240.0
# f+=( 1.0 , 2.0 , -57239.5 )	f(x(1))= -57239.5
# f-=( 1.0 , 2.0 , -57240.5 )	f(x(2))= -57240.5
# fmin= -57240.5
# min lies in ( 1.0 , 2.0 , -57240.5 )
# f(x( 478 ))<f(x( 477 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -57479.5 )
#
# iteration no. : 479
# For X
# f=( 1.0 , 2.0 , -57479.5 )	f(x(0))= -57479.5
# f+=( 1.5 , 2.0 , -57479.5 )	f(x(1))= -57479.25
# f-=( 0.5 , 2.0 , -57479.5 )	f(x(2))= -57479.25
# fmin= -57479.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -57479.5 )
# For Y
# f=( 1.0 , 2.0 , -57479.5 )	f(x(0))= -57479.5
# f+=( 1.0 , 2.5 , -57479.5 )	f(x(1))= -57479.25
# f-=( 1.0 , 1.5 , -57479.5 )	f(x(2))= -57479.25
# fmin= -57479.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -57479.5 )
# For Z
# f=( 1.0 , 2.0 , -57479.5 )	f(x(0))= -57479.5
# f+=( 1.0 , 2.0 , -57479.0 )	f(x(1))= -57479.0
# f-=( 1.0 , 2.0 , -57480.0 )	f(x(2))= -57480.0
# fmin= -57480.0
# min lies in ( 1.0 , 2.0 , -57480.0 )
# f(x( 479 ))<f(x( 478 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -57719.5 )
#
# iteration no. : 480
# For X
# f=( 1.0 , 2.0 , -57719.5 )	f(x(0))= -57719.5
# f+=( 1.5 , 2.0 , -57719.5 )	f(x(1))= -57719.25
# f-=( 0.5 , 2.0 , -57719.5 )	f(x(2))= -57719.25
# fmin= -57719.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -57719.5 )
# For Y
# f=( 1.0 , 2.0 , -57719.5 )	f(x(0))= -57719.5
# f+=( 1.0 , 2.5 , -57719.5 )	f(x(1))= -57719.25
# f-=( 1.0 , 1.5 , -57719.5 )	f(x(2))= -57719.25
# fmin= -57719.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -57719.5 )
# For Z
# f=( 1.0 , 2.0 , -57719.5 )	f(x(0))= -57719.5
# f+=( 1.0 , 2.0 , -57719.0 )	f(x(1))= -57719.0
# f-=( 1.0 , 2.0 , -57720.0 )	f(x(2))= -57720.0
# fmin= -57720.0
# min lies in ( 1.0 , 2.0 , -57720.0 )
# f(x( 480 ))<f(x( 479 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -57960.0 )
#
# iteration no. : 481
# For X
# f=( 1.0 , 2.0 , -57960.0 )	f(x(0))= -57960.0
# f+=( 1.5 , 2.0 , -57960.0 )	f(x(1))= -57959.75
# f-=( 0.5 , 2.0 , -57960.0 )	f(x(2))= -57959.75
# fmin= -57960.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -57960.0 )
# For Y
# f=( 1.0 , 2.0 , -57960.0 )	f(x(0))= -57960.0
# f+=( 1.0 , 2.5 , -57960.0 )	f(x(1))= -57959.75
# f-=( 1.0 , 1.5 , -57960.0 )	f(x(2))= -57959.75
# fmin= -57960.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -57960.0 )
# For Z
# f=( 1.0 , 2.0 , -57960.0 )	f(x(0))= -57960.0
# f+=( 1.0 , 2.0 , -57959.5 )	f(x(1))= -57959.5
# f-=( 1.0 , 2.0 , -57960.5 )	f(x(2))= -57960.5
# fmin= -57960.5
# min lies in ( 1.0 , 2.0 , -57960.5 )
# f(x( 481 ))<f(x( 480 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -58201.0 )
#
# iteration no. : 482
# For X
# f=( 1.0 , 2.0 , -58201.0 )	f(x(0))= -58201.0
# f+=( 1.5 , 2.0 , -58201.0 )	f(x(1))= -58200.75
# f-=( 0.5 , 2.0 , -58201.0 )	f(x(2))= -58200.75
# fmin= -58201.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -58201.0 )
# For Y
# f=( 1.0 , 2.0 , -58201.0 )	f(x(0))= -58201.0
# f+=( 1.0 , 2.5 , -58201.0 )	f(x(1))= -58200.75
# f-=( 1.0 , 1.5 , -58201.0 )	f(x(2))= -58200.75
# fmin= -58201.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -58201.0 )
# For Z
# f=( 1.0 , 2.0 , -58201.0 )	f(x(0))= -58201.0
# f+=( 1.0 , 2.0 , -58200.5 )	f(x(1))= -58200.5
# f-=( 1.0 , 2.0 , -58201.5 )	f(x(2))= -58201.5
# fmin= -58201.5
# min lies in ( 1.0 , 2.0 , -58201.5 )
# f(x( 482 ))<f(x( 481 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -58442.5 )
#
# iteration no. : 483
# For X
# f=( 1.0 , 2.0 , -58442.5 )	f(x(0))= -58442.5
# f+=( 1.5 , 2.0 , -58442.5 )	f(x(1))= -58442.25
# f-=( 0.5 , 2.0 , -58442.5 )	f(x(2))= -58442.25
# fmin= -58442.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -58442.5 )
# For Y
# f=( 1.0 , 2.0 , -58442.5 )	f(x(0))= -58442.5
# f+=( 1.0 , 2.5 , -58442.5 )	f(x(1))= -58442.25
# f-=( 1.0 , 1.5 , -58442.5 )	f(x(2))= -58442.25
# fmin= -58442.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -58442.5 )
# For Z
# f=( 1.0 , 2.0 , -58442.5 )	f(x(0))= -58442.5
# f+=( 1.0 , 2.0 , -58442.0 )	f(x(1))= -58442.0
# f-=( 1.0 , 2.0 , -58443.0 )	f(x(2))= -58443.0
# fmin= -58443.0
# min lies in ( 1.0 , 2.0 , -58443.0 )
# f(x( 483 ))<f(x( 482 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -58684.5 )
#
# iteration no. : 484
# For X
# f=( 1.0 , 2.0 , -58684.5 )	f(x(0))= -58684.5
# f+=( 1.5 , 2.0 , -58684.5 )	f(x(1))= -58684.25
# f-=( 0.5 , 2.0 , -58684.5 )	f(x(2))= -58684.25
# fmin= -58684.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -58684.5 )
# For Y
# f=( 1.0 , 2.0 , -58684.5 )	f(x(0))= -58684.5
# f+=( 1.0 , 2.5 , -58684.5 )	f(x(1))= -58684.25
# f-=( 1.0 , 1.5 , -58684.5 )	f(x(2))= -58684.25
# fmin= -58684.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -58684.5 )
# For Z
# f=( 1.0 , 2.0 , -58684.5 )	f(x(0))= -58684.5
# f+=( 1.0 , 2.0 , -58684.0 )	f(x(1))= -58684.0
# f-=( 1.0 , 2.0 , -58685.0 )	f(x(2))= -58685.0
# fmin= -58685.0
# min lies in ( 1.0 , 2.0 , -58685.0 )
# f(x( 484 ))<f(x( 483 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -58927.0 )
#
# iteration no. : 485
# For X
# f=( 1.0 , 2.0 , -58927.0 )	f(x(0))= -58927.0
# f+=( 1.5 , 2.0 , -58927.0 )	f(x(1))= -58926.75
# f-=( 0.5 , 2.0 , -58927.0 )	f(x(2))= -58926.75
# fmin= -58927.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -58927.0 )
# For Y
# f=( 1.0 , 2.0 , -58927.0 )	f(x(0))= -58927.0
# f+=( 1.0 , 2.5 , -58927.0 )	f(x(1))= -58926.75
# f-=( 1.0 , 1.5 , -58927.0 )	f(x(2))= -58926.75
# fmin= -58927.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -58927.0 )
# For Z
# f=( 1.0 , 2.0 , -58927.0 )	f(x(0))= -58927.0
# f+=( 1.0 , 2.0 , -58926.5 )	f(x(1))= -58926.5
# f-=( 1.0 , 2.0 , -58927.5 )	f(x(2))= -58927.5
# fmin= -58927.5
# min lies in ( 1.0 , 2.0 , -58927.5 )
# f(x( 485 ))<f(x( 484 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -59170.0 )
#
# iteration no. : 486
# For X
# f=( 1.0 , 2.0 , -59170.0 )	f(x(0))= -59170.0
# f+=( 1.5 , 2.0 , -59170.0 )	f(x(1))= -59169.75
# f-=( 0.5 , 2.0 , -59170.0 )	f(x(2))= -59169.75
# fmin= -59170.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -59170.0 )
# For Y
# f=( 1.0 , 2.0 , -59170.0 )	f(x(0))= -59170.0
# f+=( 1.0 , 2.5 , -59170.0 )	f(x(1))= -59169.75
# f-=( 1.0 , 1.5 , -59170.0 )	f(x(2))= -59169.75
# fmin= -59170.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -59170.0 )
# For Z
# f=( 1.0 , 2.0 , -59170.0 )	f(x(0))= -59170.0
# f+=( 1.0 , 2.0 , -59169.5 )	f(x(1))= -59169.5
# f-=( 1.0 , 2.0 , -59170.5 )	f(x(2))= -59170.5
# fmin= -59170.5
# min lies in ( 1.0 , 2.0 , -59170.5 )
# f(x( 486 ))<f(x( 485 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -59413.5 )
#
# iteration no. : 487
# For X
# f=( 1.0 , 2.0 , -59413.5 )	f(x(0))= -59413.5
# f+=( 1.5 , 2.0 , -59413.5 )	f(x(1))= -59413.25
# f-=( 0.5 , 2.0 , -59413.5 )	f(x(2))= -59413.25
# fmin= -59413.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -59413.5 )
# For Y
# f=( 1.0 , 2.0 , -59413.5 )	f(x(0))= -59413.5
# f+=( 1.0 , 2.5 , -59413.5 )	f(x(1))= -59413.25
# f-=( 1.0 , 1.5 , -59413.5 )	f(x(2))= -59413.25
# fmin= -59413.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -59413.5 )
# For Z
# f=( 1.0 , 2.0 , -59413.5 )	f(x(0))= -59413.5
# f+=( 1.0 , 2.0 , -59413.0 )	f(x(1))= -59413.0
# f-=( 1.0 , 2.0 , -59414.0 )	f(x(2))= -59414.0
# fmin= -59414.0
# min lies in ( 1.0 , 2.0 , -59414.0 )
# f(x( 487 ))<f(x( 486 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -59657.5 )
#
# iteration no. : 488
# For X
# f=( 1.0 , 2.0 , -59657.5 )	f(x(0))= -59657.5
# f+=( 1.5 , 2.0 , -59657.5 )	f(x(1))= -59657.25
# f-=( 0.5 , 2.0 , -59657.5 )	f(x(2))= -59657.25
# fmin= -59657.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -59657.5 )
# For Y
# f=( 1.0 , 2.0 , -59657.5 )	f(x(0))= -59657.5
# f+=( 1.0 , 2.5 , -59657.5 )	f(x(1))= -59657.25
# f-=( 1.0 , 1.5 , -59657.5 )	f(x(2))= -59657.25
# fmin= -59657.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -59657.5 )
# For Z
# f=( 1.0 , 2.0 , -59657.5 )	f(x(0))= -59657.5
# f+=( 1.0 , 2.0 , -59657.0 )	f(x(1))= -59657.0
# f-=( 1.0 , 2.0 , -59658.0 )	f(x(2))= -59658.0
# fmin= -59658.0
# min lies in ( 1.0 , 2.0 , -59658.0 )
# f(x( 488 ))<f(x( 487 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -59902.0 )
#
# iteration no. : 489
# For X
# f=( 1.0 , 2.0 , -59902.0 )	f(x(0))= -59902.0
# f+=( 1.5 , 2.0 , -59902.0 )	f(x(1))= -59901.75
# f-=( 0.5 , 2.0 , -59902.0 )	f(x(2))= -59901.75
# fmin= -59902.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -59902.0 )
# For Y
# f=( 1.0 , 2.0 , -59902.0 )	f(x(0))= -59902.0
# f+=( 1.0 , 2.5 , -59902.0 )	f(x(1))= -59901.75
# f-=( 1.0 , 1.5 , -59902.0 )	f(x(2))= -59901.75
# fmin= -59902.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -59902.0 )
# For Z
# f=( 1.0 , 2.0 , -59902.0 )	f(x(0))= -59902.0
# f+=( 1.0 , 2.0 , -59901.5 )	f(x(1))= -59901.5
# f-=( 1.0 , 2.0 , -59902.5 )	f(x(2))= -59902.5
# fmin= -59902.5
# min lies in ( 1.0 , 2.0 , -59902.5 )
# f(x( 489 ))<f(x( 488 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -60147.0 )
#
# iteration no. : 490
# For X
# f=( 1.0 , 2.0 , -60147.0 )	f(x(0))= -60147.0
# f+=( 1.5 , 2.0 , -60147.0 )	f(x(1))= -60146.75
# f-=( 0.5 , 2.0 , -60147.0 )	f(x(2))= -60146.75
# fmin= -60147.0
# the new values for calculation of Y is ( 1.0 , 2.0 , -60147.0 )
# For Y
# f=( 1.0 , 2.0 , -60147.0 )	f(x(0))= -60147.0
# f+=( 1.0 , 2.5 , -60147.0 )	f(x(1))= -60146.75
# f-=( 1.0 , 1.5 , -60147.0 )	f(x(2))= -60146.75
# fmin= -60147.0
# the new values for calculation of Z is ( 1.0 , 2.0 , -60147.0 )
# For Z
# f=( 1.0 , 2.0 , -60147.0 )	f(x(0))= -60147.0
# f+=( 1.0 , 2.0 , -60146.5 )	f(x(1))= -60146.5
# f-=( 1.0 , 2.0 , -60147.5 )	f(x(2))= -60147.5
# fmin= -60147.5
# min lies in ( 1.0 , 2.0 , -60147.5 )
# f(x( 490 ))<f(x( 489 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -60392.5 )
#
# iteration no. : 491
# For X
# f=( 1.0 , 2.0 , -60392.5 )	f(x(0))= -60392.5
# f+=( 1.5 , 2.0 , -60392.5 )	f(x(1))= -60392.25
# f-=( 0.5 , 2.0 , -60392.5 )	f(x(2))= -60392.25
# fmin= -60392.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -60392.5 )
# For Y
# f=( 1.0 , 2.0 , -60392.5 )	f(x(0))= -60392.5
# f+=( 1.0 , 2.5 , -60392.5 )	f(x(1))= -60392.25
# f-=( 1.0 , 1.5 , -60392.5 )	f(x(2))= -60392.25
# fmin= -60392.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -60392.5 )
# For Z
# f=( 1.0 , 2.0 , -60392.5 )	f(x(0))= -60392.5
# f+=( 1.0 , 2.0 , -60392.0 )	f(x(1))= -60392.0
# f-=( 1.0 , 2.0 , -60393.0 )	f(x(2))= -60393.0
# fmin= -60393.0
# min lies in ( 1.0 , 2.0 , -60393.0 )
# f(x( 491 ))<f(x( 490 ))
# Exploratory move is a success
# pattern move :
# x(p)=( 1.0 , 2.0 , -60638.5 )
#
# iteration no. : 492
# For X
# f=( 1.0 , 2.0 , -60638.5 )	f(x(0))= -60638.5
# f+=( 1.5 , 2.0 , -60638.5 )	f(x(1))= -60638.25
# f-=( 0.5 , 2.0 , -60638.5 )	f(x(2))= -60638.25
# fmin= -60638.5
# the new values for calculation of Y is ( 1.0 , 2.0 , -60638.5 )
# For Y
# f=( 1.0 , 2.0 , -60638.5 )	f(x(0))= -60638.5
# f+=( 1.0 , 2.5 , -60638.5 )	f(x(1))= -60638.25
# f-=( 1.0 , 1.5 , -60638.5 )	f(x(2))= -60638.25
# fmin= -60638.5
# the new values for calculation of Z is ( 1.0 , 2.0 , -60638.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e3d3f3225bbd> in <module>
#      84         y02=y[2]
#      85         z02=z01
# ---> 86     print("the new values for calculation of Z is (",x02,",",y02,",",z02,")")
#      87     print("For Z")
#      88     z.append(Decimal(z[k]+(delz)))
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
#number of iterations is given 
#for 2 variables 
import math
from decimal import Decimal
def f(x,y):
    return Decimal(x-y+(2*(x**2))+(2*x*y)+(z**3))
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
s=Decimal(input("Enter the number of iterations"))
k=0
i=1
j=0
l=0
x1=[]
y1=[]
fminb=[]
fcomp=[]
p=0
while i<=s:
    print("")
    print("iteration no. :",i)
    print("For X")
    x=[]
    y=[]
    fxx=[]
    fxy=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    f0=f(Decimal(x0),Decimal(y0))
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx)))
    x.append(Decimal(x[k]-(delx)))
    fxx.append(f(x[1],y[0]))
    fxx.append(f(x[2],y[0]))
    print("x(0)=(",x0,",",y0,")\tf(x(0))=",f0)
    print("x(1)=(",x[1],",",y[0],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[2],",",y[0],")\tf(x(2))=",fxx[2])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x01=x0
        y01=y0
    elif fxx[1]==fmin:
        x01=x[1]
        y01=y0
    elif fxx[2]==fmin:
        x01=x[2]
        y01=y0
    print("the new values for calculation of Y is (",x01,",",y01,")")
    print("For Y")
    y.append(Decimal(y[k]+(dely)))
    y.append(Decimal(y[k]-(dely)))
    fxy.append(f(Decimal(x01),Decimal(y01)))
    fxy.append(f(Decimal(x01),y[1]))
    fxy.append(f(Decimal(x01),y[2]))
    print("x(0)=(",x01,",",y01,")\tf(x(0))=",fxy[0])
    print("x(1)=(",x01,",",y[1],")\tf(x(1))=",fxy[1])
    print("x(2)=(",x01,",",y[2],")\tf(x(2))=",fxy[2])
    fmin=min(fxy)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxy[0]==fmin:
        x02=x01
        y02=y01
    elif fxy[1]==fmin:
        x02=x01
        y02=y[1]
    elif fxy[2]==fmin:
        x02=x01
        y02=y[2]
    x1.append(Decimal(x0))
    x1.append(Decimal(x02))
    y1.append(Decimal(y0))
    y1.append(Decimal(y02))
    print("min lies in (",x02,",",y02,")")
    if (x0==x02) and (y0==y02):
        print("Exploratory move is not a success")
        delx=delx/2
        dely=dely/2
        print("the new values of delx and dely are =(",delx,",",dely,")")
        x0=x02
        y0=y02
        j=j+2
        l=l+1
        p=1
        continue 
    elif p==1:
        break
    elif p>1 or p==0:
        print("Exploratory move is a success")
        print("pattern move :")
        if j==0:
            xp1=2*(x1[j+1])-(x1[j])
            yp1=2*(x1[j+1])-(x1[j])
            print("x(p)=(",xp1,",",yp1,")")  
        else :
            xp1=2*(x1[j+1])-(x1[j-1])
            yp1=2*(y1[j+1])-(y1[j-1])
            print("x(p)=(",xp1,",",yp1,")")
        x0=xp1
        y0=yp1
        i=i+1
        j=j+2
        l=l+1
# Out:
# Enter the intital value of x01
# Enter the intital value of y01
# Enter the x value in the reduction parameter0.5
# Enter the y value in the reduction parameter0.5
# Enter the number of iterations2
#
# iteration no. : 1
# For X
# x(0)=( 1 , 1 )	f(x(0))= 6.218598749143853687826322130
# x(1)=( 1.5 , 1 )	f(x(1))= 7.169448799378131065296315683
# x(2)=( 0.5 , 1 )	f(x(2))= 5.887498844716613444205677297
# fmin= 5.887498844716613444205677297
# the new values for calculation of Y is ( 0.5 , 1 )
# For Y
# x(0)=( 0.5 , 1 )	f(x(0))= 5.887498844716613444205677297
# x(1)=( 0.5 , 1.5 )	f(x(1))= 11.04352284651277138483038698
# x(2)=( 0.5 , 0.5 )	f(x(2))= 2.525453398512919944707277864
# fmin= 2.525453398512919944707277864
# min lies in ( 0.5 , 0.5 )
# Exploratory move is a success
# pattern move :
# x(p)=( 0.0 , 0.0 )
#
# iteration no. : 2
# For X
# x(0)=( 0.0 , 0.0 )	f(x(0))= 1.020201340026755776335676273
# x(1)=( 0.5 , 0.0 )	f(x(1))= 1.046027859908716939330020068
# x(2)=( -0.5 , 0.0 )	f(x(2))= 1.277621313204886588366093747
# fmin= 1.020201340026755776335676273
# the new values for calculation of Y is ( 0.0 , 0.0 )
# For Y
# x(0)=( 0.0 , 0.0 )	f(x(0))= 1.020201340026755776335676273
# x(1)=( 0.0 , 0.5 )	f(x(1))= 2.499626878630958781712934069
# x(2)=( 0.0 , -0.5 )	f(x(2))= 1.540775801422552770958418477
# fmin= 1.020201340026755776335676273
# min lies in ( 0.0 , 0.0 )
# Exploratory move is not a success
# the new values of delx and dely are =( 0.25 , 0.25 )
#
# iteration no. : 2
# For X
# x(0)=( 0.0 , 0.0 )	f(x(0))= 1.020201340026755776335676273
# x(1)=( 0.25 , 0.0 )	f(x(1))= 1.001250781575622639252287627
# x(2)=( -0.25 , 0.0 )	f(x(2))= 1.106553245497890580750777190
# fmin= 1.001250781575622639252287627
# the new values for calculation of Y is ( 0.25 , 0.0 )
# For Y
# x(0)=( 0.25 , 0.0 )	f(x(0))= 1.001250781575622639252287627
# x(1)=( 0.25 , 0.25 )	f(x(1))= 1.498654740830145576380161288
# x(2)=( 0.25 , -0.25 )	f(x(2))= 1.003846822321099702124413966
# fmin= 1.001250781575622639252287627
# min lies in ( 0.25 , 0.0 )

# %%
#no. of iterations is given 
#for 3 variables 
import math
from decimal import Decimal
def f(x,y,z):
    return Decimal(x-y+(2*(x**2))+(2*x*y)+(z**3))
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
z0=input(("Enter the intital value of z0"))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
s=Decimal(input("Enter the number of iterations"))
k=0
i=1
j=0
l=0
x1=[]
y1=[]
z1=[]
fminb=[]
fcomp=[]
p=0
while i<=s:
    print("")
    print("iteration no. :",i)
    print("For X")
    x=[]
    y=[]
    z=[]
    fxx=[]
    fxy=[]
    fxz=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    z.append(Decimal(z0))
    f0=f(Decimal(x0),Decimal(y0),Decimal(z0))
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx)))
    x.append(Decimal(x[k]-(delx)))
    fxx.append(f(x[1],y[0],z[0]))
    fxx.append(f(x[2],y[0],z[0]))
    print("f=(",x0,",",y0,",",z0,")\tf(x(0))=",f0)
    print("f+=(",x[1],",",y[0],",",z[0],")\tf(x(1))=",fxx[1])
    print("f-=(",x[2],",",y[0],",",z[0],")\tf(x(2))=",fxx[2])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x01=x0
        y01=y0
        z01=z0
    elif fxx[1]==fmin:
        x01=x[1]
        y01=y0
        z01=z0
    elif fxx[2]==fmin:
        x01=x[2]
        y01=y0
        z01=z0
    print("the new values for calculation of Y is (",x01,",",y01,",",z01,")")
    print("For Y")
    y.append(Decimal(y[k]+(dely)))
    y.append(Decimal(y[k]-(dely)))
    fxy.append(f(Decimal(x01),Decimal(y01),Decimal(z01)))
    fxy.append(f(Decimal(x01),y[1],Decimal(z01)))
    fxy.append(f(Decimal(x01),y[2],Decimal(z01)))
    print("f=(",x01,",",y01,",",z01,")\tf(x(0))=",fxy[0])
    print("f+=(",x01,",",y[1],",",z01,")\tf(x(1))=",fxy[1])
    print("f-=(",x01,",",y[2],",",z01,")\tf(x(2))=",fxy[2])
    fmin=min(fxy)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxy[0]==fmin:
        x02=x01
        y02=y01
        z02=z01
    elif fxy[1]==fmin:
        x02=x01
        y02=y[1]
        z02=z01
    elif fxy[2]==fmin:
        x02=x01
        y02=y[2]
        z02=z01
    print("the new values for calculation of Z is (",x02,",",y02,",",z02,")")
    print("For Z")
    z.append(Decimal(z[k]+(delz)))
    z.append(Decimal(z[k]-(delz)))
    fxz.append(f(Decimal(x02),Decimal(y02),Decimal(z02)))
    fxz.append(f(Decimal(x02),Decimal(y02),z[1]))
    fxz.append(f(Decimal(x02),Decimal(y02),z[2]))
    print("f=(",x02,",",y02,",",z02,")\tf(x(0))=",fxz[0])
    print("f+=(",x02,",",y02,",",z[1],")\tf(x(1))=",fxz[1])
    print("f-=(",x02,",",y02,",",z[2],")\tf(x(2))=",fxz[2])
    fmin=min(fxz)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxz[0]==fmin:
        x03=x02
        y03=y02
        z03=z02
    elif fxz[1]==fmin:
        x03=x02
        y03=y02
        z03=z[1]
    elif fxz[2]==fmin:
        x03=x02
        y03=y02
        z03=z[2] 
    x1.append(Decimal(x0))
    x1.append(Decimal(x03))
    y1.append(Decimal(y0))
    y1.append(Decimal(y03))
    z1.append(Decimal(z0))
    z1.append(Decimal(z03))
    print("min lies in (",x03,",",y03,",",z03,")")
    if (x0==x03) and (y0==y03) and (z0==z03):
        print("Exploratory move is not a success")
        delx=delx/2
        dely=dely/2
        delz=delz/2
        print("the new values of del are =(",delx,",",dely,",",delz,")")
        x0=x03
        y0=y03
        z0=z03
        j=j+2
        l=l+1
        p=1
        continue 
    elif p==1:
        break
    elif p!=1:
        print("Exploratory move is a success")
        print("pattern move :")
        if j==0:
            xp1=2*(x1[j+1])-(x1[j])
            yp1=2*(y1[j+1])-(y1[j])
            zp1=2*(z1[j+1])-(z1[j])
            print("x(p)=(",xp1,",",yp1,",",zp1,")")  
        else :
            xp1=2*(x1[j+1])-(x1[j-1])
            yp1=2*(y1[j+1])-(y1[j-1])
            zp1=2*(z1[j+1])-(z1[j-1])
            print("x(p)=(",xp1,",",yp1,",",zp1,")")
        x0=xp1
        y0=yp1
        z0=zp1
        i=i+1
        j=j+2
        l=l+1
# Out:
# Enter the intital value of x01
# Enter the intital value of y00.5
# Enter the intital value of z0-0.5
# Enter the x value in the reduction parameter0.5
# Enter the y value in the reduction parameter0.5
# Enter the z value in the reduction parameter0.5
# Enter the number of iterations4
#
# iteration no. : 1
# For X
# f=( 1 , 0.5 , -0.5 )	f(x(0))= 3.375
# f+=( 1.5 , 0.5 , -0.5 )	f(x(1))= 6.875
# f-=( 0.5 , 0.5 , -0.5 )	f(x(2))= 0.875
# fmin= 0.875
# the new values for calculation of Y is ( 0.5 , 0.5 , -0.5 )
# For Y
# f=( 0.5 , 0.5 , -0.5 )	f(x(0))= 0.875
# f+=( 0.5 , 1.0 , -0.5 )	f(x(1))= 0.875
# f-=( 0.5 , 0.0 , -0.5 )	f(x(2))= 0.875
# fmin= 0.875
# the new values for calculation of Z is ( 0.5 , 0.5 , -0.5 )
# For Z
# f=( 0.5 , 0.5 , -0.5 )	f(x(0))= 0.875
# f+=( 0.5 , 0.5 , 0.0 )	f(x(1))= 1.00
# f-=( 0.5 , 0.5 , -1.0 )	f(x(2))= 0.000
# fmin= 0.000
# min lies in ( 0.5 , 0.5 , -1.0 )
# Exploratory move is a success
# pattern move :
# x(p)=( 0.0 , 0.5 , -1.5 )
#
# iteration no. : 2
# For X
# f=( 0.0 , 0.5 , -1.5 )	f(x(0))= -3.875
# f+=( 0.5 , 0.5 , -1.5 )	f(x(1))= -2.375
# f-=( -0.5 , 0.5 , -1.5 )	f(x(2))= -4.375
# fmin= -4.375
# the new values for calculation of Y is ( -0.5 , 0.5 , -1.5 )
# For Y
# f=( -0.5 , 0.5 , -1.5 )	f(x(0))= -4.375
# f+=( -0.5 , 1.0 , -1.5 )	f(x(1))= -5.375
# f-=( -0.5 , 0.0 , -1.5 )	f(x(2))= -3.375
# fmin= -5.375
# the new values for calculation of Z is ( -0.5 , 1.0 , -1.5 )
# For Z
# f=( -0.5 , 1.0 , -1.5 )	f(x(0))= -5.375
# f+=( -0.5 , 1.0 , -1.0 )	f(x(1))= -3.000
# f-=( -0.5 , 1.0 , -2.0 )	f(x(2))= -10.000
# fmin= -10.000
# min lies in ( -0.5 , 1.0 , -2.0 )
# Exploratory move is a success
# pattern move :
# x(p)=( -1.5 , 1.5 , -3.0 )
#
# iteration no. : 3
# For X
# f=( -1.5 , 1.5 , -3.0 )	f(x(0))= -30.000
# f+=( -1.0 , 1.5 , -3.0 )	f(x(1))= -30.500
# f-=( -2.0 , 1.5 , -3.0 )	f(x(2))= -28.500
# fmin= -30.500
# the new values for calculation of Y is ( -1.0 , 1.5 , -3.0 )
# For Y
# f=( -1.0 , 1.5 , -3.0 )	f(x(0))= -30.500
# f+=( -1.0 , 2.0 , -3.0 )	f(x(1))= -32.000
# f-=( -1.0 , 1.0 , -3.0 )	f(x(2))= -29.000
# fmin= -32.000
# the new values for calculation of Z is ( -1.0 , 2.0 , -3.0 )
# For Z
# f=( -1.0 , 2.0 , -3.0 )	f(x(0))= -32.000
# f+=( -1.0 , 2.0 , -2.5 )	f(x(1))= -20.625
# f-=( -1.0 , 2.0 , -3.5 )	f(x(2))= -47.875
# fmin= -47.875
# min lies in ( -1.0 , 2.0 , -3.5 )
# Exploratory move is a success
# pattern move :
# x(p)=( -1.5 , 3.0 , -5.0 )
#
# iteration no. : 4
# For X
# f=( -1.5 , 3.0 , -5.0 )	f(x(0))= -134.000
# f+=( -1.0 , 3.0 , -5.0 )	f(x(1))= -133.000
# f-=( -2.0 , 3.0 , -5.0 )	f(x(2))= -134.000
# fmin= -134.000
# the new values for calculation of Y is ( -1.5 , 3.0 , -5.0 )
# For Y
# f=( -1.5 , 3.0 , -5.0 )	f(x(0))= -134.000
# f+=( -1.5 , 3.5 , -5.0 )	f(x(1))= -136.000
# f-=( -1.5 , 2.5 , -5.0 )	f(x(2))= -132.000
# fmin= -136.000
# the new values for calculation of Z is ( -1.5 , 3.5 , -5.0 )
# For Z
# f=( -1.5 , 3.5 , -5.0 )	f(x(0))= -136.000
# f+=( -1.5 , 3.5 , -4.5 )	f(x(1))= -102.125
# f-=( -1.5 , 3.5 , -5.5 )	f(x(2))= -177.375
# fmin= -177.375
# min lies in ( -1.5 , 3.5 , -5.5 )
# Exploratory move is a success
# pattern move :
# x(p)=( -2.0 , 5.0 , -7.5 )
