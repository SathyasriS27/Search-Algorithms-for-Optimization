# %%
import math
from decimal import Decimal
def f(x,y):
    return Decimal((((x**2)-y-11)**2)+((x+(y**2)-7)**2))#function
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
E=Decimal(input(("enter the termination parameter")))
i=1
j=0
fminb=[]
while True:
    k=0
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    fxx=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    f0=f(Decimal(x0),Decimal(y0))
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    fxx.append(f(x[1],y[1]))
    fxx.append(f(x[1],y[2]))
    fxx.append(f(x[2],y[1]))
    fxx.append(f(x[2],y[2]))
    print("x(0)=(",x0,",",y0,")\tf(x(0))=",f0)
    print("x(1)=(",x[1],",",y[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[2],",",y[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[2],",",y[2],")\tf(x(4))=",fxx[4])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[2]
    elif fxx[3]==fmin:
        x0=x[2]
        y0=y[1]
    elif fxx[4]==fmin:
        x0=x[2]
        y0=y[2]
    print("min lies in (",x0,",",y0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
            mag=(((delx/2)**2)+((dely/2)**2))
            if mag<E:
                print("")
                print("||del/2||<E, so therefore")
                print("min lies in (",x0,",",y0,")")
                break
            else:
                delx=delx/2
                dely=dely/2
                print("")
                print("the new delx and dely values are:",delx,dely)
                i=i+1
                j=j+1
                continue
    else:
        i=i+1
        j=j+1
        continue
# Out:
# Enter the intital value of x01
# Enter the intital value of y01
# enter the vlue of n - no. of variables used2
# Enter the x value in the reduction parameter2
# Enter the y value in the reduction parameter2
# enter the termination parameter0.5
#
# Interation no. :  1
# x(0)=( 1 , 1 )	f(x(0))= 146
# x(1)=( 2 , 2 )	f(x(1))= 82
# x(2)=( 2 , 0 )	f(x(2))= 74
# x(3)=( 0 , 2 )	f(x(3))= 178
# x(4)=( 0 , 0 )	f(x(4))= 170
# fmin= 74
# min lies in ( 2 , 0 )
#
# Interation no. :  2
# x(0)=( 2 , 0 )	f(x(0))= 74
# x(1)=( 3 , 1 )	f(x(1))= 18
# x(2)=( 3 , -1 )	f(x(2))= 10
# x(3)=( 1 , 1 )	f(x(3))= 146
# x(4)=( 1 , -1 )	f(x(4))= 106
# fmin= 10
# min lies in ( 3 , -1 )
#
# Interation no. :  3
# x(0)=( 3 , -1 )	f(x(0))= 10
# x(1)=( 4 , 0 )	f(x(1))= 34
# x(2)=( 4 , -2 )	f(x(2))= 50
# x(3)=( 2 , 0 )	f(x(3))= 74
# x(4)=( 2 , -2 )	f(x(4))= 26
# fmin= 10
# min lies in ( 3 , -1 )
#
# the new delx and dely values are: 1 1
#
# Interation no. :  4
# x(0)=( 3 , -1 )	f(x(0))= 10
# x(1)=( 3.5 , -0.5 )	f(x(1))= 13.6250
# x(2)=( 3.5 , -1.5 )	f(x(2))= 9.1250
# x(3)=( 2.5 , -0.5 )	f(x(3))= 36.1250
# x(4)=( 2.5 , -1.5 )	f(x(4))= 15.6250
# fmin= 9.1250
# min lies in ( 3.5 , -1.5 )
#
# Interation no. :  5
# x(0)=( 3.5 , -1.5 )	f(x(0))= 9.1250
# x(1)=( 4.0 , -1.0 )	f(x(1))= 40.0000
# x(2)=( 4.0 , -2.0 )	f(x(2))= 50.0000
# x(3)=( 3.0 , -1.0 )	f(x(3))= 10.0000
# x(4)=( 3.0 , -2.0 )	f(x(4))= 0
# fmin= 0
# min lies in ( 3.0 , -2.0 )
#
# Interation no. :  6
# x(0)=( 3.0 , -2.0 )	f(x(0))= 0
# x(1)=( 3.5 , -1.5 )	f(x(1))= 9.1250
# x(2)=( 3.5 , -2.5 )	f(x(2))= 21.6250
# x(3)=( 2.5 , -1.5 )	f(x(3))= 15.6250
# x(4)=( 2.5 , -2.5 )	f(x(4))= 8.1250
# fmin= 0
# min lies in ( 3.0 , -2.0 )
#
# the new delx and dely values are: 0.5 0.5
#
# Interation no. :  7
# x(0)=( 3.0 , -2.0 )	f(x(0))= 0
# x(1)=( 3.25 , -1.75 )	f(x(1))= 2.19531250
# x(2)=( 3.25 , -2.25 )	f(x(2))= 5.00781250
# x(3)=( 2.75 , -1.75 )	f(x(3))= 4.25781250
# x(4)=( 2.75 , -2.25 )	f(x(4))= 2.07031250
# fmin= 0
# min lies in ( 3.0 , -2.0 )
#
# ||del/2||<E, so therefore
# min lies in ( 3.0 , -2.0 )

# %%
import math
from decimal import Decimal
def f(x,y):
    return Decimal((x**2)-(2*x)+(y**2)-y+25)
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
n=input("enter the vlue of n - no. of variables used")
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
s=Decimal(input(("enter the number of iterations")))
i=1
j=0
fminb=[]

while i<=s:
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    fxx=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    f0=f(Decimal(x0),Decimal(y0))
    fxx.append(f0)
    x.append(Decimal(x[0]+(delx/2)))
    x.append(Decimal(x[0]-(delx/2)))
    y.append(Decimal(y[0]+(dely/2)))
    y.append(Decimal(y[0]-(dely/2)))
    fxx.append(f(x[1],y[1]))
    fxx.append(f(x[1],y[2]))
    fxx.append(f(x[2],y[1]))
    fxx.append(f(x[2],y[2]))
    print("x(0)=(",x0,",",y0,")\tf(x(0))=",f0)
    print("x(1)=(",x[1],",",y[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[2],",",y[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[2],",",y[2],")\tf(x(4))=",fxx[4])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[2]
    elif fxx[3]==fmin:
        x0=x[2]
        y0=y[1]
    elif fxx[4]==fmin:
        x0=x[2]
        y0=y[2]
    print("min lies in (",x0,",",y0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
        delx=delx/2
        dely=dely/2
        if i<s:
            print("")
            print("the new delx and dely values are:",delx,dely)
        if i<=s :
            i=i+1
            j=j+1
        else:
            break
    else:
        i=i+1
        j=j+1
# Out:
# Enter the intital value of x0-0.25
# Enter the intital value of y00.25
# enter the vlue of n - no. of variables used2
# Enter the x value in the reduction parameter1
# Enter the y value in the reduction parameter1
# enter the number of iterations4
#
# Interation no. :  1
# x(0)=( -0.25 , 0.25 )	f(x(0))= 25.3750
# x(1)=( 0.25 , 0.75 )	f(x(1))= 24.3750
# x(2)=( 0.25 , -0.25 )	f(x(2))= 24.8750
# x(3)=( -0.75 , 0.75 )	f(x(3))= 26.8750
# x(4)=( -0.75 , -0.25 )	f(x(4))= 27.3750
# fmin= 24.3750
# min lies in ( 0.25 , 0.75 )
#
# Interation no. :  2
# x(0)=( 0.25 , 0.75 )	f(x(0))= 24.3750
# x(1)=( 0.75 , 1.25 )	f(x(1))= 24.3750
# x(2)=( 0.75 , 0.25 )	f(x(2))= 23.8750
# x(3)=( -0.25 , 1.25 )	f(x(3))= 25.8750
# x(4)=( -0.25 , 0.25 )	f(x(4))= 25.3750
# fmin= 23.8750
# min lies in ( 0.75 , 0.25 )
#
# Interation no. :  3
# x(0)=( 0.75 , 0.25 )	f(x(0))= 23.8750
# x(1)=( 1.25 , 0.75 )	f(x(1))= 23.8750
# x(2)=( 1.25 , -0.25 )	f(x(2))= 24.3750
# x(3)=( 0.25 , 0.75 )	f(x(3))= 24.3750
# x(4)=( 0.25 , -0.25 )	f(x(4))= 24.8750
# fmin= 23.8750
# min lies in ( 0.75 , 0.25 )
#
# the new delx and dely values are: 0.5 0.5
#
# Interation no. :  4
# x(0)=( 0.75 , 0.25 )	f(x(0))= 23.8750
# x(1)=( 1.00 , 0.50 )	f(x(1))= 23.7500
# x(2)=( 1.00 , 0.00 )	f(x(2))= 24.0000
# x(3)=( 0.50 , 0.50 )	f(x(3))= 24.0000
# x(4)=( 0.50 , 0.00 )	f(x(4))= 24.2500
# fmin= 23.7500
# min lies in ( 1.00 , 0.50 )

# %% [markdown]
# ##

# %%
#for 3 variables- vrus code - which she decided not to do 
import math
from decimal import Decimal
x0=Decimal(input(("Enter the intital value of x0")))
y0=Decimal(input(("Enter the intital value of y0")))
z0=Decimal(input(("Enter the intital value of z0")))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
i=1
j=0
while True:
    k=0
    x=[]
    y=[]
    z=[]
    x.append((x0))
    y.append((y0))
    z.append(z0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    z.append(Decimal(z[k]+(delz/2)))
    z.append(Decimal(z[k]-(delz/2)))
    print("x(0)=(",x0,",",y0,",",z0,")")
    print("x(1)=(",x[1],",",y[1],",",z[1],")")
    print("x(2)=(",x[1],",",y[1],",",z[2],")")
    print("x(3)=(",x[1],",",y[2],",",z[1],")")
    print("x(4)=(",x[1],",",y[2],",",z[2],")")
    print("x(5)=(",x[2],",",y[1],",",z[1],")")
    print("x(6)=(",x[2],",",y[1],",",z[2],")")
    print("x(7)=(",x[2],",",y[2],",",z[1],")")
    print("x(8)=(",x[2],",",y[2],",",z[2],")")
    break
# Out:
# Enter the intital value of x01
# Enter the intital value of y02
# Enter the intital value of z07
# Enter the x value in the reduction parameter4
# Enter the y value in the reduction parameter4
# Enter the z value in the reduction parameter4
# x(0)=( 1 , 2 , 7 )
# x(1)=( 3 , 4 , 9 )
# x(2)=( 3 , 4 , 5 )
# x(3)=( 3 , 0 , 9 )
# x(4)=( 3 , 0 , 5 )
# x(5)=( -1 , 4 , 9 )
# x(6)=( -1 , 4 , 5 )
# x(7)=( -1 , 0 , 9 )
# x(8)=( -1 , 0 , 5 )

# %%
#Evolutionary search method - with termination parameter for 3 variables 
import math
from decimal import Decimal
def f(x,y,z):
    return Decimal((((x**2)-y-11)**2)+((x+(y**2)-7)**2)+z)#function
x0=Decimal(input(("Enter the intital value of x0")))
y0=Decimal(input(("Enter the intital value of y0")))
z0=Decimal(input(("Enter the intital value of z0")))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
E=Decimal(input(("enter the termination parameter")))
i=1
j=0
fminb=[]
while True:
    k=0
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    fxx=[]
    x.append((x0))
    y.append((y0))
    z.append(z0)
    f0=f(x0,y0,z0)
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    z.append(Decimal(z[k]+(delz/2)))
    z.append(Decimal(z[k]-(delz/2)))
    fxx.append(f(x[1],y[1],z[1]))
    fxx.append(f(x[1],y[1],z[2]))
    fxx.append(f(x[1],y[2],z[1]))
    fxx.append(f(x[1],y[2],z[2]))
    fxx.append(f(x[2],y[1],z[1]))
    fxx.append(f(x[2],y[1],z[2]))
    fxx.append(f(x[2],y[2],z[1]))
    fxx.append(f(x[2],y[2],z[2]))
    print("x(0)=(",x0,",",y0,",",z0,")\tf(x(0))=",fxx[0])
    print("x(1)=(",x[1],",",y[1],",",z[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[1],",",z[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[1],",",y[2],",",z[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[1],",",y[2],",",z[2],")\tf(x(4))=",fxx[4])
    print("x(5)=(",x[2],",",y[1],",",z[1],")\tf(x(5))=",fxx[5])
    print("x(6)=(",x[2],",",y[1],",",z[2],")\tf(x(6))=",fxx[6])
    print("x(7)=(",x[2],",",y[2],",",z[1],")\tf(x(7))=",fxx[7])
    print("x(8)=(",x[2],",",y[2],",",z[2],")\tf(x(8))=",fxx[8])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
        z0=z0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[2]
    elif fxx[3]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[1]
    elif fxx[4]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[2]
    elif fxx[5]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[1]
    elif fxx[6]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[2]
    elif fxx[7]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[1]
    elif fxx[8]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[2]
    print("min lies in (",x0,",",y0,",",z0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
            mag=(((delx/2)**2)+((dely/2)**2)+((delz/2)**2))
            if mag<E:
                print("")
                print("||del/2||<E, so therefore")
                print("min lies in (",x0,",",y0,",",z0,")")
                break
            else:
                delx=delx/2
                dely=dely/2
                delz=delz/2
                print("")
                print("the new delx,dely and delz values are:",delx,dely)
                i=i+1
                j=j+1
                continue
    else:
        i=i+1
        j=j+1
        continue
# Out:
# Enter the intital value of x01
# Enter the intital value of y02
# Enter the intital value of z03
# Enter the x value in the reduction parameter4
# Enter the y value in the reduction parameter4
# Enter the z value in the reduction parameter4
# enter the termination parameter0.5
#
# Interation no. :  1
# x(0)=( 1 , 2 , 3 )	f(x(0))= 151
# x(1)=( 3 , 4 , 9 )	f(x(1))= 189
# x(2)=( 3 , 4 , 5 )	f(x(2))= 185
# x(3)=( 3 , 0 , 9 )	f(x(3))= 29
# x(4)=( 3 , 0 , 5 )	f(x(4))= 25
# x(5)=( -1 , 4 , 9 )	f(x(5))= 269
# x(6)=( -1 , 4 , 5 )	f(x(6))= 265
# x(7)=( -1 , 0 , 9 )	f(x(7))= 173
# x(8)=( -1 , 0 , 5 )	f(x(8))= 169
# fmin= 25
# min lies in ( 3 , 0 , 5 )
#
# Interation no. :  2
# x(0)=( 3 , 0 , 5 )	f(x(0))= 25
# x(1)=( 5 , 2 , 9 )	f(x(1))= 157
# x(2)=( 5 , 2 , 5 )	f(x(2))= 153
# x(3)=( 5 , -2 , 9 )	f(x(3))= 269
# x(4)=( 5 , -2 , 5 )	f(x(4))= 265
# x(5)=( 1 , 2 , 9 )	f(x(5))= 157
# x(6)=( 1 , 2 , 5 )	f(x(6))= 153
# x(7)=( 1 , -2 , 9 )	f(x(7))= 77
# x(8)=( 1 , -2 , 5 )	f(x(8))= 73
# fmin= 25
# min lies in ( 3 , 0 , 5 )
#
# the new delx,dely and delz values are: 2 2
#
# Interation no. :  3
# x(0)=( 3 , 0 , 5 )	f(x(0))= 25
# x(1)=( 4 , 1 , 9 )	f(x(1))= 29
# x(2)=( 4 , 1 , 5 )	f(x(2))= 25
# x(3)=( 4 , -1 , 9 )	f(x(3))= 49
# x(4)=( 4 , -1 , 5 )	f(x(4))= 45
# x(5)=( 2 , 1 , 9 )	f(x(5))= 89
# x(6)=( 2 , 1 , 5 )	f(x(6))= 85
# x(7)=( 2 , -1 , 9 )	f(x(7))= 61
# x(8)=( 2 , -1 , 5 )	f(x(8))= 57
# fmin= 25
# min lies in ( 3 , 0 , 5 )
#
# the new delx,dely and delz values are: 1 1
#
# Interation no. :  4
# x(0)=( 3 , 0 , 5 )	f(x(0))= 25
# x(1)=( 3.5 , 0.5 , 9 )	f(x(1))= 20.1250
# x(2)=( 3.5 , 0.5 , 5 )	f(x(2))= 16.1250
# x(3)=( 3.5 , -0.5 , 9 )	f(x(3))= 22.6250
# x(4)=( 3.5 , -0.5 , 5 )	f(x(4))= 18.6250
# x(5)=( 2.5 , 0.5 , 9 )	f(x(5))= 54.6250
# x(6)=( 2.5 , 0.5 , 5 )	f(x(6))= 50.6250
# x(7)=( 2.5 , -0.5 , 9 )	f(x(7))= 45.1250
# x(8)=( 2.5 , -0.5 , 5 )	f(x(8))= 41.1250
# fmin= 16.1250
# min lies in ( 3.5 , 0.5 , 5 )
#
# Interation no. :  5
# x(0)=( 3.5 , 0.5 , 5 )	f(x(0))= 16.1250
# x(1)=( 4.0 , 1.0 , 9 )	f(x(1))= 29.0000
# x(2)=( 4.0 , 1.0 , 5 )	f(x(2))= 25.0000
# x(3)=( 4.0 , 0.0 , 9 )	f(x(3))= 43.0000
# x(4)=( 4.0 , 0.0 , 5 )	f(x(4))= 39.0000
# x(5)=( 3.0 , 1.0 , 9 )	f(x(5))= 27.0000
# x(6)=( 3.0 , 1.0 , 5 )	f(x(6))= 23.0000
# x(7)=( 3.0 , 0.0 , 9 )	f(x(7))= 29.0000
# x(8)=( 3.0 , 0.0 , 5 )	f(x(8))= 25.0000
# fmin= 16.1250
# min lies in ( 3.5 , 0.5 , 5 )
#
# the new delx,dely and delz values are: 0.5 0.5
#
# Interation no. :  6
# x(0)=( 3.5 , 0.5 , 5 )	f(x(0))= 16.1250
# x(1)=( 3.75 , 0.75 , 9 )	f(x(1))= 21.57031250
# x(2)=( 3.75 , 0.75 , 5 )	f(x(2))= 17.57031250
# x(3)=( 3.75 , 0.25 , 9 )	f(x(3))= 27.07031250
# x(4)=( 3.75 , 0.25 , 5 )	f(x(4))= 23.07031250
# x(5)=( 3.25 , 0.75 , 9 )	f(x(5))= 20.57031250
# x(6)=( 3.25 , 0.75 , 5 )	f(x(6))= 16.57031250
# x(7)=( 3.25 , 0.25 , 9 )	f(x(7))= 23.07031250
# x(8)=( 3.25 , 0.25 , 5 )	f(x(8))= 19.07031250
# fmin= 16.1250
# min lies in ( 3.5 , 0.5 , 5 )
#
# ||del/2||<E, so therefore
# min lies in ( 3.5 , 0.5 , 5 )

# %%
#no. of iterations given for 3 variables , no terminatopn parameter 
import math
from decimal import Decimal
def f(x,y,z):
    return Decimal((((x**2)-y-11)**2)+((x+(y**2)-7)**2)+z)#function
x0=Decimal(input(("Enter the intital value of x0")))
y0=Decimal(input(("Enter the intital value of y0")))
z0=Decimal(input(("Enter the intital value of z0")))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
s=Decimal(input(("enter the number of iterations")))
i=1
j=0
fminb=[]
while i<=s:
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    fxx=[]
    x.append((x0))
    y.append((y0))
    z.append(z0)
    f0=f(x0,y0,z0)
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    z.append(Decimal(z[k]+(delz/2)))
    z.append(Decimal(z[k]-(delz/2)))
    fxx.append(f(x[1],y[1],z[1]))
    fxx.append(f(x[1],y[1],z[2]))
    fxx.append(f(x[1],y[2],z[1]))
    fxx.append(f(x[1],y[2],z[2]))
    fxx.append(f(x[2],y[1],z[1]))
    fxx.append(f(x[2],y[1],z[2]))
    fxx.append(f(x[2],y[2],z[1]))
    fxx.append(f(x[2],y[2],z[2]))
    print("x(0)=(",x0,",",y0,",",z0,")\tf(x(0))=",fxx[0])
    print("x(1)=(",x[1],",",y[1],",",z[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[1],",",z[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[1],",",y[2],",",z[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[1],",",y[2],",",z[2],")\tf(x(4))=",fxx[4])
    print("x(5)=(",x[2],",",y[1],",",z[1],")\tf(x(5))=",fxx[5])
    print("x(6)=(",x[2],",",y[1],",",z[2],")\tf(x(6))=",fxx[6])
    print("x(7)=(",x[2],",",y[2],",",z[1],")\tf(x(7))=",fxx[7])
    print("x(8)=(",x[2],",",y[2],",",z[2],")\tf(x(8))=",fxx[8])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
        z0=z0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[2]
    elif fxx[3]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[1]
    elif fxx[4]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[2]
    elif fxx[5]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[1]
    elif fxx[6]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[2]
    elif fxx[7]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[1]
    elif fxx[8]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[2]
    print("min lies in (",x0,",",y0,",",z0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
        delx=delx/2
        dely=dely/2
        delz=delz/2
        if i<s:
            print("")
            print("the new delx,dely and delz values are:",delx,dely,delz)
        if i<=s :
            i=i+1
            j=j+1
        else:
            break
    else:
        i=i+1
        j=j+1
# Out:
# Enter the intital value of x01
# Enter the intital value of y02
# Enter the intital value of z03
# Enter the x value in the reduction parameter4
# Enter the y value in the reduction parameter4
# Enter the z value in the reduction parameter4
# enter the number of iterations6
#
# Interation no. :  1
# x(0)=( 1 , 2 , 3 )	f(x(0))= 151
# x(1)=( 3 , 4 , 9 )	f(x(1))= 189
# x(2)=( 3 , 4 , 5 )	f(x(2))= 185
# x(3)=( 3 , 0 , 9 )	f(x(3))= 29
# x(4)=( 3 , 0 , 5 )	f(x(4))= 25
# x(5)=( -1 , 4 , 9 )	f(x(5))= 269
# x(6)=( -1 , 4 , 5 )	f(x(6))= 265
# x(7)=( -1 , 0 , 9 )	f(x(7))= 173
# x(8)=( -1 , 0 , 5 )	f(x(8))= 169
# fmin= 25
# min lies in ( 3 , 0 , 5 )
#
# Interation no. :  2
# x(0)=( 3 , 0 , 5 )	f(x(0))= 25
# x(1)=( 5 , 2 , 9 )	f(x(1))= 157
# x(2)=( 5 , 2 , 5 )	f(x(2))= 153
# x(3)=( 5 , -2 , 9 )	f(x(3))= 269
# x(4)=( 5 , -2 , 5 )	f(x(4))= 265
# x(5)=( 1 , 2 , 9 )	f(x(5))= 157
# x(6)=( 1 , 2 , 5 )	f(x(6))= 153
# x(7)=( 1 , -2 , 9 )	f(x(7))= 77
# x(8)=( 1 , -2 , 5 )	f(x(8))= 73
# fmin= 25
# min lies in ( 3 , 0 , 5 )
#
# the new delx,dely and delz values are: 2 2 2
#
# Interation no. :  3
# x(0)=( 3 , 0 , 5 )	f(x(0))= 25
# x(1)=( 4 , 1 , 9 )	f(x(1))= 29
# x(2)=( 4 , 1 , 5 )	f(x(2))= 25
# x(3)=( 4 , -1 , 9 )	f(x(3))= 49
# x(4)=( 4 , -1 , 5 )	f(x(4))= 45
# x(5)=( 2 , 1 , 9 )	f(x(5))= 89
# x(6)=( 2 , 1 , 5 )	f(x(6))= 85
# x(7)=( 2 , -1 , 9 )	f(x(7))= 61
# x(8)=( 2 , -1 , 5 )	f(x(8))= 57
# fmin= 25
# min lies in ( 3 , 0 , 5 )
#
# the new delx,dely and delz values are: 1 1 1
#
# Interation no. :  4
# x(0)=( 3 , 0 , 5 )	f(x(0))= 25
# x(1)=( 3.5 , 0.5 , 9 )	f(x(1))= 20.1250
# x(2)=( 3.5 , 0.5 , 5 )	f(x(2))= 16.1250
# x(3)=( 3.5 , -0.5 , 9 )	f(x(3))= 22.6250
# x(4)=( 3.5 , -0.5 , 5 )	f(x(4))= 18.6250
# x(5)=( 2.5 , 0.5 , 9 )	f(x(5))= 54.6250
# x(6)=( 2.5 , 0.5 , 5 )	f(x(6))= 50.6250
# x(7)=( 2.5 , -0.5 , 9 )	f(x(7))= 45.1250
# x(8)=( 2.5 , -0.5 , 5 )	f(x(8))= 41.1250
# fmin= 16.1250
# min lies in ( 3.5 , 0.5 , 5 )
#
# Interation no. :  5
# x(0)=( 3.5 , 0.5 , 5 )	f(x(0))= 16.1250
# x(1)=( 4.0 , 1.0 , 9 )	f(x(1))= 29.0000
# x(2)=( 4.0 , 1.0 , 5 )	f(x(2))= 25.0000
# x(3)=( 4.0 , 0.0 , 9 )	f(x(3))= 43.0000
# x(4)=( 4.0 , 0.0 , 5 )	f(x(4))= 39.0000
# x(5)=( 3.0 , 1.0 , 9 )	f(x(5))= 27.0000
# x(6)=( 3.0 , 1.0 , 5 )	f(x(6))= 23.0000
# x(7)=( 3.0 , 0.0 , 9 )	f(x(7))= 29.0000
# x(8)=( 3.0 , 0.0 , 5 )	f(x(8))= 25.0000
# fmin= 16.1250
# min lies in ( 3.5 , 0.5 , 5 )
#
# the new delx,dely and delz values are: 0.5 0.5 0.5
#
# Interation no. :  6
# x(0)=( 3.5 , 0.5 , 5 )	f(x(0))= 16.1250
# x(1)=( 3.75 , 0.75 , 9 )	f(x(1))= 21.57031250
# x(2)=( 3.75 , 0.75 , 5 )	f(x(2))= 17.57031250
# x(3)=( 3.75 , 0.25 , 9 )	f(x(3))= 27.07031250
# x(4)=( 3.75 , 0.25 , 5 )	f(x(4))= 23.07031250
# x(5)=( 3.25 , 0.75 , 9 )	f(x(5))= 20.57031250
# x(6)=( 3.25 , 0.75 , 5 )	f(x(6))= 16.57031250
# x(7)=( 3.25 , 0.25 , 9 )	f(x(7))= 23.07031250
# x(8)=( 3.25 , 0.25 , 5 )	f(x(8))= 19.07031250
# fmin= 16.1250
# min lies in ( 3.5 , 0.5 , 5 )

# %%
def f(x):
    return (2**x)
y=Decimal(input("Enter the number of variables used"))
print("the number of variables computed in each iteration of ",y,"variables is ",f(y))
# Out:
# Enter the number of variables used7
# the number of variables computed in each iteration of  7 variables is  128
