# %%
import math
import numpy as np
def f(x):
    f=2*(x**2)+(16/x)
    return f
def invf(f,C):
    if f==C[0][0]:
        a=0
    elif f==C[1][0]:
        a=1
    elif f==C[2][0]:
        a=2
    elif f==C[3][0]:
        a=3
    return a
xi=float(input("initial search value:"))
s=float(input("Del value :"))
t=float(input("termination Parameter:"))
x1=xi
x2=xi+s
f1=f(x1)
f2=f(x2)
i=1
if f1>=f2:
    x3=x2+s
else:
    x3=x1-s
f3=f(x3)
while True:
    print("")
    print("the iteration no. = ",i)
    f1=f(x1)
    f2=f(x2)
    f3=f(x3)
    print("")
    print("x1 =",x1,",x2 =",x2 ,",x3 = ",x3)
    print("fx1 =",f1," ,fx2 =",f2," ,fx3 =",f3)
    a0=f1
    a1=(f2-f1)/(x2-x1)
    a2=(1/(x3-x2))*(((f3-f1)/(x3-x1))-((f2-f1)/(x2-x1)))
    print("a0 =",a0," ,a1 =",a1," ,a2=",a2)
    i=i+1
    Fmin=min(f1,f2,f3)
    if Fmin==f1:
        Xmin=x1
    elif Fmin==f2:
        Xmin=x2
    else:
        Xmin=x3
    print("Fmin =",Fmin)
    print("Xmin=",Xmin)
    xp=(0.5*(x1+x2))-(a1/(2*a2))
    fp=f(xp)
    C=np.array(((f1,x1),(f2,x2),(f3,x3),(fp,xp)))
    if abs(Fmin-fp)<t and abs(Xmin-xp)<t:
        f4=min(f1,f2,f3,fp)
        a=invf(f4,C)
        x4=C[a][1]
        break
    Fmax=max(f1,f2,f3,fp)
    a=invf(Fmax,C)
    if a==0:
        K=np.array((C[1][1],C[2][1],C[3][1]))
    elif a==1:
        K=np.array((C[0][1],C[2][1],C[3][1]))
    elif a==2:
        K=np.array((C[0][1],C[1][1],C[3][1]))
    else:
        K=np.array((C[0][1],C[1][1],C[2][1]))
    Kp=np.sort(K)
    x1=Kp[0]
    x2=Kp[1]
    x3=Kp[2]
print("the minimum lies in ",x4,", with a function value of",f4)
# Out:
# initial search value:1
# Del value :2
# termination Parameter:0.1
#
# the iteration no. =  1
#
# x1 = 1.0 ,x2 = 3.0 ,x3 =  -1.0
# fx1 = 18.0  ,fx2 = 23.333333333333332  ,fx3 = -14.0
# a0 = 18.0  ,a1 = 2.666666666666666  ,a2= -3.3333333333333335
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  2
#
# x1 = -1.0 ,x2 = 1.0 ,x3 =  2.4
# fx1 = -14.0  ,fx2 = 18.0  ,fx3 = 18.186666666666667
# a0 = -14.0  ,a1 = 16.0  ,a2= -4.666666666666667
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  3
#
# x1 = -1.0 ,x2 = 1.0 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 18.0  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 16.0  ,a2= -7.333333333333333
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  4
#
# x1 = -1.0 ,x2 = 1.090909090909091 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 17.046831955922862  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 14.848484848484848  ,a2= -6.555555555555555
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  5
#
# x1 = -1.0 ,x2 = 1.1779661016949152 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 16.35794208643427  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 13.938666016339472  ,a2= -5.923261390887291
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  6
#
# x1 = -1.0 ,x2 = 1.2655870445344128 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.845775581163796  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 13.173528535645923  ,a2= -5.374706760503308
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  7
#
# x1 = -1.0 ,x2 = 1.35830489643679 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.469372090776597  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 12.495997500281858  ,a2= -4.871309495988158
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  8
#
# x1 = -1.0 ,x2 = 1.4617641885084678 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.21918700396715  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.869206295372447  ,a2= -4.384978785707377
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  9
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  11
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  12
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  13
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  14
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  15
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  16
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  17
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  18
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  19
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  20
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  21
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  22
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  23
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  24
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  25
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  26
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  27
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  28
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  29
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  30
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  31
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  32
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  33
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  34
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  35
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  36
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  37
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  38
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  39
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  40
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  41
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  42
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  43
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  44
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  45
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  46
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  47
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  48
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  49
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  50
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  51
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  52
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  53
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  54
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  55
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  56
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  57
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  58
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  59
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  60
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  61
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  62
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  63
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  64
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  65
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  66
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  67
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  68
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  69
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  70
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  71
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  72
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  73
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  74
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  75
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  76
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  77
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  78
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  79
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  80
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  81
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  82
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  83
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  84
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  85
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  86
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  87
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  88
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  89
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  90
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  91
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  92
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  93
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  94
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  95
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  96
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  97
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  98
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  99
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  100
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  101
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  102
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  103
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  104
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  105
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  106
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  107
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  108
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  109
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  110
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  111
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  112
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  113
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  114
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  115
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  116
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  117
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  118
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  119
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  120
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  121
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  122
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  123
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  124
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  125
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  126
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  127
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  128
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  129
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  130
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  131
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  132
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  133
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  134
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  135
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  136
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  137
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  138
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  139
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  140
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  141
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  142
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  143
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  144
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  145
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  146
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  147
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  148
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  149
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  150
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  151
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  152
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  153
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  154
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  155
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  156
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  157
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  158
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  159
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  160
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  161
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  162
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  163
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  164
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  165
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  166
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  167
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  168
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  169
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  170
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  171
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  172
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  173
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  174
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  175
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  176
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  177
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  178
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  179
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  180
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  181
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  182
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  183
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  184
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  185
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  186
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  187
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  188
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  189
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  190
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  191
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  192
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  193
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  194
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  195
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  196
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  197
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  198
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  199
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  200
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  201
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  202
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# ...
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10358
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10359
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10360
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10361
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10362
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10363
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10364
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10365
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10366
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10367
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10368
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10369
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10370
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10371
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10372
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10373
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10374
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10375
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10376
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10377
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10378
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10379
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10380
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10381
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10382
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10383
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10384
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10385
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10386
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10387
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10388
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10389
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10390
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10391
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10392
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10393
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10394
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10395
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10396
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10397
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10398
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10399
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10400
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10401
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10402
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10403
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10404
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10405
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10406
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10407
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10408
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10409
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10410
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10411
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10412
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10413
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10414
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10415
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 = 15.210884353741497
# a0 = -14.0  ,a1 = 11.267802799873762  ,a2= -3.891229744396761
# Fmin = -14.0
# Xmin= -1.0
#
# the iteration no. =  10416
#
# x1 = -1.0 ,x2 = 1.584275904739651 ,x3 =  1.7142857142857142
# fx1 = -14.0  ,fx2 = 15.119111275071738  ,fx3 =
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ca841db06c69> in <module>
#      35     print("")
#      36     print("x1 =",x1,",x2 =",x2 ,",x3 = ",x3)
# ---> 37     print("fx1 =",f1," ,fx2 =",f2," ,fx3 =",f3)
#      38     a0=f1
#      39     a1=(f2-f1)/(x2-x1)
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import math
import numpy as np
def f(x):
    f=(648/(x**2))+(x**3)
    return f
def invf(f,C):
    if f==C[0][0]:
        a=0
    elif f==C[1][0]:
        a=1
    elif f==C[2][0]:
        a=2
    elif f==C[3][0]:
        a=3
    return a
xi=float(input("initial search value:"))
s=float(input("Del value :"))
j=float(input("enter the number of iterations"))
i=1
x1=xi
x2=xi+s
f1=f(x1)
f2=f(x2)
if f1>=f2:
    x3=x2+s
else:
    x3=x1-s
f3=f(x3)
while True:
    print("")
    print("iteration number=",i)
    f1=f(x1)
    f2=f(x2)
    f3=f(x3)
    i=i+1
    print("")
    print("x1 =",x1,",x2 =",x2 ,",x3 = ",x3)
    print("fx1 =",f1," ,fx2 =",f2," ,fx3 =",f3)
    a0=f1
    a1=(f2-f1)/(x2-x1)
    a2=(1/(x3-x2))*(((f3-f1)/(x3-x1))-((f2-f1)/(x2-x1)))
    print("a0 =",a0," ,a1 =",a1," ,a2=",a2)
    Fmin=min(f1,f2,f3)
    if Fmin==f1:
        Xmin=x1
    elif Fmin==f2:
        Xmin=x2
    else:
        Xmin=x3
    print("Fmin =",Fmin)
    print("Xmin=",Xmin)
    xp=(0.5*(x1+x2))-(a1/(2*a2))
    fp=f(xp)
    C=np.array(((f1,x1),(f2,x2),(f3,x3),(fp,xp)))
    if i>j:
        f4=min(f1,f2,f3,fp)
        a=invf(f4,C)
        x4=C[a][1]
        break
    Fmax=max(f1,f2,f3,fp)
    a=invf(Fmax,C)
    if a==0:
        K=np.array((C[1][1],C[2][1],C[3][1]))
    elif a==1:
        K=np.array((C[0][1],C[2][1],C[3][1]))
    elif a==2:
        K=np.array((C[0][1],C[1][1],C[3][1]))
    else:
        K=np.array((C[0][1],C[1][1],C[2][1]))
    Kp=np.sort(K)
    x1=Kp[0]
    x2=Kp[1]
    x3=Kp[2]
print("the minimum lies in ",x4,", with a function value of",f4)
# Out:
# initial search value:1
# Del value :1
# enter the number of iterations2
#
# iteration number= 1
#
# x1 = 1.0 ,x2 = 2.0 ,x3 =  3.0
# fx1 = 649.0  ,fx2 = 170.0  ,fx3 = 99.0
# a0 = 649.0  ,a1 = -479.0  ,a2= 204.0
# Fmin = 99.0
# Xmin= 3.0
#
# iteration number= 2
#
# x1 = 2.0 ,x2 = 2.674019607843137 ,x3 =  3.0
# fx1 = 170.0  ,fx2 = 109.74480191167102  ,fx3 = 99.0
# a0 = 170.0  ,a1 = -89.39680298195721  ,a2= 56.43530538825968
# Fmin = 99.0
# Xmin= 3.0
# the minimum lies in  3.1290388570730605 , with a function value of 96.82006948643718

# %%
import math
from decimal import Decimal
def f(x):
    return Decimal(-3+(x**2)+(16/x))
a=Decimal(input("enter the starting interval"))
E=Decimal(input("enter the termination parameter"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a)
    i=i+1
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*a
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
    print("f'a =",diff_fa)
    diff2_fa=(f(a+dela)+f(a-dela)-(2*f(a)))/(dela**2)
    print("f\"a =",diff2_fa)
    a1=(a)-(diff_fa/diff2_fa)
    print("a1=",a1)
    if a1 < -0.01 or a1 > 0.01:
        dela1=Decimal(0.01)*a1
    elif a1>=-0.01 and a1<=0.01:
        dela1=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    diff_fa1=(f(a1+dela1)-f(a1-dela1))/(2*dela1)
    print("f'a1 =",diff_fa1)
    if abs(diff_fa1)<E:
        print("the minimum lies on ",a1)
        break
    else:
        a=a1
        continue
# Out:
# enter the starting interval1
# enter the termination parameter0.01
#
# iteration no. =  1
# a = 1
# the value of del a is  0.010000
# f'a = -14.001600160016001600160016
# f"a = 34.00320032003200320032
# a1= 1.411773010429473114547733021
# f'a1 = -5.204940161370387815453520704
#
# iteration no. =  2
# a = 1.411773010429473114547733021
# the value of del a is  0.014118
# f'a = -5.204940192070668302760916915
# f"a = 13.37362189759851284000875907
# a1= 1.800967518239306882616601743
# f'a1 = -1.331525449642917196116297800
#
# iteration no. =  3
# a = 1.800967518239306882616601743
# the value of del a is  0.018010
# f'a = -1.331525467440568007640259578
# f"a = 7.478677937226005098737730072
# a1= 1.979010412801291201647350111
# f'a1 = -0.1276865224135564357705823151
#
# iteration no. =  4
# a = 1.979010412801291201647350111
# the value of del a is  0.019790
# f'a = -0.1276865181136496454945338050
# f"a = 6.129040774406951454585400367
# a1= 1.999843447335313313177764548
# f'a1 = -0.001339492160688280980370570616
# the minimum lies on  1.999843447335313313177764548

# %%
import math
import numpy as np
def f(x):
    f=(((x**2)-3)**2)+(((2*(x**3))-5)**2)
    return f
def invf(f,C):
    if f==C[0][0]:
        a=0
    elif f==C[1][0]:
        a=1
    elif f==C[2][0]:
        a=2
    elif f==C[3][0]:
        a=3
    return a
xi=float(input("initial search value:"))
s=float(input("Del value :"))
j=float(input("enter the number of iterations"))
i=1
x1=xi
x2=xi+s
f1=f(x1)
f2=f(x2)
if f1>=f2:
    x3=x2+s
else:
    x3=x1-s
f3=f(x3)
while True:
    print("")
    print("iteration number=",i)
    f1=f(x1)
    f2=f(x2)
    f3=f(x3)
    i=i+1
    print("")
    print("x1 =",x1,",x2 =",x2 ,",x3 = ",x3)
    print("fx1 =",f1," ,fx2 =",f2," ,fx3 =",f3)
    a0=f1
    a1=(f2-f1)/(x2-x1)
    a2=(1/(x3-x2))*(((f3-f1)/(x3-x1))-((f2-f1)/(x2-x1)))
    print("a0 =",a0," ,a1 =",a1," ,a2=",a2)
    Fmin=min(f1,f2,f3)
    if Fmin==f1:
        Xmin=x1
    elif Fmin==f2:
        Xmin=x2
    else:
        Xmin=x3
    print("Fmin =",Fmin)
    print("Xmin=",Xmin)
    xp=(0.5*(x1+x2))-(a1/(2*a2))
    fp=f(xp)
    C=np.array(((f1,x1),(f2,x2),(f3,x3),(fp,xp)))
    if i>j:
        f4=min(f1,f2,f3,fp)
        a=invf(f4,C)
        x4=C[a][1]
        break
    Fmax=max(f1,f2,f3,fp)
    a=invf(Fmax,C)
    if a==0:
        K=np.array((C[1][1],C[2][1],C[3][1]))
    elif a==1:
        K=np.array((C[0][1],C[2][1],C[3][1]))
    elif a==2:
        K=np.array((C[0][1],C[1][1],C[3][1]))
    else:
        K=np.array((C[0][1],C[1][1],C[2][1]))
    Kp=np.sort(K)
    x1=Kp[0]
    x2=Kp[1]
    x3=Kp[2]
print("the minimum lies in ",x4,", with a function value of",f4)
# Out:
# initial search value:0
# Del value :1
# enter the number of iterations1
#
# iteration number= 1
#
# x1 = 0.0 ,x2 = 1.0 ,x3 =  2.0
# fx1 = 34.0  ,fx2 = 13.0  ,fx3 = 122.0
# a0 = 34.0  ,a1 = -21.0  ,a2= 65.0
# Fmin = 13.0
# Xmin= 1.0
# the minimum lies in  1.0 , with a function value of 13.0

# %%
#bisection - question 5
import math
from decimal import Decimal
def f(x):
    return Decimal(Decimal(math.exp(((x-Decimal(0.2))**2)/(2))))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
E=Decimal(input("enter the termination parameter"))
i=1
if a < -0.01 or a > 0.01:
    dela=Decimal(0.01)*a
elif a>=-0.01 and a<=0.01:
    dela=0.001
else:
    print("invalid , try again")
dela=round(dela,6)
print("the value of del a is ",dela)
if b < -0.01 or b > 0.01:
    delb=Decimal(0.01)*b
elif b>=-0.01 and b<=0.01:
    delb=0.001
else:
    print("invalid , try again")
delb=round(delb,6)
print("the value of del b is ",delb)
diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
diff_fb=(f(b+delb)-f(b-delb))/(2*delb)
print("f'a =",diff_fa," ,f'b =",diff_fb)
if diff_fa<0 and diff_fb>0:
    print("the minimum lies between",a,"and",b)
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    i=i+1
    z=(a+b)/2
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if abs(diff_fz)<E:
        print("the minimum lies on ",z,"or lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval-0.5
# enter the ending interval1
# enter the termination parameter0.2
# the value of del a is  -0.005000
# the value of del b is  0.010000
# f'a = -0.8943479244575058828559122048  ,f'b = 1.101769050071943478741332001
# the minimum lies between -0.5 and 1
#
# iteration no. =  1
# a = -0.5 ,b= 1
# the value of z= 0.25 ,the value of delz = 0.002500
# f'z = 0.05006269565486221040373493452
# the minimum lies on  0.25 or lies in the interval ( -0.5 , 1 )

# %%
#secant method - question 5
import math
from decimal import Decimal
def f(x):
    return Decimal(Decimal(math.exp(((x-Decimal(0.2))**2)/(2))))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
E=Decimal(input("enter the termination parameter"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*abs(a)
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    if b < -0.01 or b > 0.01:
        delb=Decimal(0.01)*abs(b)
    elif b>=-0.01 and b<=0.01:
        delb=0.001
    else:
        print("invalid , try again")
    delb=round(delb,6)
    print("the value of del b is ",delb)
    diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
    diff_fb=(f(b+delb)-f(b-delb))/(2*delb)
    print("f'a =",diff_fa," ,f'b =",diff_fb)
    if diff_fa<0 and diff_fb>0:
        print("the minimum lies between",a,"and",b)
    i=i+1
    z=b-(((b-a)/(diff_fb-diff_fa))*diff_fb)
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if abs(diff_fz)<E:
        b=z
        print("the minimum lies on lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval-0.5
# enter the ending interval1
# enter the termination parameter0.2
#
# iteration no. =  1
# a = -0.5 ,b= 1
# the value of del a is  0.005000
# the value of del b is  0.010000
# f'a = -0.8943479244575058828559122048  ,f'b = 1.101769050071943478741332001
# the minimum lies between -0.5 and 1
# the value of z= 0.1720657675898476842880960117 ,the value of delz = 0.001721
# f'z = -0.02794517477071495011393620388
# the minimum lies on lies in the interval ( -0.5 , 0.1720657675898476842880960117 )

# %%
import math
from decimal import Decimal
def f(x):
    return Decimal((x**4)+(3*((x-1)**2)))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
j=Decimal(input("enter the iterations"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*abs(a)
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    if b < -0.01 or b > 0.01:
        delb=Decimal(0.01)*abs(b)
    elif b>=-0.01 and b<=0.01:
        delb=0.001
    else:
        print("invalid , try again")
    delb=round(delb,6)
    print("the value of del b is ",delb)
    diff_fa=(f(a+Decimal(dela))-f(a-Decimal(dela)))/(2*Decimal(dela))
    diff_fb=(f(b+Decimal(delb))-f(b-Decimal(delb)))/(2*Decimal(delb))
    print("f'a =",diff_fa," ,f'b =",diff_fb)
    if diff_fa<0 and diff_fb>0:
        print("the minimum lies between",a,"and",b)
    i=i+1
    z=b-(((b-a)/(diff_fb-diff_fa))*diff_fb)
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if i>j:
        b=z
        print("the minimum lies on lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval0.5
# enter the ending interval0.9
# enter the iterations2
#
# iteration no. =  1
# a = 0.5 ,b= 0.9
# the value of del a is  0.005000
# the value of del b is  0.009000
# f'a = -2.499950000000000000  ,f'b = 2.316291600000000000
# the minimum lies between 0.5 and 0.9
# the value of z= 0.7076266273685273595909308204 ,the value of delz = 0.007076
# f'z = -0.3367635798721452261254541973
#
# iteration no. =  2
# a = 0.7076266273685273595909308204 ,b= 0.9
# the value of del a is  0.007076
# the value of del b is  0.009000
# f'a = -0.3367635798721452261254541973  ,f'b = 2.316291600000000000
# the minimum lies between 0.7076266273685273595909308204 and 0.9
# the value of z= 0.7320453978980475746146064150 ,the value of delz = 0.007320
# f'z = -0.03838612011059265636245953552
# the minimum lies on lies in the interval ( 0.7076266273685273595909308204 , 0.7320453978980475746146064150 )

# %%
#question 7 using newton raphson 
import math
from decimal import Decimal
def f(x):
    return Decimal(((x**3)*(Decimal(math.cos(2*x))))+Decimal(math.exp(x)))
a=Decimal(input("enter the starting interval"))
E=Decimal(input("enter the termination parameter"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a)
    i=i+1
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*a
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
    print("f'a =",diff_fa)
    diff2_fa=(f(a+dela)+f(a-dela)-(2*f(a)))/(dela**2)
    print("f\"a =",diff2_fa)
    a1=(a)-(diff_fa/diff2_fa)
    print("a1=",a1)
    if a1 < -0.01 or a1 > 0.01:
        dela1=Decimal(0.01)*a1
    elif a1>=-0.01 and a1<=0.01:
        dela1=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    diff_fa1=(f(a1+dela1)-f(a1-dela1))/(2*dela1)
    print("f'a1 =",diff_fa1)
    if abs(diff_fa1)<E:
        print("the minimum lies on ",a1)
        break
    else:
        a=a1
        continue
# Out:
# enter the starting interval3
# enter the termination parameter0.25
#
# iteration no. =  1
# a = 3
# the value of del a is  0.030000
# f'a = 61.0512692344394622673053875
# f"a = -36.16850058365892795770374444
# a1= 4.687967934784188092516609127
# f'a1 = 33.05809501485568760959117699
#
# iteration no. =  2
# a = 4.687967934784188092516609127
# the value of del a is  0.046880
# f'a = 33.05809964363927916895052497
# f"a = 479.1417148645490234663478171
# a1= 4.618973525368208439608058728
# f'a1 = 2.233379168375323191964431281
#
# iteration no. =  3
# a = 4.618973525368208439608058728
# the value of del a is  0.046190
# f'a = 2.233383100668112121212686068
# f"a = 413.8506976172779869867860280
# a1= 4.613576934004398521782621730
# f'a1 = 0.01364750517554727159457564918
# the minimum lies on  4.613576934004398521782621730

# %%
#question 7 - powelss successive 
import math
import numpy as np
def f(x):
    f=(((x**3)*((math.cos(2*x))))+(math.exp(x)))
    return f
def invf(f,C):
    if f==C[0][0]:
        a=0
    elif f==C[1][0]:
        a=1
    elif f==C[2][0]:
        a=2
    elif f==C[3][0]:
        a=3
    return a
xi=float(input("initial search value:"))
s=float(input("Del value :"))
j=float(input("enter the number of iterations"))
i=1
x1=xi
x2=xi+s
f1=f(x1)
f2=f(x2)
if f1>=f2:
    x3=x2+s
else:
    x3=x1-s
f3=f(x3)
while True:
    print("")
    print("iteration number=",i)
    f1=f(x1)
    f2=f(x2)
    f3=f(x3)
    i=i+1
    print("")
    print("x1 =",x1,",x2 =",x2 ,",x3 = ",x3)
    print("fx1 =",f1," ,fx2 =",f2," ,fx3 =",f3)
    a0=f1
    a1=(f2-f1)/(x2-x1)
    a2=(1/(x3-x2))*(((f3-f1)/(x3-x1))-((f2-f1)/(x2-x1)))
    print("a0 =",a0," ,a1 =",a1," ,a2=",a2)
    Fmin=min(f1,f2,f3)
    if Fmin==f1:
        Xmin=x1
    elif Fmin==f2:
        Xmin=x2
    else:
        Xmin=x3
    print("Fmin =",Fmin)
    print("Xmin=",Xmin)
    xp=(0.5*(x1+x2))-(a1/(2*a2))
    fp=f(xp)
    C=np.array(((f1,x1),(f2,x2),(f3,x3),(fp,xp)))
    if i>j:
        f4=min(f1,f2,f3,fp)
        a=invf(f4,C)
        x4=C[a][1]
        break
    Fmax=max(f1,f2,f3,fp)
    a=invf(Fmax,C)
    if a==0:
        K=np.array((C[1][1],C[2][1],C[3][1]))
    elif a==1:
        K=np.array((C[0][1],C[2][1],C[3][1]))
    elif a==2:
        K=np.array((C[0][1],C[1][1],C[3][1]))
    else:
        K=np.array((C[0][1],C[1][1],C[2][1]))
    Kp=np.sort(K)
    x1=Kp[0]
    x2=Kp[1]
    x3=Kp[2]
print("the minimum lies in ",x4,", with a function value of",f4)
# Out:
# initial search value:4
# Del value :0.5
# enter the number of iterations3
#
# iteration number= 1
#
# x1 = 4.0 ,x2 = 4.5 ,x3 =  5.0
# fx1 = 45.28614786939297  ,fx2 = 6.990386186280631  ,fx3 = 43.52921796802005
# a0 = 45.28614786939297  ,a1 = -76.59152336622468  ,a2= 149.66918692970353
# Fmin = 6.990386186280631
# Xmin= 4.5
#
# iteration number= 2
#
# x1 = 4.5 ,x2 = 4.505869377449742 ,x3 =  5.0
# fx1 = 6.990386186280631  ,fx2 = 6.7581685521582955  ,fx3 = 43.52921796802005
# a0 = 6.990386186280631  ,a1 = -39.56426999468794  ,a2= 227.95983170767775
# Fmin = 6.7581685521582955
# Xmin= 4.505869377449742
#
# iteration number= 3
#
# x1 = 4.5 ,x2 = 4.505869377449742 ,x3 =  4.58971372715964
# fx1 = 6.990386186280631  ,fx2 = 6.7581685521582955  ,fx3 = 4.67723450270843
# a0 = 6.990386186280631  ,a1 = -39.56426999468794  ,a2= 164.35897756637635
# Fmin = 4.67723450270843
# Xmin= 4.58971372715964
# the minimum lies in  4.623294010072893 , with a function value of 4.571438736082229

# %%
#question 7 - secant method 
import math
from decimal import Decimal
def f(x):
    return Decimal(((x**3)*(Decimal(math.cos(2*x))))+Decimal(math.exp(x)))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
j=Decimal(input("enter the iterations"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*abs(a)
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    if b < -0.01 or b > 0.01:
        delb=Decimal(0.01)*abs(b)
    elif b>=-0.01 and b<=0.01:
        delb=0.001
    else:
        print("invalid , try again")
    delb=round(delb,6)
    print("the value of del b is ",delb)
    diff_fa=(f(a+Decimal(dela))-f(a-Decimal(dela)))/(2*Decimal(dela))
    diff_fb=(f(b+Decimal(delb))-f(b-Decimal(delb)))/(2*Decimal(delb))
    print("f'a =",diff_fa," ,f'b =",diff_fb)
    if diff_fa<0 and diff_fb>0:
        print("the minimum lies between",a,"and",b)
    i=i+1
    z=b-(((b-a)/(diff_fb-diff_fa))*diff_fb)
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if i>j:
        b=z
        print("the minimum lies on lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval-5
# enter the ending interval-3
# enter the iterations4
#
# iteration no. =  1
# a = -5 ,b= -3
# the value of del a is  0.050000
# the value of del b is  0.030000
# f'a = 73.20812776075902868724854  ,f'b = 41.01251388189732234884251267
# the value of z= -0.452291853405260035608765178 ,the value of delz = -0.004523
# f'z = 0.8699235135037422493838993809
#
# iteration no. =  2
# a = -5 ,b= -0.452291853405260035608765178
# the value of del a is  0.050000
# the value of del b is  0.004523
# f'a = 73.20812776075902868724854  ,f'b = 0.8699235135037422493838993809
# the value of z= -0.3976021041857057555501123733 ,the value of delz = -0.003976
# f'z = 0.9141961626084898903793026157
#
# iteration no. =  3
# a = -5 ,b= -0.3976021041857057555501123733
# the value of del a is  0.050000
# the value of del b is  0.003976
# f'a = 73.20812776075902868724854  ,f'b = 0.9141961626084898903793026157
# the value of z= -0.3394022746545303535352151376 ,the value of delz = -0.003394
# f'z = 0.9320649548795820558051320713
#
# iteration no. =  4
# a = -5 ,b= -0.3394022746545303535352151376
# the value of del a is  0.050000
# the value of del b is  0.003394
# f'a = 73.20812776075902868724854  ,f'b = 0.9320649548795820558051320713
# the value of z= -0.2792996675126172794104967792 ,the value of delz = -0.002793
# f'z = 0.9316687376617162597571790369
# the minimum lies on lies in the interval ( -5 , -0.2792996675126172794104967792 )

# %%
#question 8 - powells successive 
import math
import numpy as np
def f(x):
    f=((x**3)*(math.sin(2*x)))+x
    return f
def invf(f,C):
    if f==C[0][0]:
        a=0
    elif f==C[1][0]:
        a=1
    elif f==C[2][0]:
        a=2
    elif f==C[3][0]:
        a=3
    return a
xi=float(input("initial search value:"))
s=float(input("Del value :"))
j=float(input("enter the number of iterations"))
i=1
x1=xi
x2=xi+s
f1=f(x1)
f2=f(x2)
if f1>=f2:
    x3=x2+s
else:
    x3=x1-s
f3=f(x3)
while True:
    print("")
    print("iteration number=",i)
    f1=f(x1)
    f2=f(x2)
    f3=f(x3)
    i=i+1
    print("")
    print("x1 =",x1,",x2 =",x2 ,",x3 = ",x3)
    print("fx1 =",f1," ,fx2 =",f2," ,fx3 =",f3)
    a0=f1
    a1=(f2-f1)/(x2-x1)
    a2=(1/(x3-x2))*(((f3-f1)/(x3-x1))-((f2-f1)/(x2-x1)))
    print("a0 =",a0," ,a1 =",a1," ,a2=",a2)
    Fmin=min(f1,f2,f3)
    if Fmin==f1:
        Xmin=x1
    elif Fmin==f2:
        Xmin=x2
    else:
        Xmin=x3
    print("Fmin =",Fmin)
    print("Xmin=",Xmin)
    xp=(0.5*(x1+x2))-(a1/(2*a2))
    fp=f(xp)
    C=np.array(((f1,x1),(f2,x2),(f3,x3),(fp,xp)))
    if i>j:
        f4=min(f1,f2,f3,fp)
        a=invf(f4,C)
        x4=C[a][1]
        break
    Fmax=max(f1,f2,f3,fp)
    a=invf(Fmax,C)
    if a==0:
        K=np.array((C[1][1],C[2][1],C[3][1]))
    elif a==1:
        K=np.array((C[0][1],C[2][1],C[3][1]))
    elif a==2:
        K=np.array((C[0][1],C[1][1],C[3][1]))
    else:
        K=np.array((C[0][1],C[1][1],C[2][1]))
    Kp=np.sort(K)
    x1=Kp[0]
    x2=Kp[1]
    x3=Kp[2]
print("the minimum lies in ",x4,", with a function value of",f4)
# Out:
# initial search value:2.5
# Del value :1
# enter the number of iterations3
#
# iteration number= 1
#
# x1 = 2.5 ,x2 = 3.5 ,x3 =  1.5
# fx1 = -12.483191791611539  ,fx2 = 31.668300420068082  ,fx3 = 1.9762800272020518
# a0 = -12.483191791611539  ,a1 = 44.151492211679624  ,a2= 29.305482015246607
# Fmin = -12.483191791611539
# Xmin= 2.5
#
# iteration number= 2
#
# x1 = 1.5 ,x2 = 2.2467025079350487 ,x3 =  2.5
# fx1 = 1.9762800272020518  ,fx2 = -8.823086209892377  ,fx3 = -12.483191791611539
# a0 = 1.9762800272020518  ,a1 = -14.462742688462757  ,a2= 0.012913154498698017
# Fmin = -12.483191791611539
# Xmin= 2.5
#
# iteration number= 3
#
# x1 = 2.2467025079350487 ,x2 = 2.5 ,x3 =  561.873724900894
# fx1 = -8.823086209892377  ,fx2 = -12.483191791611539  ,fx3 = -143531947.24205074
# a0 = -8.823086209892377  ,a1 = -14.449829533964062  ,a2= -458.48311059379404
# Fmin = -143531947.24205074
# Xmin= 561.873724900894
# the minimum lies in  561.873724900894 , with a function value of -143531947.24205074

# %%
#question 8 - bisection method 
import math
from decimal import Decimal
def f(x):
    return Decimal((x**3)*Decimal(math.sin(2*x)))+x
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
j=Decimal(input("enter the number of iterations"))
E=0
i=1
if a < -0.01 or a > 0.01:
    dela=Decimal(0.01)*abs(a)
elif a>=-0.01 and a<=0.01:
    dela=0.001
else:
    print("invalid , try again")
dela=round(dela,6)
print("the value of del a is ",dela)
if b < -0.01 or b > 0.01:
    delb=Decimal(0.01)*abs(b)
elif b>=-0.01 and b<=0.01:
    delb=0.001
else:
    print("invalid , try again")
delb=round(delb,6)
print("the value of del b is ",delb)
diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
diff_fb=(f(b+delb)-f(b-delb))/(2*delb)
print("f'a =",diff_fa," ,f'b =",diff_fb)
if diff_fa<0 and diff_fb>0:
    print("the minimum lies between",a,"and",b)
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    i=i+1
    z=(a+b)/2
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*abs(z)
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if i>j:
        if diff_fz<0:
            a=z
        if diff_fz>0:
            b=z
        z=(a+b)/2
        print("the minimum lies on ",z,"or lies in the interval (",a,",",b,")")
        break
    if diff_fz<0:
        a=z
        continue
    if diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval2
# enter the ending interval3.5
# enter the number of iterations5
# the value of del a is  0.020000
# the value of del b is  0.035000
# f'a = -18.5333140175032221595774473  ,f'b = 89.69964545746327733519442929
# the minimum lies between 2 and 3.5
#
# iteration no. =  1
# a = 2 ,b= 3.5
# the value of z= 2.75 ,the value of delz = 0.027500
# f'z = 14.48693865919671865678461382
#
# iteration no. =  2
# a = 2 ,b= 2.75
# the value of z= 2.375 ,the value of delz = 0.023750
# f'z = -14.88400116178790990060501137
#
# iteration no. =  3
# a = 2.375 ,b= 2.75
# the value of z= 2.5625 ,the value of delz = 0.025625
# f'z = -3.529893468403020989394304976
#
# iteration no. =  4
# a = 2.5625 ,b= 2.75
# the value of z= 2.65625 ,the value of delz = 0.026563
# f'z = 4.719960095175187400732750442
#
# iteration no. =  5
# a = 2.5625 ,b= 2.65625
# the value of z= 2.609375 ,the value of delz = 0.026094
# f'z = 0.3915157072059789592762539281
# the minimum lies on  2.5859375 or lies in the interval ( 2.5625 , 2.609375 )

# %%
#question 8 - secant method 
import math
from decimal import Decimal
def f(x):
    return Decimal((x**3)*Decimal(math.sin(2*x)))+x
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
j=Decimal(input("enter the iterations"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*abs(a)
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    if b < -0.01 or b > 0.01:
        delb=Decimal(0.01)*abs(b)
    elif b>=-0.01 and b<=0.01:
        delb=0.001
    else:
        print("invalid , try again")
    delb=round(delb,6)
    print("the value of del b is ",delb)
    diff_fa=(f(a+Decimal(dela))-f(a-Decimal(dela)))/(2*Decimal(dela))
    diff_fb=(f(b+Decimal(delb))-f(b-Decimal(delb)))/(2*Decimal(delb))
    print("f'a =",diff_fa," ,f'b =",diff_fb)
    if diff_fa<0 and diff_fb>0:
        print("the minimum lies between",a,"and",b)
    i=i+1
    z=b-(((b-a)/(diff_fb-diff_fa))*diff_fb)
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if i>j:
        b=z
        print("the minimum lies on lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval1.8
# enter the ending interval3.7
# enter the iterations4
#
# iteration no. =  1
# a = 1.8 ,b= 3.7
# the value of del a is  0.018000
# the value of del b is  0.037000
# f'a = -13.75932331114155165817902747  ,f'b = 82.21041042123402767267836838
# the minimum lies between 1.8 and 3.7
# the value of z= 2.072405822903201947938197175 ,the value of delz = 0.020724
# f'z = -19.42540420622859750623780359
#
# iteration no. =  2
# a = 2.072405822903201947938197175 ,b= 3.7
# the value of del a is  0.020724
# the value of del b is  0.037000
# f'a = -19.42540420622859750623780359  ,f'b = 82.21041042123402767267836838
# the minimum lies between 2.072405822903201947938197175 and 3.7
# the value of z= 2.383483909793118928227479403 ,the value of delz = 0.023835
# f'z = -14.52163719597850567848997294
#
# iteration no. =  3
# a = 2.383483909793118928227479403 ,b= 3.7
# the value of del a is  0.023835
# the value of del b is  0.037000
# f'a = -14.52163719597850567848997294  ,f'b = 82.21041042123402767267836838
# the minimum lies between 2.383483909793118928227479403 and 3.7
# the value of z= 2.581122329485276669716874685 ,the value of delz = 0.025811
# f'z = -2.022082922150146780369098446
#
# iteration no. =  4
# a = 2.581122329485276669716874685 ,b= 3.7
# the value of del a is  0.025811
# the value of del b is  0.037000
# f'a = -2.022082922150146780369098446  ,f'b = 82.21041042123402767267836838
# the minimum lies between 2.581122329485276669716874685 and 3.7
# the value of z= 2.607982076118915412330904586 ,the value of delz = 0.026080
# f'z = 0.2690112189832692519293564034
# the minimum lies on lies in the interval ( 2.581122329485276669716874685 , 2.607982076118915412330904586 )

# %%
#question 8 - newton Rahson method 
import math
from decimal import Decimal
def f(x):
    return Decimal((x**3)*Decimal(math.sin(2*x)))+x
a=Decimal(input("enter the starting interval"))
j=Decimal(input("enter the number of iterations"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a)
    i=i+1
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*a
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
    print("f'a =",diff_fa)
    diff2_fa=(f(a+dela)+f(a-dela)-(2*f(a)))/(dela**2)
    print("f\"a =",diff2_fa)
    a1=(a)-(diff_fa/diff2_fa)
    print("a1=",a1)
    if a1 < -0.01 or a1 > 0.01:
        dela1=Decimal(0.01)*a1
    elif a1>=-0.01 and a1<=0.01:
        dela1=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    diff_fa1=(f(a1+dela1)-f(a1-dela1))/(2*dela1)
    print("f'a1 =",diff_fa1)
    if i>j:
        print("the minimum lies on ",a1)
        break
    else:
        a=a1
        continue
# Out:
# enter the starting interval3.5
# enter the number of iterations4
#
# iteration no. =  1
# a = 3.5
# the value of del a is  0.035000
# f'a = 89.69964545746327733519442929
# f"a = 11.87256814165920932091502857
# a1= -4.055201569466639125117165168
# f'a1 = -12.76649186559197039232466968
#
# iteration no. =  2
# a = -4.055201569466639125117165168
# the value of del a is  -0.040552
# f'a = -12.76649196487534276206939658
# f"a = -284.4196344132005279424678366
# a1= -4.100087682871624299262505781
# f'a1 = 0.4549011885540172908007536637
#
# iteration no. =  3
# a = -4.100087682871624299262505781
# the value of del a is  -0.041001
# f'a = 0.4549019057294661498085362552
# f"a = -304.5121780444700927643092409
# a1= -4.098593811891978179596428703
# f'a1 = 0.0005995366126975028660997591012
#
# iteration no. =  4
# a = -4.098593811891978179596428703
# the value of del a is  -0.040986
# f'a = 0.0005998980651049269143163519250
# f"a = -303.8745683844091801124808602
# a1= -4.098591837728532076267496643
# f'a1 = -1.973858090904211276886022355E-7
# the minimum lies on  -4.098591837728532076267496643

# %%
#question 9 - bisection 
import math
from decimal import Decimal
def f(x):
    return Decimal(Decimal(math.cos(5*x))+(x**2))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
E=Decimal(input("enter the termination parameter"))
i=1
if a < -0.01 or a > 0.01:
    dela=Decimal(0.01)*a
elif a>=-0.01 and a<=0.01:
    dela=0.001
else:
    print("invalid , try again")
dela=round(dela,6)
print("the value of del a is ",dela)
if b < -0.01 or b > 0.01:
    delb=Decimal(0.01)*b
elif b>=-0.01 and b<=0.01:
    delb=0.001
else:
    print("invalid , try again")
delb=round(delb,6)
print("the value of del b is ",delb)
diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
diff_fb=(f(b+delb)-f(b-delb))/(2*delb)
print("f'a =",diff_fa," ,f'b =",diff_fb)
if diff_fa<0 and diff_fb>0:
    print("the minimum lies between",a,"and",b)
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    i=i+1
    z=(a+b)/2
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if abs(diff_fz)<E:
        print("the minimum lies on ",z,"or lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval0.1
# enter the ending interval0.9
# enter the termination parameter0.1
# the value of del a is  0.001000
# the value of del b is  0.009000
# f'a = -2.19711770500145027185112665  ,f'b = 6.686001173264049097295153639
# the minimum lies between 0.1 and 0.9
#
# iteration no. =  1
# a = 0.1 ,b= 0.9
# the value of z= 0.5 ,the value of delz = 0.005000
# f'z = -1.9920490260186616282567229
#
# iteration no. =  2
# a = 0.5 ,b= 0.9
# the value of z= 0.7 ,the value of delz = 0.007000
# f'z = 3.153558069168960541008215971
#
# iteration no. =  3
# a = 0.5 ,b= 0.7
# the value of z= 0.6 ,the value of delz = 0.006000
# f'z = 0.494505794944017592248049675
#
# iteration no. =  4
# a = 0.5 ,b= 0.6
# the value of z= 0.55 ,the value of delz = 0.005500
# f'z = -0.8080644434186626186415609909
#
# iteration no. =  5
# a = 0.55 ,b= 0.6
# the value of z= 0.575 ,the value of delz = 0.005750
# f'z = -0.1670485121673779638701054609
#
# iteration no. =  6
# a = 0.575 ,b= 0.6
# the value of z= 0.5875 ,the value of delz = 0.005875
# f'z = 0.1617520912203046695130398553
#
# iteration no. =  7
# a = 0.575 ,b= 0.5875
# the value of z= 0.58125 ,the value of delz = 0.005813
# f'z = -0.003216892726128760603427541717
# the minimum lies on  0.58125 or lies in the interval ( 0.575 , 0.5875 )

# %%
#question 9 - secant method
import math
from decimal import Decimal
def f(x):
    return Decimal(Decimal(math.cos(5*x))+(x**2))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
E=Decimal(input("enter the termination parameter"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*abs(a)
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    if b < -0.01 or b > 0.01:
        delb=Decimal(0.01)*abs(b)
    elif b>=-0.01 and b<=0.01:
        delb=0.001
    else:
        print("invalid , try again")
    delb=round(delb,6)
    print("the value of del b is ",delb)
    diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
    diff_fb=(f(b+delb)-f(b-delb))/(2*delb)
    print("f'a =",diff_fa," ,f'b =",diff_fb)
    if diff_fa<0 and diff_fb>0:
        print("the minimum lies between",a,"and",b)
    i=i+1
    z=b-(((b-a)/(diff_fb-diff_fa))*diff_fb)
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if abs(diff_fz)<E:
        b=z
        print("the minimum lies on lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval0.1
# enter the ending interval0.9
# enter the termination parameter0.1
#
# iteration no. =  1
# a = 0.1 ,b= 0.9
# the value of del a is  0.001000
# the value of del b is  0.009000
# f'a = -2.19711770500145027185112665  ,f'b = 6.686001173264049097295153639
# the minimum lies between 0.1 and 0.9
# the value of z= 0.2978690354242297592949296261 ,the value of delz = 0.002979
# f'z = -4.387501103013192682401463696
#
# iteration no. =  2
# a = 0.2978690354242297592949296261 ,b= 0.9
# the value of del a is  0.002979
# the value of del b is  0.009000
# f'a = -4.387501103013192682401463696  ,f'b = 6.686001173264049097295153639
# the minimum lies between 0.2978690354242297592949296261 and 0.9
# the value of z= 0.5364430841146990840243512770 ,the value of delz = 0.005364
# f'z = -1.143798006400119905634107672
#
# iteration no. =  3
# a = 0.5364430841146990840243512770 ,b= 0.9
# the value of del a is  0.005364
# the value of del b is  0.009000
# f'a = -1.143798006400119905634107672  ,f'b = 6.686001173264049097295153639
# the minimum lies between 0.5364430841146990840243512770 and 0.9
# the value of z= 0.5895524507869128971560054915 ,the value of delz = 0.005896
# f'z = 0.2161495500562933910287876102
#
# iteration no. =  4
# a = 0.5364430841146990840243512770 ,b= 0.5895524507869128971560054915
# the value of del a is  0.005364
# the value of del b is  0.005896
# f'a = -1.143798006400119905634107672  ,f'b = 0.2161495500562933910287876102
# the minimum lies between 0.5364430841146990840243512770 and 0.5895524507869128971560054915
# the value of z= 0.5811112681431602350060008074 ,the value of delz = 0.005811
# f'z = -0.006866405226267861634983797969
# the minimum lies on lies in the interval ( 0.5364430841146990840243512770 , 0.5811112681431602350060008074 )

# %%
#question 9 - newton raphson method 
import math
from decimal import Decimal
def f(x):
    return Decimal(Decimal(math.cos(5*x))+(x**2))
a=Decimal(input("enter the starting interval"))
j=Decimal(input("enter the number of iterations"))
i=1
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a)
    i=i+1
    if a < -0.01 or a > 0.01:
        dela=Decimal(0.01)*a
    elif a>=-0.01 and a<=0.01:
        dela=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    print("the value of del a is ",dela)
    diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
    print("f'a =",diff_fa)
    diff2_fa=(f(a+dela)+f(a-dela)-(2*f(a)))/(dela**2)
    print("f\"a =",diff2_fa)
    a1=(a)-(diff_fa/diff2_fa)
    print("a1=",a1)
    if a1 < -0.01 or a1 > 0.01:
        dela1=Decimal(0.01)*a1
    elif a1>=-0.01 and a1<=0.01:
        dela1=0.001
    else:
        print("invalid , try again")
    dela=round(dela,6)
    diff_fa1=(f(a1+dela1)-f(a1-dela1))/(2*dela1)
    print("f'a1 =",diff_fa1)
    if i>j:
        print("the minimum lies on ",a1)
        break
    else:
        a=a1
        continue
# Out:
# enter the starting interval0.3
# enter the number of iterations2
#
# iteration no. =  1
# a = 0.3
# the value of del a is  0.003000
# f'a = -4.387287904814331068736876783
# f"a = 0.2316031161224000199815222222
# a1= 19.24312986054855840235397769
# f'a1 = 34.55449497954021022811054333
#
# iteration no. =  2
# a = 19.24312986054855840235397769
# the value of del a is  0.192431
# f'a = 34.55449296936383688320662315
# f"a = 10.94482372552581735569468575
# a1= 16.08597595511151578199614571
# f'a1 = 36.42374464086259214950078738
# the minimum lies on  16.08597595511151578199614571

# %%
#question 9 - sqe 
import math
import numpy as np
def f(x):
    f=(math.cos(5*x))+(x**2)
    return f
def invf(f,C):
    if f==C[0][0]:
        a=0
    elif f==C[1][0]:
        a=1
    elif f==C[2][0]:
        a=2
    elif f==C[3][0]:
        a=3
    return a
xi=float(input("initial search value:"))
s=float(input("Del value :"))
j=float(input("enter the number of iterations"))
i=1
x1=xi
x2=xi+s
f1=f(x1)
f2=f(x2)
if f1>=f2:
    x3=x2+s
else:
    x3=x1-s
f3=f(x3)
while True:
    print("")
    print("iteration number=",i)
    f1=f(x1)
    f2=f(x2)
    f3=f(x3)
    i=i+1
    print("")
    print("x1 =",x1,",x2 =",x2 ,",x3 = ",x3)
    print("fx1 =",f1," ,fx2 =",f2," ,fx3 =",f3)
    a0=f1
    a1=(f2-f1)/(x2-x1)
    a2=(1/(x3-x2))*(((f3-f1)/(x3-x1))-((f2-f1)/(x2-x1)))
    print("a0 =",a0," ,a1 =",a1," ,a2=",a2)
    Fmin=min(f1,f2,f3)
    if Fmin==f1:
        Xmin=x1
    elif Fmin==f2:
        Xmin=x2
    else:
        Xmin=x3
    print("Fmin =",Fmin)
    print("Xmin=",Xmin)
    xp=(0.5*(x1+x2))-(a1/(2*a2))
    fp=f(xp)
    C=np.array(((f1,x1),(f2,x2),(f3,x3),(fp,xp)))
    if i>j:
        f4=min(f1,f2,f3,fp)
        a=invf(f4,C)
        x4=C[a][1]
        break
    Fmax=max(f1,f2,f3,fp)
    a=invf(Fmax,C)
    if a==0:
        K=np.array((C[1][1],C[2][1],C[3][1]))
    elif a==1:
        K=np.array((C[0][1],C[2][1],C[3][1]))
    elif a==2:
        K=np.array((C[0][1],C[1][1],C[3][1]))
    else:
        K=np.array((C[0][1],C[1][1],C[2][1]))
    Kp=np.sort(K)
    x1=Kp[0]
    x2=Kp[1]
    x3=Kp[2]
print("the minimum lies in ",x4,", with a function value of",f4)
# Out:
# initial search value:1
# Del value :0.2
# enter the number of iterations3
#
# iteration number= 1
#
# x1 = 1.0 ,x2 = 1.2 ,x3 =  0.8
# fx1 = 1.2836621854632262  ,fx2 = 2.400170286650366  ,fx3 = -0.013643620863611816
# a0 = 1.2836621854632262  ,a1 = 5.582540505935699  ,a2= -2.25997131424623
# Fmin = -0.013643620863611816
# Xmin= 0.8
#
# iteration number= 2
#
# x1 = 0.8 ,x2 = 1.0 ,x3 =  1.2
# fx1 = -0.013643620863611816  ,fx2 = 1.2836621854632262  ,fx3 = 2.400170286650366
# a0 = -0.013643620863611816  ,a1 = 6.486529031634191  ,a2= -2.2599713142462323
# Fmin = -0.013643620863611816
# Xmin= 0.8
#
# iteration number= 3
#
# x1 = 0.8 ,x2 = 1.0 ,x3 =  1.2
# fx1 = -0.013643620863611816  ,fx2 = 1.2836621854632262  ,fx3 = 2.400170286650366
# a0 = -0.013643620863611816  ,a1 = 6.486529031634191  ,a2= -2.2599713142462323
# Fmin = -0.013643620863611816
# Xmin= 0.8
# the minimum lies in  0.8 , with a function value of -0.013643620863611816
