# %%
#bisection search - termination parameter , interval is given  
import math
from decimal import Decimal
def f(x):
    return Decimal(x**2+(54/x))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
E=Decimal(input("enter the termination parameter"))
i=1
if a < -0.01 or a > 0.01:
    dela=Decimal(0.01)*a
elif a>=-0.01 and a<=0.01:
    dela=0.001
else:
    print("invalid , try again")
dela=round(dela,6)
print("the value of del a is ",dela)
if b < -0.01 or b > 0.01:
    delb=Decimal(0.01)*b
elif b>=-0.01 and b<=0.01:
    delb=0.001
else:
    print("invalid , try again")
delb=round(delb,6)
print("the value of del b is ",delb)
diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
diff_fb=(f(b+delb)-f(b-delb))/(2*delb)
print("f'a =",diff_fa," ,f'b =",diff_fb)
if diff_fa<0 and diff_fb>0:
    print("the minimum lies between",a,"and",b)
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    i=i+1
    z=(a+b)/2
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*z
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if abs(diff_fz)<E:
        print("the minimum lies on ",z,"or lies in the interval (",a,",",b,")")
        break
    elif diff_fz<0:
        a=z
        continue
    elif diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval2
# enter the ending interval5
# enter the termination parameter0.5
# the value of del a is  0.020000
# the value of del b is  0.050000
# f'a = -9.5013501350135013501350135  ,f'b = 7.8397839783978397839783978
# the minimum lies between 2 and 5
#
# iteration no. =  1
# a = 2 ,b= 5
# the value of z= 3.5 ,the value of delz = 0.035000
# f'z = 2.591395874281305681588567143
#
# iteration no. =  2
# a = 2 ,b= 3.5
# the value of z= 2.75 ,the value of delz = 0.027500
# f'z = -1.641209988767471788501164182
#
# iteration no. =  3
# a = 2.75 ,b= 3.5
# the value of z= 3.125 ,the value of delz = 0.031250
# f'z = 0.71984698469846984698469856
#
# iteration no. =  4
# a = 2.75 ,b= 3.125
# the value of z= 2.9375 ,the value of delz = 0.029375
# f'z = -0.3836611762126869092522651915
# the minimum lies on  2.9375 or lies in the interval ( 2.75 , 3.125 )

# %%
#bisection search method - interval is given and nummber of iterations is given 
import math
from decimal import Decimal
def f(x):
    return Decimal((x**4)+(10*(x**2))+x-Decimal(math.exp(Decimal(0.2)*x)))
a=Decimal(input("enter the starting interval"))
b=Decimal(input("enter the ending interval"))
j=Decimal(input("enter the number of iterations"))
E=0
i=1
if a < -0.01 or a > 0.01:
    dela=Decimal(0.01)*abs(a)
elif a>=-0.01 and a<=0.01:
    dela=0.001
else:
    print("invalid , try again")
dela=round(dela,6)
print("the value of del a is ",dela)
if b < -0.01 or b > 0.01:
    delb=Decimal(0.01)*abs(b)
elif b>=-0.01 and b<=0.01:
    delb=0.001
else:
    print("invalid , try again")
delb=round(delb,6)
print("the value of del b is ",delb)
diff_fa=(f(a+dela)-f(a-dela))/(2*dela)
diff_fb=(f(b+delb)-f(b-delb))/(2*delb)
print("f'a =",diff_fa," ,f'b =",diff_fb)
if diff_fa<0 and diff_fb>0:
    print("the minimum lies between",a,"and",b)
while True :
    print("")
    print("iteration no. = ", i)
    print("a =",a,",b=",b )
    i=i+1
    z=(a+b)/2
    if z< -0.01 or z > 0.01:
        delz=Decimal(0.01)*abs(z)
    elif z>=-0.01 and z<=0.01:
        delz=0.001
    else:
        print("invalid , try again")
    delz=round(delz,6)
    print("the value of z=",z,",the value of delz =",delz) 
    diff_fz=(f(z+delz)-f(z-delz))/(2*delz)
    print("f'z =",diff_fz)
    if i>j:
        if diff_fz<0:
            a=z
        if diff_fz>0:
            b=z
        z=(a+b)/2
        print("the minimum lies on ",z,"or lies in the interval (",a,",",b,")")
        break
    if diff_fz<0:
        a=z
        continue
    if diff_fz>0:
        b=z
        continue
# Out:
# enter the starting interval-1
# enter the ending interval1.5
# enter the number of iterations3
# the value of del a is  0.010000
# the value of del b is  0.015000
# f'a = -23.1641462597797234575836001  ,f'b = 44.23137783352697964147637333
# the minimum lies between -1 and 1.5
#
# iteration no. =  1
# a = -1 ,b= 1.5
# the value of z= 0.25 ,the value of delz = 0.002500
# f'z = 5.85225202196422224290017766
#
# iteration no. =  2
# a = -1 ,b= 0.25
# the value of z= -0.375 ,the value of delz = 0.003750
# f'z = -6.896507308410906573688710823
#
# iteration no. =  3
# a = -0.375 ,b= 0.25
# the value of z= -0.0625 ,the value of delz = 0.000625
# f'z = -0.4484922207693873531297872
# the minimum lies on  0.09375 or lies in the interval ( -0.0625 , 0.25 )
