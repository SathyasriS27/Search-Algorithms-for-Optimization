# %%
#evolutionary search - starting point is given , reduction parameter is given , termination parameter is given 
#for 2 variables 
import math
from decimal import Decimal
def f(x,y):
    return Decimal((x-2)**2 + (y-3)**2)#function
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
E=Decimal(input(("enter the termination parameter")))
i=1
j=0
fminb=[]
while True:
    k=0
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    fxx=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    f0=f(Decimal(x0),Decimal(y0))
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    fxx.append(f(x[1],y[1]))
    fxx.append(f(x[1],y[2]))
    fxx.append(f(x[2],y[1]))
    fxx.append(f(x[2],y[2]))
    print("x(0)=(",x0,",",y0,")\tf(x(0))=",f0)
    print("x(1)=(",x[1],",",y[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[2],",",y[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[2],",",y[2],")\tf(x(4))=",fxx[4])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[2]
    elif fxx[3]==fmin:
        x0=x[2]
        y0=y[1]
    elif fxx[4]==fmin:
        x0=x[2]
        y0=y[2]
    print("min lies in (",x0,",",y0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
            mag=(((delx/2)**2)+((dely/2)**2))
            if mag<E:
                print("")
                print("||del/2||<E, so therefore")
                print("min lies in (",x0,",",y0,")")
                break
            else:
                delx=delx/2
                dely=dely/2
                print("")
                print("the new delx and dely values are:",delx,dely)
                i=i+1
                j=j+1
                continue
    else:
        i=i+1
        j=j+1
        continue
# Out:
# Enter the intital value of x01
# Enter the intital value of y00
# Enter the x value in the reduction parameter2
# Enter the y value in the reduction parameter2
# enter the termination parameter0.8
#
# Interation no. :  1
# x(0)=( 1 , 0 )	f(x(0))= 10
# x(1)=( 2 , 1 )	f(x(1))= 4
# x(2)=( 2 , -1 )	f(x(2))= 16
# x(3)=( 0 , 1 )	f(x(3))= 8
# x(4)=( 0 , -1 )	f(x(4))= 20
# fmin= 4
# min lies in ( 2 , 1 )
#
# Interation no. :  2
# x(0)=( 2 , 1 )	f(x(0))= 4
# x(1)=( 3 , 2 )	f(x(1))= 2
# x(2)=( 3 , 0 )	f(x(2))= 10
# x(3)=( 1 , 2 )	f(x(3))= 2
# x(4)=( 1 , 0 )	f(x(4))= 10
# fmin= 2
# min lies in ( 3 , 2 )
#
# Interation no. :  3
# x(0)=( 3 , 2 )	f(x(0))= 2
# x(1)=( 4 , 3 )	f(x(1))= 4
# x(2)=( 4 , 1 )	f(x(2))= 8
# x(3)=( 2 , 3 )	f(x(3))= 0
# x(4)=( 2 , 1 )	f(x(4))= 4
# fmin= 0
# min lies in ( 2 , 3 )
#
# Interation no. :  4
# x(0)=( 2 , 3 )	f(x(0))= 0
# x(1)=( 3 , 4 )	f(x(1))= 2
# x(2)=( 3 , 2 )	f(x(2))= 2
# x(3)=( 1 , 4 )	f(x(3))= 2
# x(4)=( 1 , 2 )	f(x(4))= 2
# fmin= 0
# min lies in ( 2 , 3 )
#
# ...

# %%
#evolutionary search - starting point is given , reduction parameter is given , termination parameter is given 
#for 3 variables 
import math
from decimal import Decimal
def f(x,y,z):
    return Decimal((((x**2)-y-11)**2)+((x+(y**2)-7)**2)+z)#function
x0=Decimal(input(("Enter the intital value of x0")))
y0=Decimal(input(("Enter the intital value of y0")))
z0=Decimal(input(("Enter the intital value of z0")))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
E=Decimal(input(("enter the termination parameter")))
i=1
j=0
fminb=[]
while True:
    k=0
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    z=[]
    fxx=[]
    x.append((x0))
    y.append((y0))
    z.append(z0)
    f0=f(x0,y0,z0)
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    z.append(Decimal(z[k]+(delz/2)))
    z.append(Decimal(z[k]-(delz/2)))
    fxx.append(f(x[1],y[1],z[1]))
    fxx.append(f(x[1],y[1],z[2]))
    fxx.append(f(x[1],y[2],z[1]))
    fxx.append(f(x[1],y[2],z[2]))
    fxx.append(f(x[2],y[1],z[1]))
    fxx.append(f(x[2],y[1],z[2]))
    fxx.append(f(x[2],y[2],z[1]))
    fxx.append(f(x[2],y[2],z[2]))
    print("x(0)=(",x0,",",y0,",",z0,")\tf(x(0))=",fxx[0])
    print("x(1)=(",x[1],",",y[1],",",z[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[1],",",z[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[1],",",y[2],",",z[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[1],",",y[2],",",z[2],")\tf(x(4))=",fxx[4])
    print("x(5)=(",x[2],",",y[1],",",z[1],")\tf(x(5))=",fxx[5])
    print("x(6)=(",x[2],",",y[1],",",z[2],")\tf(x(6))=",fxx[6])
    print("x(7)=(",x[2],",",y[2],",",z[1],")\tf(x(7))=",fxx[7])
    print("x(8)=(",x[2],",",y[2],",",z[2],")\tf(x(8))=",fxx[8])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
        z0=z0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[2]
    elif fxx[3]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[1]
    elif fxx[4]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[2]
    elif fxx[5]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[1]
    elif fxx[6]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[2]
    elif fxx[7]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[1]
    elif fxx[8]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[2]
    print("min lies in (",x0,",",y0,",",z0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
            mag=(((delx/2)**2)+((dely/2)**2)+((delz/2)**2))
            if mag<E:
                print("")
                print("||del/2||<E, so therefore")
                print("min lies in (",x0,",",y0,",",z0,")")
                break
            else:
                delx=delx/2
                dely=dely/2
                delz=delz/2
                print("")
                print("the new del values are:",delx,dely,delz)
                i=i+1
                j=j+1
                continue
    else:
        i=i+1
        j=j+1
        continue
# Out:
# Enter the intital value of x01
# Enter the intital value of y01
# Enter the intital value of z01
# Enter the x value in the reduction parameter1
# Enter the y value in the reduction parameter1
# Enter the z value in the reduction parameter1
# enter the termination parameter0.4
#
# Interation no. :  1
# x(0)=( 1 , 1 , 1 )	f(x(0))= 147
# x(1)=( 1.5 , 1.5 , 1.5 )	f(x(1))= 117.1250
# x(2)=( 1.5 , 1.5 , 0.5 )	f(x(2))= 116.1250
# x(3)=( 1.5 , 0.5 , 1.5 )	f(x(3))= 114.6250
# x(4)=( 1.5 , 0.5 , 0.5 )	f(x(4))= 113.6250
# x(5)=( 0.5 , 1.5 , 1.5 )	f(x(5))= 169.6250
# x(6)=( 0.5 , 1.5 , 0.5 )	f(x(6))= 168.6250
# x(7)=( 0.5 , 0.5 , 1.5 )	f(x(7))= 167.1250
# x(8)=( 0.5 , 0.5 , 0.5 )	f(x(8))= 166.1250
# fmin= 113.6250
# min lies in ( 1.5 , 0.5 , 0.5 )
#
# Interation no. :  2
# x(0)=( 1.5 , 0.5 , 0.5 )	f(x(0))= 113.6250
# x(1)=( 2.0 , 1.0 , 1.0 )	f(x(1))= 81.0000
# x(2)=( 2.0 , 1.0 , 0.0 )	f(x(2))= 80.0000
# x(3)=( 2.0 , 0.0 , 1.0 )	f(x(3))= 75.0000
# x(4)=( 2.0 , 0.0 , 0.0 )	f(x(4))= 74.0000
# ...

# %%
#evolutionary search - no. of iterations is given , initial search is given , del value is given 
#2 variables 
import math
from decimal import Decimal
def f(x,y):
    return Decimal((9*(x**2))+(4*(y**2))-(6*x)-(8*y)+(8*x*y)+5)
x0=input(("Enter the intital value of x0"))
y0=input(("Enter the intital value of y0"))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
s=Decimal(input(("enter the number of iterations")))
i=1
j=0
fminb=[]

while i<=s:
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    fxx=[]
    x.append(Decimal(x0))
    y.append(Decimal(y0))
    f0=f(Decimal(x0),Decimal(y0))
    fxx.append(f0)
    x.append(Decimal(x[0]+(delx/2)))
    x.append(Decimal(x[0]-(delx/2)))
    y.append(Decimal(y[0]+(dely/2)))
    y.append(Decimal(y[0]-(dely/2)))
    fxx.append(f(x[1],y[1]))
    fxx.append(f(x[1],y[2]))
    fxx.append(f(x[2],y[1]))
    fxx.append(f(x[2],y[2]))
    print("x(0)=(",x0,",",y0,")\tf(x(0))=",f0)
    print("x(1)=(",x[1],",",y[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[2],",",y[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[2],",",y[2],")\tf(x(4))=",fxx[4])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[2]
    elif fxx[3]==fmin:
        x0=x[2]
        y0=y[1]
    elif fxx[4]==fmin:
        x0=x[2]
        y0=y[2]
    print("min lies in (",x0,",",y0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
        delx=delx/2
        dely=dely/2
        if i<s:
            print("")
            print("the new delx and dely values are:",delx,dely)
        if i<=s :
            i=i+1
            j=j+1
        else:
            break
    else:
        i=i+1
        j=j+1
# Out:
# Enter the intital value of x01
# Enter the intital value of y01
# Enter the x value in the reduction parameter0.8
# Enter the y value in the reduction parameter0.8
# enter the number of iterations2
#
# Interation no. :  1
# x(0)=( 1 , 1 )	f(x(0))= 12
# x(1)=( 1.4 , 1.4 )	f(x(1))= 26.56
# x(2)=( 1.4 , 0.6 )	f(x(2))= 17.60
# x(3)=( 0.6 , 1.4 )	f(x(3))= 8.00
# x(4)=( 0.6 , 0.6 )	f(x(4))= 4.16
# fmin= 4.16
# min lies in ( 0.6 , 0.6 )
#
# Interation no. :  2
# x(0)=( 0.6 , 0.6 )	f(x(0))= 4.16
# x(1)=( 1.0 , 1.0 )	f(x(1))= 12.00
# x(2)=( 1.0 , 0.2 )	f(x(2))= 8.16
# x(3)=( 0.2 , 1.0 )	f(x(3))= 1.76
# x(4)=( 0.2 , 0.2 )	f(x(4))= 3.04
# fmin= 1.76
# min lies in ( 0.2 , 1.0 )

# %%
#evolutionary search - no. of iterations is given , initial search is given , del value is given 
#3 variables 
import math
from decimal import Decimal
def f(x,y,z):
    return Decimal((((x**2)-y-11)**2)+((x+(y**2)-7)**2)+z)#function
x0=Decimal(input(("Enter the intital value of x0")))
y0=Decimal(input(("Enter the intital value of y0")))
z0=Decimal(input(("Enter the intital value of z0")))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
s=Decimal(input(("enter the number of iterations")))
i=1
j=0
fminb=[]
while i<=s:
    print("")
    print("Interation no. : ", i)
    x=[]
    y=[]
    fxx=[]
    x.append((x0))
    y.append((y0))
    z.append(z0)
    f0=f(x0,y0,z0)
    fxx.append(f0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    z.append(Decimal(z[k]+(delz/2)))
    z.append(Decimal(z[k]-(delz/2)))
    fxx.append(f(x[1],y[1],z[1]))
    fxx.append(f(x[1],y[1],z[2]))
    fxx.append(f(x[1],y[2],z[1]))
    fxx.append(f(x[1],y[2],z[2]))
    fxx.append(f(x[2],y[1],z[1]))
    fxx.append(f(x[2],y[1],z[2]))
    fxx.append(f(x[2],y[2],z[1]))
    fxx.append(f(x[2],y[2],z[2]))
    print("x(0)=(",x0,",",y0,",",z0,")\tf(x(0))=",fxx[0])
    print("x(1)=(",x[1],",",y[1],",",z[1],")\tf(x(1))=",fxx[1])
    print("x(2)=(",x[1],",",y[1],",",z[2],")\tf(x(2))=",fxx[2])
    print("x(3)=(",x[1],",",y[2],",",z[1],")\tf(x(3))=",fxx[3])
    print("x(4)=(",x[1],",",y[2],",",z[2],")\tf(x(4))=",fxx[4])
    print("x(5)=(",x[2],",",y[1],",",z[1],")\tf(x(5))=",fxx[5])
    print("x(6)=(",x[2],",",y[1],",",z[2],")\tf(x(6))=",fxx[6])
    print("x(7)=(",x[2],",",y[2],",",z[1],")\tf(x(7))=",fxx[7])
    print("x(8)=(",x[2],",",y[2],",",z[2],")\tf(x(8))=",fxx[8])
    fmin=min(fxx)
    print("fmin=",fmin)
    fminb.append(fmin)
    if fxx[0]==fmin:
        x0=x0
        y0=y0
        z0=z0
    elif fxx[1]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[1]
    elif fxx[2]==fmin:
        x0=x[1]
        y0=y[1]
        z0=z[2]
    elif fxx[3]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[1]
    elif fxx[4]==fmin:
        x0=x[1]
        y0=y[2]
        z0=z[2]
    elif fxx[5]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[1]
    elif fxx[6]==fmin:
        x0=x[2]
        y0=y[1]
        z0=z[2]
    elif fxx[7]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[1]
    elif fxx[8]==fmin:
        x0=x[2]
        y0=y[2]
        z0=z[2]
    print("min lies in (",x0,",",y0,",",z0,")")
    if j>0 and (fminb[j]==fminb[j-1]):
        delx=delx/2
        dely=dely/2
        delz=delz/2
        if i<s:
            print("")
            print("the new delx,dely and delz values are:",delx,dely,delz)
        if i<=s :
            i=i+1
            j=j+1
        else:
            break
    else:
        i=i+1
        j=j+1
# Out:
# Enter the intital value of x01
# Enter the intital value of y01
# Enter the intital value of z01
# Enter the x value in the reduction parameter1
# Enter the y value in the reduction parameter1
# Enter the z value in the reduction parameter1
# enter the number of iterations3
#
# Interation no. :  1
# x(0)=( 1 , 1 , 1 )	f(x(0))= 147
# x(1)=( 1.5 , 1.5 , -1.75 )	f(x(1))= 113.8750
# x(2)=( 1.5 , 1.5 , -2.25 )	f(x(2))= 113.3750
# x(3)=( 1.5 , 0.5 , -1.75 )	f(x(3))= 111.3750
# x(4)=( 1.5 , 0.5 , -2.25 )	f(x(4))= 110.8750
# x(5)=( 0.5 , 1.5 , -1.75 )	f(x(5))= 166.3750
# x(6)=( 0.5 , 1.5 , -2.25 )	f(x(6))= 165.8750
# x(7)=( 0.5 , 0.5 , -1.75 )	f(x(7))= 163.8750
# x(8)=( 0.5 , 0.5 , -2.25 )	f(x(8))= 163.3750
# fmin= 110.8750
# min lies in ( 1.5 , 0.5 , -2.25 )
#
# Interation no. :  2
# x(0)=( 1.5 , 0.5 , -2.25 )	f(x(0))= 110.8750
# x(1)=( 2.0 , 1.0 , -1.75 )	f(x(1))= 78.2500
# x(2)=( 2.0 , 1.0 , -2.25 )	f(x(2))= 77.7500
# x(3)=( 2.0 , 0.0 , -1.75 )	f(x(3))= 72.2500
# ...

# %%
#evolutionary search - starting point is given , del value is given , find all the search points 
#3 variables 
import math
from decimal import Decimal
x0=Decimal(input(("Enter the intital value of x0")))
y0=Decimal(input(("Enter the intital value of y0")))
z0=Decimal(input(("Enter the intital value of z0")))
delx=Decimal(input(("Enter the x value in the reduction parameter")))
dely=Decimal(input(("Enter the y value in the reduction parameter")))
delz=Decimal(input(("Enter the z value in the reduction parameter")))
i=1
j=0
while True:
    k=0
    x=[]
    y=[]
    z=[]
    x.append((x0))
    y.append((y0))
    z.append(z0)
    x.append(Decimal(x[k]+(delx/2)))
    x.append(Decimal(x[k]-(delx/2)))
    y.append(Decimal(y[k]+(dely/2)))
    y.append(Decimal(y[k]-(dely/2)))
    z.append(Decimal(z[k]+(delz/2)))
    z.append(Decimal(z[k]-(delz/2)))
    print("x(0)=(",x0,",",y0,",",z0,")")
    print("x(1)=(",x[1],",",y[1],",",z[1],")")
    print("x(2)=(",x[1],",",y[1],",",z[2],")")
    print("x(3)=(",x[1],",",y[2],",",z[1],")")
    print("x(4)=(",x[1],",",y[2],",",z[2],")")
    print("x(5)=(",x[2],",",y[1],",",z[1],")")
    print("x(6)=(",x[2],",",y[1],",",z[2],")")
    print("x(7)=(",x[2],",",y[2],",",z[1],")")
    print("x(8)=(",x[2],",",y[2],",",z[2],")")
    break
# Out:
# Enter the intital value of x01
# Enter the intital value of y02
# Enter the intital value of z07
# Enter the x value in the reduction parameter4
# Enter the y value in the reduction parameter4
# Enter the z value in the reduction parameter4
# x(0)=( 1 , 2 , 7 )
# x(1)=( 3 , 4 , 9 )
# x(2)=( 3 , 4 , 5 )
# x(3)=( 3 , 0 , 9 )
# x(4)=( 3 , 0 , 5 )
# x(5)=( -1 , 4 , 9 )
# x(6)=( -1 , 4 , 5 )
# x(7)=( -1 , 0 , 9 )
# x(8)=( -1 , 0 , 5 )

# %%
#evolutionary search - how many search points are taken in each iteration 
def f(x):
    return (2**x)+1
y=Decimal(input("Enter the number of variables used"))
print("the number of variables computed in each iteration of ",y,"variables is ",f(y))
# Out:
# Enter the number of variables used7
# the number of variables computed in each iteration of  7 variables is  129
